# %%
import pytesseract
from pdf2image import convert_from_path
import pandas as pd
import os

# Path to your Tesseract-OCR installation
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Update this path if necessary

# Function to convert PDF to images and extract text using OCR
def extract_text_from_pdf(pdf_path):
    # Convert PDF pages to images
    images = convert_from_path(pdf_path)
    text = ""
    for img in images:
        # Use pytesseract to do OCR on the image
        img_text = pytesseract.image_to_string(img)
        text += img_text + "\n"
    return text

# Function to create a mapping DataFrame from extracted text
def create_mapping_from_extracted_text(extracted_text, unique_words):
    # Split the text into lines
    lines = extracted_text.splitlines()
    
    # Prepare a mapping DataFrame
    mappings = []
    for word in unique_words:
        # Find the line that contains the current unique Sanskrit word
        for line in lines:
            if word in line:
                # Assuming the format is "Sanskrit Word - Transliteration - Meaning"
                parts = line.split('-')
                if len(parts) == 3:
                    transliteration = parts[1].strip()
                    meaning = parts[2].strip()
                    mappings.append([word, transliteration, meaning])
                break  # Exit loop after finding the word

    # Create a DataFrame
    df = pd.DataFrame(mappings, columns=['Unique Sanskrit Word', 'Transliteration', 'Meaning'])
    return df

# Main execution
if __name__ == "__main__":
    pdf_path = 'dictallcheck.pdf'  # Update with your PDF path
    csv_path = 'unique_sanskrit_words_ordered.csv'  # Update with your CSV path
    
    # Read unique Sanskrit words from the CSV file
    unique_sanskrit_words = pd.read_csv(csv_path)['Unique_Sanskrit_Words'].tolist()
    
    # Extract text from the PDF
    extracted_text = extract_text_from_pdf(pdf_path)
    
    # Print extracted text for review
    print("Extracted Text:")
    print(extracted_text)
    
    # Create mapping from the extracted text and unique Sanskrit words
    mapping_df = create_mapping_from_extracted_text(extracted_text, unique_sanskrit_words)
    
    # Show the first few entries of the DataFrame
    print("\nMapping DataFrame:")
    print(mapping_df.head(100))  # Display first 100 entries as a test
# Out:
# Extracted Text:
# Online Sanskrit Dictionary
# February 12, 2003
#
# Introduction
#
# The following is a list of Sanskrit words printed in Devanagari with its transliterated form
# and a short meaning provided as a reference source. This cannot be a substitute for a good
# printed Sanskrit-English dictionary. However, we anticipate this to aid a student of Sanskrit in
#
# the on-line world.
#
# The list of words is a compilation from various sources such as messages on sanskrit-digest,
# translated documents such as Bhagavadgita, atharvashiirshha, raamarakshaa et cetera, and other
# files accessible on the web. The words are encoded in ITRANS transliteration scheme so as to
#
# print them in Devanagari.
#
# There is a copyright on this file to the extent of preventing misuse on other internet sites
#
# and ego-trips of individuals.
#
# We recommend not to copy and post this file on any other site since we periodically update
# and correct this list and we do not want different versions of file floating around the internet.
#
# We have seen people copying this work and calling of their own.
#
# We request you to provide corrections, and more importantly many such additions from
#
# your own collection.
#
# The list has been arranged according to Devanagari sequence.
# The transliteration according to ITRANS (older 3.2) scheme is given by
#
# vowels(svara):
# a aa(A) iii(I) u uu(U) R7i R’le aio au aM aH L*iL‘I
#
# consonants(vya.njana):
#
# k kh g gh N*
#
# ch chh j jh JN
#
# TThDDhN
#
# tthddhn
#
# p ph b bhm
#
# y rlvshshhs h L(maraaThii) kSh(x ksh) GY (hindii)
# Both .n and M produce anusvaara, .a avagraha, .h haLa.nta
# H visarga, Only a dot . or a vertical line 0 a da.nDa .
# A backslash with a period produces just a dot (puurNaviraama),
# a.c and aa.c produce ardhachandra as in cat and talk.
# The vowels need to be added after each consonant, unless one wants joDaakshara,
#
# No other letters (upper or lower cases) are allowed.
#
# For other examples, see texts on Sanskrit Documents site at http://sanskrit.gde.to/ or its
#
# mirror at http://sanskrit.bhaarat.com the document project.
#
# There is an excellent freeware available for Itrans users, called Itranslator98/99, written by
# Swamis at Omkarananda Ashram. Please download and install it from
# http: //www.omkarananda-ashram.org/Sanskrit /Itranslt.html The .itx version of this file is
# directly viewable in the software allowing text display in Devanagari as well as
#
# Roman-+diacritics marks.
#
# For those interested in volunteering to encode, proofread, or translate Sanskrit documents
# we suggest you access volunteer help file from
#
# http://sanskrit.gde.to/ OR
#
# http://sanskrit.bhaarat.com in the document project.
#
# The site contains additional information on Sanskrit projects. A file of frequently
# asked-answered questions (FAQ) is available at
#
# http: //sanskrit.gde.to/sanskritfaq. html
#
# Please join us in collecting word = meaning lists with word encoded in strict ITRANS
#
# scheme format.
# Please contact sanskrit@cheerful.com for additional details.
#
# We appreciate your contribution to make this effort successful.
#
# Glossary of Sanskrit Terms
# i T
# 3 (AUM) = Primordial Sound
# sare (OMkaara) = the syllable om
#
# a (a) = not
#
# wea (ankusha) = a goad (metal stick used to control elephants)
#
# i a.nkushadhaariNam.h) = bearing the weapon ‘ankusha’ with which the elephant
# aerahory (ankushadhaariNam.h) = b hi ‘ankusha’ with which the eleph
#
# 3aT (amga) = body, organ
#
# aim (angaNa) = field
#
# sore rat (a.ngasa.nginau) = with
#
# ar: (a.ngaiH) = limbs, body parts
# airequataeayhr: (a.ngaistushhTuvaa.nsastanuubhiH) = having satisfied with strong limbs?
# art (a.njana) = anointment
#
# w#aGT (antara.nga) = inner body or inner nature, feelings, inside
# amt (antargata) = internal
#
# 3#aT (aMbaa) = mother
#
# aa (a.nsha) = part, angle
#
# agrqd (a.nshabhuutaM) = has been a part of her
# 3: (a.nshaH) = fragmental particle
#
# SYA (a.nshumaan.h) = radiant
#
# aigrq (a.nshena) = part
#
# aHat (akartaaraM) = as the nondoer
#
# aq (akarma) = inaction
#
# aatgq (akarmakRit.h) = without doing something
# aaa: (akarmaNaH) = than no work
#
# ararifor (akarmaNi) = in not doing prescribed duties
# wart (akalmashhaM) = freed from all past sinful reactions
# aac (akasmaat.h) = by chance
#
# aart: (akaaraH) = the first letter
#
# warm? (akaaro) = the letter ‘a’
#
# award (akaarya) = and forbidden activities
#
# ward (akaaryaM) = what ought not to be done
# aaTt (akaarye) = and what ought not to be done
# aah (akiirti) = infamy
#
# aatft (akiirtiM) = infamy
#
# aatft: (akiirtiH) = ill fame
#
# ag@dq (akurvat.h) = did
#
# aaa (akurvata) = did they do
#
# aga (akushalaM) = inauspicious
#
# aHpratecary (akRitabuddhitvaat.h) = due to unintelligence
# aeneart: (akRitaatmaanaH) = those without self-realisation
#
# wea (akRitena) = without discharge of duty
# aweeaT (akRitvaa) = without doing (from kRi)
#
# aacetfaar: (akRitsnavidaaH) = persons with a poor fund of knowledge
# afar: (akriyaaH) = without duty
#
# ATT (akrodha) = freedom from anger
#
# aTATe: (akrodhaH) = freedom from anger
#
# FeTT: (akledyaH) = insoluble
#
# afte (akhila) = entire
#
# afact (akhilaM) = whole
#
# afenye (akhilaguru) = preceptor for all, also all types of long syllable letters
# ard (agata) = not past
#
# added (agatasuu.nscha) = agata + asuun.h + cha:undeparted life + and (living people)
# sTeqT (agatvaa) = without going (from gam.h)
#
# aTy (agama) = proof of the trustworthiness of a source of knowledge
# SITESTATH = (agastamaasa) = month of August
#
# arat_s (agochara) = (adj) unknown
#
# afrt (agni) = fire
#
# ater: (agniH) = fire
#
# afaqdd: (agniparvataH) = (m) volcano, volcanic cone
# afatfast (agnipetikaa) = (f) matchbox
#
# afasearet (agnishalaakaa) = (f) matchstick
#
# aay (agnishhu) = in the fires
#
# ait (agnau) = in the fire of consummation
#
# ay (agra) = (neut in this sense) tip
#
# wa (agraM) = at the tip
#
# wut: (agrajaH) = elder
#
# aud: (agrataH) = (let the two go) before (me)
# amare: (agradiipaH) = (m) headlight
#
# aq (agre) = in front of/ahead/beforehand
#
# aaa: (aghaMmanal) = (adj) evil-minded
#
# wat (aghaM) = grievous sins
#
# seaTq: +(aghaayuH) = whose life is full of sins
#
# ag (anka) = number
#
# ay (amga) = a limb, or body part
#
# aq (angaM) = limb(s)
#
# agihr (a.ngaani) = limbs
#
# aye (a.ngula) = a finger
#
# age (a.ngushhTha) = the big toe
#
# age: (a.ngushhThaH) = (m) thumb
#
# aaqt (acharaM) = and not moving
#
# water (acharasya) = and nonmoving
#
# wat (achala) = (adj) still, stationary
#
# wat (achalaM) = unmoving
#
# aac: (achalaH) = immovable
#
# arate (achalapratishhThaM) = steadily situated
#
# aac (achalaa) = unflinching
#
# TIT (achalena) = without its being deviated
#
# aaa, (achakShus.h) = one without an eye
#
# aaTqt (achaapalaM) = determination
#
# afer (achintya) = inconceivable
#
# ahr (achintyaM) = beyond contemplation
#
# afar: (achintyaH) = inconceivable
#
# afar (achiraad.h) = without delay/in no time
# afeurse (achiraadbhava) = in no time from the cycle of birth&death
# afar (achireNa) = very soon
#
# adet: (achetasaH) = without KRishhNa consciousness
# Wea: (achchhedyaH) = unbreakable
#
# aeqt (achyuta) = O infallible one
#
# weqdy (achyutam.h) = the who does not slip
#
# aT (aja) = goat
#
# aw (ajaM) = unborn
#
# at: (ajaH) = unborn
#
# sent: (ajagaraH) = (m) python
#
# S@wIT (ajapaa) = involuntary repetition (as with a mantra)
# ware (ajasraM) = the unborn one
#
# aT (ajaa) = (f) goat
#
# watt (ajaanaM) = do not understand
#
# aera (ajaanat.h) = knew
#
# aaa (ajaanataa) = without knowing
#
# wrt: (ajaanantaH) = without knowing
#
# aeqt: (aJNchalaH) = (m) aanchal in Hindi
#
# aeaTtT (aJNjana) = the name of the mother of Hanuman
# IAAI (aJNjaneyaasana) = the splits
#
# asaft (aJNjali) = (m) folded hands
#
# weft (aTati) = (1 pp) to roam
#
# aurare (aNiiyaa.nsaM) = smaller
#
# ay (aNu) = atom
#
# amr: (aNoH) = than the atom
#
# svqet (aNvastraM) = (n) nuclear weapon
#
# aq: (ataH) = hence
#
# aarataq (atattvaarthavat.h) = without knowledge of reality
# afer: (atandritaH) = with great care
#
# aaventa (atapaskaaya) = to one who is not austere
# aft (ati) = extremely
#
# ateatesr (atiparichaya) = excessive familiarity
#
# afedrt (ativiiryaM) = super power
#
# aferare (atichaara) = Accelerated planetary motion
# afta (atitaranti) = transcend
#
# afract (atitaralaM) = ati+tarala, very+-unstable
#
# atfafr (atithi) = (m) guest
#
# atefr: (atithiH) = (masc.Nom.sing.)guest (literally undated)
# afrererry (atidaaruuNaman.h) = adj. very dreadful
# afager (atidurvRitta) = of exceedingly bad conduct
# ata (atirichyate) = becomes more
#
# atrada (ativartate) = transcends
#
# afar (atishaya) = wonderful
#
# afesratter (atishayokti) = exaggeration
#
# aera: (atiitaH) = surpassed
#
# ater (atiitya) = transcending
#
# atest (atiindriyaM) = transcendental
#
# ate (atiiva) = very much
#
# ETAT (atulaniiya) = uncomparable
#
# aqea (atuulyaM) = uncomparable
#
# act (atmaanaM) = (masc.Acc.S)the self
#
# waa + (atyajat.h) = left, sacrifice
#
# act (atyantaM) = the highest
#
# aert (atyarthaM) = highly
#
# aearhtat (atyaaginaaM) = for those who are not renounced
# aeaft (atyaani) = surpassing
#
# acqer (atyushhNa) = very hot
#
# aeafe (atyeti) = surpasses
#
# aq (atra) = here
#
# ay (atha) = thereupon
#
# aysise (athashabda) = the word atha (prayers are started with words atha or AUM)
# at: (atha.rH) = object, meaning
#
# aadqvatet (atharvaNvaakyaM) = ‘atharvaNa” word-piece
# ayasitt (atharvashiirshha) = atharva(?)
#
# aera t (atharvashiirshhaM) = ’atharva’ heading or head
# swat (athavaa) = or
#
# watt: (athaataH) = atha and ataH : then and therefore
# aut (athau) = or in other words
#
# aq (ad.h) = to eat
#
# weed (adadat.h) = gave
#
# aefaret (adambhitvaM) = pridelessness
#
# wast: (adarshaH) = mirror
#
# aefartr (adakShiNaM) = with no remunerations to the priests
# aetey: (adaahyaH) = unable to be burned
#
# afadt (aditii) = the mother of the gods
#
# age (adRishhTa) = Unseen, fortune, luck
#
# aeeyd (adRishhTapuurvaM) = never seen before
#
# ae (adesha) = at an unpurified place
#
# aga (adbhuta) = the sentiment of marvel
#
# agd (adbhutaM) = wonderful
#
# aga (adbhuutaM) = wonderfull
#
# WI (adya) = today
#
# age: (adrohaH) = freedom from envy
#
# aglet (advaasana) = the prone posture
#
# afar: (advitiiyaH) = the inseparable or the non-dual
# @geT (adveshhTaa) = nonenvious
#
# ser (advaita) = non-duality of the universal spirit
# a@q: (adhaH) = (indeclinable) below
#
# aq (adhana) = one without money
#
# aay (adhama) = inferior
#
# aaqat (adhamaaM) = condemned
#
# aaqaTas (adhamaadhama) = the worst among the inferior
# wat (adhara) = Lip
#
# wat: (adharaH) = (m) lips
#
# aera (adharaat.h) = from below
#
# aqyq (adharma) = breach of duty
#
# aat (adharmaM) = irreligion
#
# aert: (adharmaH) = irreligion
#
# aaaarTet (adharmachaarii) = adj. impious
#
# aadeq (adharmasya) = of irreligion
#
# afae# (adhika) = additional
#
# aaa (adhikaM) = more
#
# afan: (adhikaH) = greater
#
# afaaat: (adhikataraH) = very much
#
# afeart (adhikaara) = title
#
# afeare: (adhikaaraH) = right
#
# afeatitast (adhikaaritantraM) = (n) bureaucracy
# afafarcte (adhikShipati) = to censure
#
# afeerq: (adhikShepaH) = (m) accusation
#
# aforafe (adhigachchhati) = attains
#
# after (adhigamya) = having gone to
#
# afar (adhidaiva) = the principle of subjective existence
# afye¢ (adhidaivaM) = governing all the demigods
# afatad (adhidaivataM) = called adhidaiva
#
# afafraa: (adhiniyamaH) = (m) act
#
# afaq (adhipa) = protector
#
# afatft (adhipati) = lord
#
# ange (adhibhuta) = the principle of objective existence
# aft (adhibhuutaM) = the material manifestation
# ahr (adhimaatra) = superior
#
# afrararert (adhimaatraatama) = the highest, the supreme one
#
# afar (adhiyaGYa) = the principle of sacrifice, incarnation
# afyaa: (adhiyaGYaH) = the Supersoul
#
# afvart (adhivaasa) = dwelling
#
# afyaat (adhiveshanaM) = (n) conference
#
# afrsrt (adhishhThaana) = seat, abode
#
# afrert (adhishhThaanaM) = sitting place
#
# afasrt (adhishhThaaya) = being so situated
#
# afvaft (adhisari) = competent candidate
#
# waite (adhiita) = studied
#
# aaitaT (adhiitaa) = studied
#
# ait: (adhiiyaanaH) = studied
#
# a@qat (adhunaa) = recently
#
# avarqe (adhomukha) = face downwards
#
# TATA ATT (adhomukhashvaanaasana) = the dog stretch posture
# aeqat (adhyayana) = study
#
# Teaay: (adhyayanaiH) = or Vedic study
#
# aeqay (adhyakSheNa) = by superintendence
#
# aeqTeq (adhyaatma) = the principle of self
#
# areatet (adhyaatmaM) = transcendental
#
# srearTenfaar (adhyaatmavidyaa) = spiritual knowledge
# areata: (adhyaadeshaH) = (m) ordinance
#
# srearafag (adhyaapayituM) = to teach (infinitive of causative of adhi+i, to study)
# areatftsT (adhyaapikaa) = (f) lady teacher
#
# areata (adhyaasa) = a case of mistaken identity
#
# areqrgad (adhyeshhyate) = will study
#
# PAT (adhyopatya) = Lordship
#
# aya (adhruvaM) = temporary
#
# seq (adhvan.h) = road
#
# @aT{ (adhvaan.h) = (m) road, path, way
#
# at TATA (an.gamejayatva) = unsteadiness of the body
# aqq (anagha) = O sinless one
#
# @teqT (ananta) = infinite, a name of Vishnu
#
# wast (anantaM) = unlimited
#
# aaeq: (anantaH) = Ananta
#
# Baat (anantaraM) = after
#
# WeTeT (anantaruupa) = O unlimited form
#
# Bate (anantaruupaM) = unlimited form
#
# arafaat (anantavijayaM) = the conch named Ananta-vijaya
# aradat (anantaviiryaa) = unlimited potency
#
# @eaT: +(anantaaH) = unlimited
#
# a@aat (anantaasana) = Ananta’s posture
#
# Waa: (ananyachetaaH) = without deviation of the mind
# BTaATR (ananyabhaak.h) = without deviation
#
# aTaAaT: (ananyamanasaH) = without deviation of the mind
# @TaaT (ananyayaa) = unalloyed, undeviating
#
# aT (ananyayogena) = by unalloyed devotional service
# WaT: +(ananyaaH) = having no other object
#
# aeart (ananyena) = without division
#
# ararrer: (anapekShaH) = neutral
#
# TET (anapekShya) = without considering the consequences
# aahrag: (anabhishva.ngaH) = being without association
# aah (anabhisandhaaya) = without desiring
#
# aaftete: (anabhisnehaH) = without affection
#
# afte (anabhiGYa) = ignorant of, unacquainted with
# aaa: (anayoH) = of them
#
# at (anarthaM) = purposeless/in vain/danger-productive
# wat (anala) = fire
#
# wae: (analaH) = fire
#
# aqert (analena) = by the fire
#
# aaqqeateart (anavalokayaan.h) = not looking
#
# waqaTat (anavaaptaM) = wanted
#
# wage: (anashnataH) = abstaining from eating
#
# Way (anashnan.h) = without eating (having fasted)
# aqqad (anasuyave) = to the nonenvious
#
# wqqa: (anasuuyaH) = not envious
#
# aqqa-dt: (anasuuyantaH) = without envy
#
# areata (anaha.nvaadi) = without false ego
#
# ategiTe: (anaha.nkaaraH) = being without false egoism
# gaat: (anaatmanaH) = of one who has failed to control the mind
# aTet (anaadara) = lack of respect
#
# arate (anaadi) = without beginning
#
# aafe (anaadiM) = without beginning
#
# arathacr (anaaditva) = non-beginning
#
# aatfacatat (anaaditvaat.h) = due to eternity
#
# aaTTahAH (anaanasaphalam.h) = (n) pineapple
#
# waTaa (anaamayaM) = without miseries
#
# aay, (anaarambhaat.h) = by nonperformance
#
# aja (anaarya) = persons who do not know the value of life
# aagft (anaavRittiM) = no return
#
# amafart: (anaashinaH) = never to be destroyed
#
# oratfare: (anaashritaH) = without taking shelter
#
# aaTet (anaahata) = unbeaten
#
# afar: (aniketaH) = having no residence
#
# afte (anichchhan.h) = without desiring
#
# after (anitya) = uncertain/temporary /ephemeral /transient
# afer (anityaM) = temporary
#
# after: (anityaH) = nonpermanent
#
# afrafta (aniyamita) = irregular
#
# afrast (anirdeshyaM) = indefinite
#
# afafarrsce (anirviNNachetasa) = without deviation
# afta: (anilaH) = wind or air
#
# afargiet (anilachulli) = (f) gas (LPG)
#
# afrart (anivaarya) = (adj) compulsary
#
# aftgaq (anishchayat.h) = due to non-determination (having not decided)
# afte (anishhTa) = and undesirable
#
# afr (anishhTaM) = leading to hell
#
# arat (aniishvaraM) = with no controller
#
# Wy (anu) = following
#
# aqeeqt (anukampaarthaM) = to show special mercy
# agate (anukaari) = like
#
# ATA (anuchaaraya) = (causative of anu+car) follow
# aqhaarrt (anuchintayan.h) = constantly thinking of
# aqfasfe (anutishhThanti) = regularly perform
#
# wqaH (anuttamaM) = the finest
#
# aqaat (anuttamaaM) = the highest
#
# aqestt (anudarshanaM) = observing
#
# wqett (anudaanaM) = (n) donation, grant
#
# ager (anudinaM) = daily
#
# aqfeya (anuddishya) = having targetted or aimed at
# arqarhrar (anudyogitaa) = unemployment
#
# aqarit (anudyogii) = unemployed
#
# arpferaaar: (anudvignamanaaH) = without being agitated in mind
# aqarat (anudvegakaraM) = not agitating
#
# arate (anupakaariNe) = irrespective of return
# aqigaft (anupashyati) = one tries to see through authority
# arate (anupashyanti) = can see
#
# aqigattt (anupashyaami) = do I foresee
#
# AqITaT: +(anuprapannaaH) = following
#
# a@qa-T (anubandha) = (m) result, effect
#
# aqaet (anubandhaM) = of future bondage
#
# a@qa-t: (anubandhaH) = (m) annexure
#
# ayant (anubandhiini) = bound
#
# aqaq=t (anubandhe) = at the end
#
# aqvg: (anubhavaH) = (m) experience
#
# a@qaT + (anumantaa) = permitter
#
# AqAT{ (anumaatuM) = to guess
#
# a@qartT (anumaana) = an inference
#
# aqaraT{: (anumaanaat.h) = (ablat.)from guessing or induction
#
# agatha: (anuyaayinaH) = followers
#
# 10
#
# ayaa (anurajyate) = is becoming attached
# @TTAT (anuraadhaa) = Seventeenth nakshatra
#
# araferer (anulipta) = smeared
#
# aT (anulekha) = destiny
# agqeaqt (anulepanaM) = smeared with
#
# ayer (anuloma) = with the grain, naturally
#
# ayaa (anuvartate) = follows in the footsteps
#
# aqadst (anuvartante) = would follow
#
# aqadate (anuvartayati) = adopt
#
# wqate (anuvaadaM) = translation
#
# aqara (anuvaadya) = having translated
#
# agri (anuvidhiiyate) = becomes constantly engaged
# aqafaart (anushaasitaaraM) = the controller
#
# @qWZZFA (anushushruma) = I have heard by disciplic succession
# agate (anushochanti) = lament
#
# agnhad (anushochituM) = to lament
#
# aad (anushhajjate) = one necessarily engages
# ATT (anushhTup.h) = the format’s name
#
# @qST (anushhThana) = (n) performance, execution
# aged? (anusantataani) = extended
#
# aqaest (anusandhaanaM) = (n) investigation
# aqaTt (anusaara) = following, customary (masc)
# aqeqt (anusuuchii) = schedule
#
# @YTFAC (anusmara) = go on remembering
#
# ATACT (anusmaran.h) = remembering
#
# TTAT (anusmaret.h) = always thinks of
#
# aqTeat: +(anusvaaraH) = the accompanying sound or letter ( the letter form ‘.n’ ‘M’?)
# aqataat +(anuGYaayataaM) = (verb) be given leave/permission
# wqatt (anuuchaanaM) = (teacher?)
#
# @qq (anRita) = false
#
# aq (aneka) = Many
#
# awa (anekadhaa) = into many
#
# aaqaat (anekavachanaM) = plural
#
# avatht (anekaani) = many
#
# aq (anena) = by this
#
# wat (angaM) = body
#
# aT (anta) = end
#
# at (antaM) = or end
#
# aq: (antaH) = (adv) inside
#
# WUATT (antaHkaraNa) = Mind
#
# aeaifest (antaHpeTikaa) = (f) drawer
#
# area (antaHsthaani) = within
#
# ada (antakaale) = at the end of life
#
# 11
#
# aenrtd (antagataM) = completely eradicated
# Wat (antara) = Sub-period in a Dasha
# wat (antaraM) = between
#
# waty (antara.nga) = the practices of pranayama and pratyahara
# PATENT (antaradeshiiya) = among different countries mainly for transaction??
# SITIHAT (antaraatmanaa) = within himself
# BATH (antaraatmaa) = the inner self, residing in the heart
# aay (antaraaya) = (m) obstacle
# WIA: +(antaraaraamaH) = actively enjoying within
# araheer (antarikSha) = (n) space
#
# araftet (antarikShaM) = space, sky
#
# TIT (antare) = between
#
# ary (antareNa) = without
#
# aeaeatte: (antarjyotiH) = aiming within
# aagqqey (antaryutakam.h) = (n) vest
# aeagqe: (antarsukhaH) = happy from within
# aeqaq (antavat.h) = perishable
#
# waa: (antavantaH) = perishable
#
# afare (antike) = near
#
# ae (ante) = after
#
# aq (andha) = blind
#
# aeTHTe (andhakaara) = darkness
#
# aa (anna) = food
#
# aa (annaM) = foodstuff
#
# @aT{ (annaat.h) = from grains
#
# aq (anya) = other person
#
# wet (anyaM) = other
#
# aq: (anyaH) = another
#
# Wa (anyat.h) = other
#
# way (anyatra) = somewhere else
#
# a-aUT (anyathaa) = other
#
# aaat (anyayaa) = by the other
#
# wat (anyaaM) = another
#
# aarq (anyaan.h) = others
#
# aeaft (anyaani) = different
#
# wart (anyaayena) = illegally
#
# aq (anye) = others
#
# wart (anyena) = by another
#
# a-nz: (anyebhyaH) = from others
#
# wer: (anyaiH) = by others
#
# a-arq (anyonya) = mutual
#
# aqa (anvaya) = Family
#
# as: (anvashochaH) = you are lamenting
#
# 12
#
# afqeg (anvichchha) = try for
#
# afta (anvita) = (p.p) Followed or attended by, in company with, joined by; having ossessed of;
# overpowerd by, connected grammatically;
#
# afqat: (anvitaaH) = absorbed
#
# aavr{ (anveshhaNam.h) = (n) search, exploration
# aqH (apakRi) = to harm
#
# ATH RT (apakendraNa) = centrifugation
#
# atqG (apa.nga) = handicapped
#
# ara (apachii) = to decrease
#
# aye (apaTham.h) = read
#
# aqiftst (apaNDita) = someone who is not a scholar
# aq (apatya) = Progeny
#
# aTqITT (apanudyaat.h) = can drive away
#
# STAT (apamaa) = comparison
#
# STaMat: (apamaanayoH) = and dishonour
#
# a@qt (apara) = other
#
# BI (aparaM) = junior
#
# AIT (apararaatra) = (m) dawn
#
# AIT (aparaspara) = without cause
#
# aT (aparaa) = lower
#
# aqifat: (aparaajitaH) = who had never been vanquished
# arse (aparaajiita) = Unconquered
#
# arf (aparaaNi) = others
#
# aqTwy] (aparaan.h) = others
#
# avftae (aparigraha) = abstention from greed, non-possessiveness
# aaftue: (aparigrahaH) = free from the feeling of possessiveness
# aqfaa (aparimeyaM) = immeasurable
#
# ayfcert (aparihaarye) = of that which is unavoidable
# aqt (apare) = others
#
# ayaret (aparyaaptaM) = immeasurable
#
# areas (apalaayanaM) = not fleeing
#
# arent (apavarga) = heaven, liberation
#
# avdet (apavahanaM) = seducetion
#
# aqate (apavaada) = exceptional
#
# aifaet: (apavighnaH) = without obstacles
#
# aqgaq ~(apashyat.h) = he could see
#
# ATC (apasmaara) = forgetful
#
# ATA: +(apasmaaraH) = (m) epilepsy
#
# aTEcy (apaharaNa) = stealing
#
# aywett (apaharaNaM) = abduction, kipnapping
# aveqtt (apahartaaraM) = the remover]destroyer
# awed (apahRita) = stolen
#
# areqaarea4nr (apahRitachetasaaM) = bewildered in mind
#
# 13
#
# AIPA: (apaatrebhyaH) = to unworthy persons
#
# watt (apaana) = one of the vital airs, controls the elimination of bodily wastes
# aqtt (apaanaM) = the air going downward
#
# aot (apaane) = in the air which acts downward
#
# wT (apaapo) = without sins
#
# arabe: (apaayinaH) = disappearing
#
# aq (apaaraa) = one who has no limits
#
# awdd (apaavRitaM) = wide open
#
# aft (api) = also
#
# aney (apiiteshhu) = (Masc.Loc.P1.) having not drunk(taken water)
# ayy (apuNya) = vice
#
# agra (apunaraavRittiM) = to liberation
#
# agst (apushhpa) = one without flowers
#
# aryfrear: (apRithivyoH) = to the earth
#
# ata (apekSh.h) = to expect
#
# ayar (apekShaa) = (f) expectation, hope
#
# aug (apaishunaM) = aversion to fault-finding
#
# ate? (apohanaM) = forgetfulness
#
# aaat (apyayau) = disappearance
#
# area: (aprakaashaH) = darkness
#
# asfaasare (apratimaprabhaava) = O immeasurable power
# aufas (apratishhThaM) = without foundation
#
# asfas: (apratishhThaH) = without any position
#
# amrarart (apratiikaaraM) = without being resistant
#
# aware (apradaaya) = without offering
#
# avaa (aprameya) = the ununderstandable
#
# ayaa (aprameyaM) = immeasurable
#
# WITTE (aprameyasya) = immeasurable
#
# ayaft: (apravRittiH) = inactivity
#
# aaa (apraaptat.h) = uttained, obtained
#
# aaTa (apraapya) = failing to attain
#
# aay ~(apraamaamaaNya) = Unjustified
#
# afva (apriyaM) = the unpleasant
#
# afore: (apriyaH) = and the undesirable
#
# aq (apsu) = in water
#
# aaAgt (aphala) = one without fruit
#
# ARATTAT (aphalaprepsunaa) = by one without desire for fruitive result
# anerrartea hr: (aphalaakaa.nkShibhiH) = by those devoid of desire for result
# aa-J (abandhu) = one who does not have any brothers / kinmen
# wat (abala) = helpless (woman)
#
# aaa (abalaa) = (helpless) Woman
#
# agGgEga: (abuddhayaH) = less intelligent persons
#
# aarr (abodha) = Ignorance
#
# 14
#
# aeq (abda) = Season of plenty
#
# afer (abdhi) = sea
#
# wet (abdhii) = (m) ocean, sea
#
# ATT (abraviit.h) = spoke
#
# agave (abrahmaNya) = Not kosher
#
# stata (abhaktaaya) = to one who is not a devotee
# wa (abhaya) = freedom from fear
#
# ava (abhayaM) = fearlessness
#
# RT (abhaye) = and fearlessness
#
# wad (abhavat.h) = became
#
# amtfasrq. (abhavishhyat.h) = will become
#
# we: (abhaavaH) = changing quality
#
# smTaad: + (abhaavayataH) = of one who is not fixed
# saTyt + (abhaashhata) = began to speak
#
# aht (abhi) = preposition
#
# ahi (abhi+taD.h) = to strike
#
# afhteert (abhikathanaM) = (n) allegation
#
# afta (abhikrama) = in endeavouring
#
# ahtate (abhichaara) = black magic
#
# ahrrrart (abhijanavaan.h) = surrounded by aristocratic relatives
# ahi: (abhijaataH) = born of
#
# afr (abhijaatasya) = of one who is born of
# ahtaratt (abhijaananti) = they know
#
# ahaa (abhijaanaati) = does know
#
# ahirad (abhijaayate) = becomes manifest
#
# aha (abhijita) = A nakshatra between uttaraashhDhaa and shravaNa mainly centred on the
# star Vega. For some reason it is not usually included in the 27 nakshatras although it would
# make 28 if it was. adhipatii - Lord
#
# ahiraat (abhijin.hmuhuurta) = the most auspicious moment
# afta: (abhitaH) = everywhere
#
# afagre: (abhidrohaH) = (m) insurgency
#
# abreast (abhidhaanaM) = (n) designation
#
# ahrareafa (abhidhaasyati) = explains
#
# afta (abhidhiiyate) = is called
#
# ahteadt (abhinandatii) = praises
#
# afta (abhinaya) = acting
#
# afafraa (abhinivesha) = possessiveness
#
# ahrare: (abhinyaasaH) = (m) layout
#
# ahr: (abhipushhTiH) = (f) affirmation
#
# aha: (abhipravRittaH) = being fully engaged
# afhisra: (abhipraayaH) = (m) opinion
#
# afnraft (abhibhavati) = transforms
#
# ahprart (abhibhavaat.h) = having become predominant
#
# 15
#
# abner (abhibhuuya) = surpassing
#
# ahr: (abhimanaH) = conceit
#
# ahrart (abhimaana) = self-importance
#
# ahtqet: (abhimukhaaH) = towards
#
# ahrarsat (abhiyaachanaa) = (f) demand
#
# ahrgrarat (abhiyuktaanaaM) = fixed in devotion
#
# ahranr (abhiyoga) = prosecution
#
# ahrart: (abhiyogaH) = (m) prosecution
#
# aha: (abhirataH) = following
#
# ahrearreg (abhirakShantu) = should give support
#
# aficfert (abhirakShitaM) = perfectly protected
#
# arhrefarert (abhirakShitam.h) = who has been well protected
# ahrmfercarart (abhiraamastrilokaanaaM) = the laudable rAma for all the three worlds
# ahrfasaater (abhivijvalanti) = and are blazing
#
# afafvaft (abhishhi.nchati) = performs’ puuja’, by pouring water etc. on the idol
# ahwt (abhishhekaM) = ablution
#
# ahta-arq (abhisandhaaya) = desiring
#
# afafgat (abhihitaa) = described
#
# art (abhiipsita) = desired
#
# apatra: (abhyadhikaH) = greater
#
# mayest (abhyanunaadayan.h) = resounding
#
# spat (abhyarchya) = by worshiping
#
# saat (abhyasanaM) = practice
#
# saqaeyT: (abhyasuuyakaaH) = envious
#
# sragqafe (abhyasuuyati) = is envious
#
# waqad: (abhyasuuyantaH) = out of envy
#
# mM7eT (abhyahanyanta) = were simultaneously sounded
# Many: (abhyaaropaH) = (m) indictment
#
# spare (abhyaasha) = outskirts
#
# satay (abhyaasa) = study
#
# spaTaant (abhyaasayoga) = by practice
#
# PATA aNT (abhyaasayogena) = by the practice of devotional service
# saTeaTq: (abhyaasaat.h) = than practice
#
# wary (abhyaase) = in practice
#
# spgTat (abhyaasena) = by practice
#
# mz (abhyutthaanaM) = predominance
#
# syeq (abhyudaya) = rise , prosperity
#
# ay (abhraM) = cloud
#
# aq (ama.nda) = not slow or dull, active, intelligent; sharp, strong, violent, not little
# wa-aqT (amanyata) = believed
#
# at (amarshha) = (m) anger
#
# aq (amala) = without rubbish
#
# wat (amalaM) = clean
#
# 16
#
# aac (amalaan.h) = pure
#
# aafact (amaanitvaM) = humility
#
# afvafanat: (amitavikramaH) = and unlimited force
#
# at (amii) = all those
#
# aga (amutra) = in the next life
#
# @{eT: (amuuDhaaH) = unbewildered
#
# syct (amuulya) = priceless, excellent
#
# aya (amRita) = of ambrosia, potion to cause immortality
# aad (amRitaM) = veritable nectar
#
# aqrara (amRitattvaaya) = for liberation
#
# aqdfa-g (amRitabinduu) = a drop of nectar
#
# airy: (amRitabhujaH) = those who have tasted such nectar
# aqdeq (amRitasya) = of the immortal
#
# aqdted (amRitodbhavaM) = produced from the churning of the ocean
# aq (amRitopamaM) = just like nectar
#
# aaet (amedhyaM) = untouchable
#
# a@a-T (ambandha) = relation / connection
#
# gat (ambara) = aakaasha
#
# arqt (ambaraM) = sky, garment
#
# Seat (ambaa) = mother
#
# aq (ambu) = water
#
# arghr (ambudhi) = sea
#
# aqua: (ambuvegaaH) = waves of the waters
#
# aeaTq (ambhas.h) = (n) water
#
# aT (ambhasaa) = by the water
#
# waif] (ambhasi) = on the water
#
# waee (ambhuruhaM) = lotus
#
# att (amla) = (m) sour
#
# wat (ayaM) = him (from idaM.h)
#
# waxed (ayajanta) = third person plur. imperfect aatmanepada of yaj, to worship
# arate: (ayatiH) = the unsuccessful transcendentalist
#
# waurad: (ayathaavat.h) = imperfectly
#
# aaay (ayaneshhu) = in the strategic points
#
# way (ayama) = length, extension, restraint
#
# way: (ayashaH) = infamy
#
# wae: (ayasaH) = (m) iron
#
# aaaeq (ayaGYasya) = for one who performs no sacrifice
# aged: (ayuktaH) = one who is not in KRishhNa consciousness
# aqrdeq (ayuktasya) = of one who is not connected (with KRishhNa consciousness)
# sane: (ayogataH) = without devotional service
#
# warmer (ayojayishhyat.h) = if one does not join or connect
# wari (ayobhaaNDam.h) = (n) a wooden barrel
#
# agqy (araNyam.h) = (n) jungle, forest
#
# 17
#
# Ua HT: (araNyaukasaH) = (Masc.poss.sing.) forester’s
#
# arf: (aratiH) = being without attachment
#
# AMET: (araagadveshhataH) = without love or hatred
#
# aft (ari) = enemies
#
# afore (aribhaava) = the sixth house in a Rashi or bhaava chart
# afty (arishhu) = on enemies
#
# aftsaft: (arishhTanemiH) = the appelation to Garuda?
# aftqet (arisuudana) = O killer of the enemies
#
# arate (arogita) = diseaselessness
#
# ae (arka) = essence, a name of Sun
#
# aq (argha) = value
#
# arate (archati) = (1 pp) to worship
#
# afiq (archituM) = to worship
#
# aot (arjana) = obtaining
#
# att (arjanaM) = the earning or acquiring or acqusition
#
# aya (arjuna) = a disciple of Krishna, hero of the Mahabharata
# aya (arjunaM) = unto Arjuna
#
# aayt: (arjunaH) = Arjuna
#
# ayqar: (arjunayoH) = and Arjuna
#
# ay (artha) = money
#
# at (arthaM) = wealth
#
# aw: (arthaH) = is meant
#
# aq (arthan.h) = and economic development
#
# aig (arthanaipuNa) = (n) efficient in polity
#
# arfertafe (arthapraaptirbhavati) = wealth-attainment becomes
# wae (arthayate) = (10 pp) to request
#
# aviary (arthavaan.h) = one with money
#
# ager (arthashaastra) = ecomonics
#
# aveq (arthasya) = (masc.poss.sing.) wealth or meaning
#
# aart (arthaarthii) = one who desires material gain
#
# afte (arthiyaM) = meant
#
# at (arthe) = in meaning
#
# autastara (arthopaarjanaaya) = for earning maney
#
# ad (ardha) = half
#
# araret (ardhagola) = semicircle, dome
#
# TET (ardhachandraasana) = the half-moon posture
# advarat (ardhanavaasana) = the half-boat posture
# adarteat (ardhanaariinaTeshvara) = Shiva and his Shakti united as one
# adarerat (ardhanaariishvara) = Shiva and his Shakti united as one
# adfaiat: (ardhanicholaH) = (m) frock
#
# aaqartt (ardhapadmaasana) = the half-lotus posture
#
# TEC RTT (ardhamatsyendraasana) = the half spinal-twist posture
# ardfarstert (ardhashirshhaasana) = the half headstand posture
#
# 18
#
# ardeatgrry (ardhasarvaa.ngaasana) = the half-shoulderstand posture
# ade (ardhasalabhaasana) = the half-locust posture
# TIER (ardhoruka) = (n) half-pant
#
# reeaL (ardhorukam.h) = (n) half-pant , shorts
#
# ava (arpaNa) = Offer
#
# aya (arpaNaM) = contribution
#
# atte (arpita) = surrendering
#
# arte (arbhaka) = small
#
# aaat (aryamaa) = Aryama
#
# ry (arha) = deserving
#
# weat (arhataa) = (f) qualification
#
# orate (arhati) = (1 pp) to deserve
#
# aefe (arhasi) = deserve
#
# wet (alaM) = especially
#
# aerate (ala.nkaaradiiptaM) = shining with adornments, decorations
# aaTgeT (alankRita) = decorated / ornamented
#
# aren frat (alabdhabhuumikatva) = the feeling that it is impossible to see reality
# ama (alabhya) = Difficult
#
# aera: (alasaH) = lazy
#
# aeateq (alasya) = indolence
#
# aaqaartT (alakShamaana) = one who disregards
#
# orertert: (alakShmiH) = poverty (alaxmiH is opp. of laxmiH)
# arte (aliika) = (adj) false, untrue
#
# aed (aloluptvaM) = freedom from greed
#
# aeq (alpa) = small, little
#
# art (alpaM) = a few, little, inadequate
#
# aera (alpadhii) = mental deficiency
#
# aeigga: (alpabuddhayaH) = the less intelligent
#
# aeqTraat (alpamedhasaaM) = of those of small intelligence
# aeiqaen (alpavayaskaM) = young (small) age
#
# aewgq (alpaayu) = Short life between 8 and 32 years
#
# aq (ava) = prrotect
#
# aaafter (avakarikaa) = (f) dustbin, garbage bin
#
# awaqntt (avakalana) = differentiation
#
# ANTS (avagachchha) = must know
#
# away (avagam.h) = to comprehend, understand
#
# ward (avagamaM) = understood
#
# aque (avagraha) = (m) famine
#
# waaay (avachaya) = (m) gathering, collection
#
# aafaatfe (avachinoti) = to pluck
#
# aaa: (avachyaH) = unblamable
#
# aaa (avajaananti) = deride
#
# aqate (avataara) = a divine incarnation particularly of Vishnu, e.g. Buddha
#
# 19
#
# waareate (avataarayati) = to keep down, to get down
# aaft (avati) = (1 pp) to protect
#
# awafasft (avatishhThati) = remains
#
# aafasy (avatishhThate) = becomes established
#
# awaqq (avatu) = (may the lord) protect
#
# aaa (avadhiiraNaa) = (f) a repulse, repulsion
# waeq: (avadhyaH) = cannot be killed
#
# aaT (avana) = protection
#
# waft (avaniM) = earth
#
# aafraret (avanipaala) = of warrior kings
#
# watttat (avaniitanya) = the daughter of the Earth (siita)
# wqaq (avayava) = part
#
# wat (avaraM) = abominable
#
# TeENT (avaruddhavega) = retardation
#
# aarentg (avaruuNaddhi) = to obstruct
#
# aanctafer (avarohati) = to descend
#
# aafaet (avalipta) = proud, haughty
#
# waae: (avalehaH) = (m) pickle
#
# wag: (avashaH) = helplessly
#
# waft (avashishhyate) = remains
#
# wags (avashoshhaNa) = absorption
#
# Bqez (avashhTabhya) = entering into
#
# wae (avasaM) = automatically
#
# aqeq{ (avasan.h) = III pl. imperfect of vas, to live
# waaay: (avasannaaH) = inadequate
#
# awqat: (avasaraH) = (m) opportunity, chance
# aaetft (avasarpati) = to slide (as from a waterslide)
# Wray (avasaadayet.h) = put into degradation
# aqTeaT (avasthaa) = a state of the mind
#
# are (avasthaatuM) = to stay
#
# wqeay: (avasthaatrayaH) = three states of bodily consciousness (awake, sleep, dream)
# wafer? (avasthitaM) = situated
#
# aaferd: (avasthitaH) = situated
#
# waferat: (avasthitaaH) = situated
#
# aaferar (avasthitaan.h) = arrayed on the battlefield
# aaqeratt (avahaasaarthaM) = for joking
#
# await (avaG Yaa) = contempt
#
# wast (avaGYaataM) = without proper attention
# award? (avaachii) = (f) south
#
# wart (avaachya) = unkind
#
# waTatet ~(avaaptavyaM) = to be gained
#
# wate (avaaptuM) = to achieve
#
# aaTaift (avaapnoti) = gets
#
# 20
#
# wate (avaapya) = achieving
#
# aaa (avaapyate) = is achieved
#
# waTeay (avaapsyatha) = you will achieve
#
# aareafe (avaapsyasi) = will gain
#
# afaaerr (avikalpena) = without division
#
# afaart: (avikaaryaH) = unchangeable
#
# afaart (avichaarii) = adj. thoughtless
#
# afafer (avidita) = without knowledge, unknowingly
# atager: (avidushaH) = of one who does not know
#
# afar (avidyaa) = metaphysical ignorance
#
# afagie: (avidvaa.nsaH) = the ignorant
#
# atfahrqgaa (avidhipuurvakaM) = in a wrong way
#
# afaqgaet (avinashyantaM) = not destroyed
#
# afeatsr (avinaasha) = undestructible, name of Vishnu
# afaafa (avinaashi) = imperishable
#
# atfeatfart (avinaashinaM) = indestructible
#
# afacfset: (avipashchitaH) = men with a poor fund of knowledge
# afar (avibhaktaM) = without division
#
# afacfe (avirati) = sensuality
#
# afar (avirodha) = no opposition
#
# afaxat (aviGYeyaM) = unknowable
#
# aaa (avekShe) = let me see
#
# aaer (avekShya) = considering
#
# aq (avaidha) = (adj) illegal
#
# aaa += (avottaraattaat.h) = protect me from the northern direction
# aeaqeq (avyakta) = nonmanifested
#
# were? (avyaktaM) = nonmanifested
#
# wea: (avyaktaH) = invisible
#
# aeaeagidat (avyaktamuurtinaa) = by the unmanifested form
# weqrat (avyaktaa) = toward the unmanifested
#
# sere, (avyaktaat.h) = to the unmanifest
#
# wearearar hy (avyaktaadiini) = in the beginning unmanifested
# aeahrarrir (avyabhichaariNii) = without any break
# aeahratha4r (avyabhichaariNyaa) = without any break
# aeahrarw (avyabhichaareNa) = without fail
#
# aeqy (avyaya) = without deterioration
#
# wed (avyayaM) = immutable
#
# aweqay: (avyayaH) = inexhaustible
#
# aeqaat: (avyayavargaH) = the class of indeclinable words
# weqaeq (avyayasya) = of the imperishable
#
# aeqaria (avyayiibhaava) = indeclinable affixes
# aerqatfaat (avyavasaayinaaM) = of those who are not in KRishhNa consciousness
# aeaThaT (avyaakRitaa) = not expressed
#
# 21
#
# weaved: (avyaahataaGYaH) = avyAhata+agyaH, not feeling the hit?
# aa (ash.h) = to obtain, accomplish
#
# aie (asha.nka) = undaunted
#
# art (ashakta) = weak
#
# amet: (ashaktaH) = unable
#
# aa (ashana) = food
#
# aay: (ashamaH) = uncontrollable
#
# agate (ashayaat.h) = from their source
#
# amaeq (ashastraM) = without being fully equipped
# aM-TteT (ashaantasya) = of the unpeaceful
#
# aurad (ashaashvataM) = temporary
#
# aatet (ashaastra) = not in the scriptures
#
# afesq (ashishhya) = unteachable (adj)
#
# afarsarr (ashishhyaaya) = non-disciple i.e.non-believer
# agft (ashuchi) = to the unclean
#
# agfe: (ashuchiH) = unclean
#
# agqat (ashuchau) = unclean
#
# agpt (ashubha) = and inauspicious
#
# aypt (ashubhaM) = evil
#
# agqeTq (ashubhaat.h) = from ill fortune
#
# ag_er{ (ashubhaan.h) = inauspicious
#
# ATTTT (ashushruushhave) = to one who is not engaged in devotional service
# art (asheshha) = total
#
# agrvd: (asheshhataH) = completely
#
# agraftr (asheshhaaNi) = all
#
# aay (asheshheNa) = in detail
#
# agrart (ashochyaan.h) = not worthy of lamentation
# BIT: (ashoshhyaH) = not able to be dried
#
# agqqt: (ashnataH) = of one who eats
#
# ayqtq (ashnan.h) = eating
#
# asafat (ashnanti) = enjoy
#
# asatft (ashnaami) = accept
#
# awatft (ashnaasi) = you eat
#
# agqd (ashnute) = achieves
#
# agq (ashma) = stone
#
# ag (ashman.h) = (masc) stone
#
# @eEITT: (ashraddadhaanaH) = without faith in revealed scriptures
# @aEeTAT: (ashraddadhaanaaH) = those who are faithless
# aga (ashraddhayaa) = without faith
#
# sry (ashru) = (n) tears
#
# arygaige (ashruupuurNaakula) = full of tears
#
# wert (ashraushhaM) = have heard
#
# ayeareeq (ashlaaghya) = adj. virtueless
#
# 22
#
# aq (ashva) = a horse
#
# wact (ashvatthaM) = a banyan tree
#
# war: (ashvatthaH) = the banyan tree
#
# SaIATAT (ashvatthaamaa) = Asvatthama
#
# rary (ashvamedha) = a form of sacrifice where a horse is sent around to estiblish supremacy
# aaTat (ashvaanaaM) = among horses
#
# arate (ashvini) = a mudraa, contraction of the anal sphincter muscles
# afait (ashvinau) = the two Asvinis
#
# ae (ashhTa) = eight
#
# aeettatast (ashhTadalakamalabandha) = eight-petalled lotus pattern, a form of bandha
# poetry
#
# @eeT (ashhTadhaa) = eightfold
#
# weTeg (ashhTaadasha) = eighteen
#
# aetah (ashhTaavakra) = name of a deformed(at eight places) sage
# aerattest (ashhTottariidashaa) = A lunar based Dasha system uses 108 yr cycle and one
# chooses it according to certain criteria
#
# ast (ashhTau) = eight
#
# asaHat (ashhtakavarga) = A predictive method of Astrology that uses a system of points based
# upon planetary positions
#
# weed (asa.nnyasta) = without giving up
#
# weaaT (asa.nyataa) = unbridled
#
# Hews (asanshayaM) = undoubtedly
#
# wey: (asa.nshayaH) = beyond a doubt
#
# ward (asakta) = unattached
#
# weed (asaktaM) = without attraction
#
# werd: (asaktaH) = without attachment
#
# aerate: (asaktabuddhiH) = having unattached intelligence
# aera (asaktaatmaa) = one who is not attached
#
# arated: (asaktiH) = being without attachment
#
# wags: (asa.nkhyaH) = (m) countless
#
# AMT (asa.ngashastreNa) = by the weapon of detachment
#
# wad (asat.h) = matter
#
# wad: (asataH) = of the nonexistent
#
# wacHt (asatkRitaM) = without respect
#
# wach: (asatkRitaH) = dishonoured
#
# aaead (asatyaM) = unreal
#
# aaevT (asadRishhii) = unfit
#
# aeqiet (asapatnaM) = without rival
#
# aaaqyt: (asamarthaH) = unable
#
# awearaitd + (asampraGYaata) = unconscious samadhi
#
# Hays: (asammuuDhaH) = undeluded
#
# aeqAyet: (asammuuDhaaH) = unbewildered
#
# SAAS: (asammohaH) = freedom from doubt
#
# 23
#
# aay (asaaraM) = worthless/without essence
# araTatfect: (asaavaadityaH) = asau and AdityaH: this(person) and Sun
# aft (asi) = you are
#
# afad: (asitaH) = Asita
#
# afacar: (asid.hdhyoH) = and failure
#
# afeet (asiddhau) = failure
#
# aged (asukhaM) = full of miseries
#
# age (asura) = devil
#
# Bw (asuraaNaaM) = of demons
#
# aq (asuraan.h) = demons
#
# aq (asuu) = to hate, be jealous
#
# SIT (asuun.h) = life
#
# aqat (asuuyaa) = (f) envy
#
# wat (asRij) = (neut) blood
#
# weert (asRishhTaannaM) = without distribution of prasaadam
# aat (asau) = him (from adas.h)
#
# aaieq (asaumya) = (adj) unpleasant
#
# wet (asta) = fall (set)
#
# wed (astaM) = destroyed , vanquished
# eae (astamavelaa) = (fem) evening twilight
# afer (asti) = (2 pp) is
#
# weq (astu) = there should be
#
# aweqa (asteya) = non-stealing
#
# aweq (astra) = Weapon
#
# afer (asthi) = Bone
#
# afer (asthipaJNjaram.h) = (n) skeleton
# afer (asthiraM) = unsteady
#
# aeqsa (asparshana) = not touching
#
# AeA (asmad.h) = I, me
#
# eT: (asmadiiyaiH) = our
#
# weqTe (asmaakaM) = us
#
# aeAT] (asmaat.h) = these
#
# SeATT (asmaan.h) = us
#
# aeathr: (asmaabhiH) = by us
#
# afer (asmi) = I am
#
# aferar (asmitaa) = egotism, self righteousness
# afer{ (asmin.h) = in this
#
# afar (asmindvaye) = in this pair
#
# aeq (asya) = of it
#
# aeater (asyati) = (4 pp) to throw
#
# wea (asyaaM) = in this
#
# aeqra (asvargyaM) = which does not lead to higher planets
# weedy (asvasthataa) = illness
#
# 24
#
# a@ (aha) = said
#
# we (ahaM) = ii
#
# ae: (ahaH) = of daytime
#
# Beget (aha.nkara) = tendency to identify oneself with external phenomena, ’the I-maker’
# wegit (aha.nkaara) = Egoism, selfishness, ignorance
# wag (aha.nkaaraM) = false ego
#
# Begr: (aha.nkaaraH) = false ego
#
# wages (aha.nkaaravimuuDha) = bewildered by false ego
# weg (aha.nkaaraat.h) = by false ego
#
# Begd: (aha.nkRitaH) = of false ego
#
# weet (ahatvaa) = not killing
#
# Tey (aharaagame) = at the beginning of the day
# aefist (aharnishaM) = ahaH and nishaa:day and night
# af (ahi) = on earth
#
# afgaa (ahi-nsaka) = non-violent
#
# afar (ahi.nsaa) = non-violence
#
# ater (ahita) = sorrow (antonym of hita)
#
# afgat: (ahitaaH) = enemies
#
# atagfts#: (ahituNDikaH) = (m) a snake charmer
# CEG (ahaitukaM) = without cause
#
# wet (aho) = Oh!
#
# aera (ahoraatra) = day and night
#
# awa (akShama) = (adj) incapable
#
# wea (akShayaM) = unlimited
#
# aaa: (akShayaH) = eternal
#
# wat (akShara) = Letter
#
# wat (akSharaM) = indestructible
#
# wat: (akSharaH) = infallible
#
# warm + (akSharaaNaaM) = of letters
#
# warty (akSharaat.h) = beyond the infallible
#
# afer (akShi) = (n) eye
#
# aq (aGYa) = the ignorant person
#
# at: (aGYaH) = a fool who has no knowledge in standard scriptures
# awa (aGYataa) = ignorance
#
# aatt (aGYaana) = ignorance
#
# aaitt (aGYaanaM) = nescience
#
# warts + (aGYaanajaM) = due to ignorance
#
# BatteaTt (aGYaanasambhuutaM) = born of ignorance
# watt (aGYaanaaM) = of the foolish
#
# aaT (aGYaanena) = by ignorance
#
# aT (aa) = from
#
# ataat (aa+ghraa) = to smell
#
# aaqay (aat+char.h) = to practice
#
# 25
#
# aTaqat_ (aa+yaa) = to come
#
# aaeg (aa+ruh.h) = to climb
#
# atzat (aaudau) = in the beginning
#
# arate (aa.ndolana) = movement
#
# atfare (aa.nshika) = partial
#
# at: (aaH) = to sit
#
# arett (aakarNa) = towards the ear
#
# aTetrtq¢rat (aakarNadhanuraasana) = the shooting bow posture
# ajay (aakarshha) = attracted
#
# aTatt (aakarshhaNa) = attraction
#
# aratat (aakaa.nkShaa) = wish, ambition
#
# arate (aakaara) = (masc) form, shape
#
# aTartart (aakaaramaana) = volume
#
# ararftat (aakaarikaa) = (f) doorbell
#
# aTeTar (aakaasha) = ether
#
# aratat (aakaashaM) = the sky
#
# arTaTaarit + (aakaashavaaNii) = (f) radio
#
# aTaraferd: (aakaashasthitaH) = situated in the sky
# STeIATeq_ (aakaashaat.h) = (abl.S)from space or sky
#
# ager (aakula) = full of
#
# argefary (aakulitam.h) = sad, worried
#
# aTedif (aakRitiini) = forms
#
# ape (aakRishhTa) = (past part. of aa + kRishh) attracted
# array (aakram.h) = to attack
#
# araqy (aakramaNa) = attacks
#
# aay: (aakShepaH) = (m) insinuation, opposition
# arg (aakhu) = mouse
#
# areq (aakhya) = named
#
# areat (aakhyaa) = (f) name
#
# arated (aakhyaataM) = described
#
# areatfe (aakhyaahi) = please explain
#
# AST (aagachchhet.h) = one should come
# amit: (aagataH) = having attained
#
# antaT: (aagataaH) = attained
#
# amTq (aagama) = arrival
#
# anTat (aagamana) = coming
#
# amr (aagame) = on the arrival
#
# arg (aa.ngla) = English
#
# ATT (aa.nglabhaashhaa) = English language
# arat. (aachar.h) = to behave, interact
#
# arated: (aacharataH) = acting
#
# aratft (aacharati) = he does
#
# arar_ (aacharaan.h) = performing
#
# 26
#
# arate: (aachaaraH) = behavior
#
# arava (aachaarya) = a religious teacher
#
# arata(:) (aachaarya(H)) = (Masc.nom.$)teacher; preceptor
# aratg (aachaaryaM) = the teacher
#
# aratat: (aachaaryaaH) = teachers
#
# aratar{: (aachaaryaan.h) = teachers
#
# araratareast (aachaaryopaasanaM) = approaching a bona fide spiritual master
# BTeSleHAL (aachchhaadakam.h) = (n) covering sheet, chaddar
# anaes (aajaanubaahuM) = the one whose arms extend upto his knees
# arse (aajyaM) = melted butter
#
# ater: (aaDhyaH) = wealthy
#
# aft: (aaNiH) = nail
#
# arg (aatanka) = horror , terror
#
# aerate: (aatataayinaH) = aggressors
#
# aTat (aatapa) = heat
#
# alaqat (aatapatraM) = sunshade
#
# ara gars: (aata NkvaadaH) = (m) terrorism
#
# atfas (aatishhTha) = be situated
#
# age (aatura) = anxious
#
# ard (aatta) = ready
#
# aTet (aattha) = have spoken
#
# act (aatma) = of the self
#
# area (aatmakaM) = consisting of
#
# aicH#: (aatmakaH) = possessing or controlling
# AHA + (aatmakaaraNaat.h) = for sense enjoyment
# aia (aatmaja) = son
#
# aes: (aatmajaH) = son
#
# aTcait (aatmajaa) = daughter
#
# aa: (aatmatRiptaH) = self-illuminated
#
# acy (aatman.h) = Soul
#
# aieqt (aatmana) = (Masc.instr.sing.) thro’ the self
# aictt: (aatmanaH) = of the person
#
# SIcHaT (aatmanaa) = by the purified mind
#
# areaft (aatmani) = in himself
#
# aTesquTe (aatmabhaava) = within their hearts
# ATHYATHT + (aatmabhuutaatmaa) = compassionate
# SIcHaTaaT (aatmamaayayaa) = by My internal energy
# ATTANITL (aatmayogaat.h) = by My internal potency
# areaxft: (aatmaratiH) = taking pleasure in the self
# aia (aatmavantaM) = situated in the self
# arenasy: (aatmavashyaiH) = under one’s control
# aictaty{ (aatmavaan.h) = established in the self
#
# arenfafare: (aatmavinigrahaH) = self-control
#
# 27
#
# arenfeanraa: (aatmavibhuutayaH) = personal opulences
# areafeare: (aatmavishvaasaH) = (m) confidence
# aicesqaaey (aatmasa.nyama) = of controlling the mind
# areraegte: (aatmasa.nstutiH) = and praise of himself
# areaded (aatmasa.nsthaM) = placed in transcendence
# arctate, (aatmasaat.h) = to imbibe, to make one’s own, to train oneself
# acHeeaT (aatmahatyaa) = suicide
#
# STs (aatmaGYaana) = knowledge of self
#
# aTcHT (aatmaa) = soul
#
# aTeaTs aca (aatmaa.atattvamasi) = Thou art That Not (self + Self are differnt:Duality)
# arc? + (aatmaanaM) = the mind
#
# area (aatmaani) = in the pure state of the soul
# arearaeifaar: (aatmaasambhavitaaH) = self-complacent
# arferrat (aatmiyataa) = the feeling of oneness
#
# arete (aatmaiva) = the very mind
#
# areata (aatyantikaM) = supreme
#
# aTad (aadatte) = accepts
#
# wert (aadaana) = taking
#
# atte (aadi) = beginning
#
# arte (aadiM) = the origin
#
# atfe: (aadiH) = the origin
#
# atfenst (aadikartre) = to the supreme creator
#
# atfee®y (aadikeshhu) = etc etc
#
# arfeer (aaditya) = a name of Sun, Vishnu is among twelve Aditya-s
# atfact: (aadityaH) = the Adityas
#
# atfecnte (aadityagataM) = in the sunshine
#
# atfacraq (aadityavat.h) = like the rising sun
#
# atfacratt (aadityavarNaM) = luminous like the sun
# atfacart (aadityaan.h) = the twelve sons of Aditi
# atfacarat (aadityaanaaM) = of the Adityas
#
# atfaeq (aadidevaM) = the original Lord
#
# atteeq: (aadidevaH) = the original Supreme God
# atfaft: (aadibhiH) = by those
#
# atfex (aadishhTa) = ordered
#
# atfeear{ (aadishhTavaan.h) = (he was)commanded
# aerate (aadiishvara) = the primeval lord, a name of Shiva
# ated: (aadRitaH) = having begun
#
# aqat (aadau) = First
#
# ate (aadya) = earliest
#
# wate (aadyaM) = original
#
# ave! (aadye) = (Masc.loc.sing.) the first
#
# araceq (aadhatsva) = fix
#
# areata (aadhaaya) = resigning
#
# 28
#
# arate: (aadhaaraH) = support or base
#
# aha (aadhika) = addition, plus
#
# athtet (aadhikya) = surplus
#
# aThrqer (aadhipatya) = overlordship
#
# aThraet (aadhipatyaM) = supremacy
#
# arearfara (aadhyaatmikaM) = super-natural, spiritual
# alt (aanana) = Face
#
# arat (aananaM) = face
#
# alt-z (aananda) = happiness
#
# @lt-eT (aanandana) = happiness
#
# artreAeT: (aanandamayaH) = full of great happiness
# aaa (aantaradeshiiya) = within the country mainly for transaction??
# arate (aantarjaalaM) = (n) internet
#
# arq (aap.h) = to obtain
#
# aq: (aapaH) = water
#
# arqy: (aapaNaH) = (m) shop
#
# arate: (aapaNikaH) = (m) shop-keeper
#
# arqe (aapad.h) = calamity
#
# arqat (aapadaaM) = dangers
#
# arte (aapannaM) = achieved
#
# aTqTaT: +(aapannaaH) = gaining
#
# arqe (aapah) = water
#
# aTgaart (aapuryamaaNaM) = always being filled
#
# aye (aapuurya) = covering
#
# SIT=s (aapRichchha) = take leave of
#
# araifeat (aapoklima) = The 3rd, 6th, 9th and 12th Houses
# are (aaptuM) = afflicts one with
#
# areqat (aapnuyaaM) = may have
#
# areqaft (aapnuvanti) = attain
#
# areife (aapnoti) = achieves
#
# aware? (aapravaasii) = (m) immigrant
#
# areqaT (aaplutaa) = immersed
#
# warez (aabda) = year
#
# ateqaAett (aabdaphala) = yearly prognostication, also varshhaphala
# aTatenyaate, (aabrahmabhuvanaat.h) = up to the Brahmaloka planet
# amt = (aabharaNaM) = ornaments
#
# arm, (aabharaNam.h) = (n) ornaments, jewellery
#
# amt (aabhaa) = colour
#
# aria (aabhaasaM) = the original source
#
# aTaaqen (aamanaska) = the mind free from desire
#
# aTqq (aamaya) = disease
#
# arate (aamraphalam.h) = (n) mango (the king of fruits)
# are (aamla) = sour
#
# 29
#
# ate (aamlaM) = (n) acid
#
# aad (aayatam.h) = (n) rectangle
#
# alaaia (aayanaa.nsha) = Precession of Equinoxes. Used to convert Tropical positions to
# Sidereal
#
# arate: (aayaataH) = (m) import
#
# arattt (aayaatana) = abode, resting place
#
# aq: (aayuH) = [long] life
#
# arqd (aayudhaM) = weapons
#
# area (aayudhaanaaM) = of all weapons
#
# argattse (aayushhkaaraka) = Significator of Longevity which is Saturn
# arTant: (aayogaH) = (m) commision
#
# arear (aaratii) = crying out of desperation for help, ritual
# areeyqe_ (aarabdhat.h) = started
#
# arxesqq (aarabdham.h) = started
#
# arery (aarabhate) = begins
#
# ...
#
# enraft (sthagayati) = to stop someone
#
# eared: (sthambitaH) = (gerund) startled/overwhelmed
# eae (sthalaa) = (f) tiles (on the floor)
#
# eat (sthaa) = to stand
#
# er(fasfe) (sthaa(tishhThati)) = to stand
#
# eaTy: (sthaaNuH) = unchangeable
#
# wart (sthaana) = place, house, position
#
# eat (sthaanaM) = place
#
# earqe = (sthaanaka) = (m) station, base
#
# 211
#
# eaTquge (sthaanabhrashTa) = adj. skidrow bum
# STATA + (sthaanaantaraNa) = transfer
#
# eft (sthaani) = situated
#
# err (sthaane) = rightly
#
# eaTqa (sthaapaya) = please keep
#
# errqafe (sthaapayati) = to put, to keep
#
# errqfacar (sthaapayitvaa) = placing
#
# eafaat (sthaalikaa) = (f) plate, dish
#
# eaTat (sthaavara) = not moving
#
# eae = (sthaavaraaNaaM) = of immovable things
# erreafa (sthaasyati) = remains
#
# fert (sthitaM) = situated
#
# fert: (sthitaH) = situated
#
# ferrit: (sthitadhiiH) = one fixed in KRishhNa consciousness
# ferawat: (sthitapraGYaH) = transcendentally situated
# feramaret (sthitapraGYasya) = of one who is situated in fixed KRishhNa consciousness
# ferat: (sthitaaH) = are situated
#
# ferart (sthitaan.h) = standing
#
# ferft (sthiti) = position
#
# ferft (sthitiM) = situation
#
# ferft: (sthitiH) = situation
#
# ferdt (sthitii) = existing
#
# ferdt (sthitau) = situated
#
# fercat (sthitvaa) = being situated
#
# ferc (sthira) = fixed
#
# fercerfar (sthiraraashi) = Fixed Signs
#
# fert (sthiraM) = firm
#
# fert: (sthiraH) = still
#
# ferxat (sthirataa) = steadiness
#
# fercafe: (sthirabuddhiH) = self-intelligent
#
# fert (sthiraaM) = stable
#
# fert: (sthiraaH) = enduring
#
# fertg: (sthiraa NkaH) = (m) constant number/variable
# feat: (sthiraiH) = with firm or strong (limbs)
#
# eye (sthuula) = (adj) strong, big
#
# eye: (sthuulaH) = (adj) fat
#
# SAAT (sthuulamaatraa) = macro
#
# STMT (sthuulashariira) = (bahuvriihi) big-bodied
# eqeenfest (sthuulasphaTikii) = macrocrystaline
# at (sthairyaM) = steadfastness
#
# Sidarat (snaatakottara) = post graduate
#
# eaft (snaati) = to bathe
#
# GT (snaana) = bath, ablution
#
# 212
#
# Sst (snaanashiila) = (metaphorically) pure
# eTTye (snaanagRiham.h) = (n) bathroom
#
# wiTq (snaayu) = sinew
#
# errata (snaayuvitananaM) = sprain
#
# ferret (snigdha) = affectionate; also oily,greasy
# feqrar: (snigdhaaH) = fatty
#
# ew (snushhaa) = (f) daughter-in-law
#
# Ste (sneha) = love
#
# Gig: (snehaH) = friendship (oil)
#
# @lalq (snehaat.h) = (Masc.absol.sing.) from affection
# @iet (snehena) = (Masc.instr.sing.) through affection
# era (spandate) = (1 ap) to throb
#
# eqs (sparshanaM) = touch
#
# eqat{ (sparshaan.h) = sense objects, such as sound
# eq= (spashhTa) = Longitude of planet or house (bhaava)
# eqIaT (spRish) = to touch
#
# eqaft (spRishati) = (6 pp) to touch
#
# IM (spRishan.h) = touching
#
# eq (spRishhTaM) = (past participle) touched
#
# Jat (spRihaa) = aspiration
#
# feraftrret (sprihaNiyaruupaM) = desirable form (personal appearance)
# Saree (sphiita) = (adj) prosperous
#
# egfed (sphuTita) = overt
#
# earfa (sphurati) = (6 pp) to throb
#
# egita (sphurita) = shining
#
# SRTaH: (sphotakaH) = (m) bomb, explosive
#
# =] (sma) = an indeclinable that changes the sentence to past tense from present tense
# eae (smayate) = (1 ap) to smile
#
# ert (smarati) = (1 pp) to remember, recollect
# eAt{ (smaran.h) = thinking of
#
# arf (smaraami) = remember
#
# RT (smaret.h) = remembers, recalls
#
# e=ara-T (smaashana) = graveyard
#
# eT (smRita) = remembered
#
# ead (smRitaM) = is considered
#
# eq: (smRitaH) = is considered
#
# =qfaT (smRitaa) = when remembered
#
# eater (smRiti) = of memory
#
# etft: (smRitiH) = memory
#
# eaferiaret (smRitibhra.nshaat.h) = after bewilderment of memory
# eid (smRitii) = memory
#
# wey (syandane) = chariot
#
# ware (syandin.h) = oozing
#
# 213
#
# wat (syaaM) = would be
#
# aq (syaat.h) = may be
#
# waTq_ (syaama) = will we become
#
# eq: (syuH) = form from “as.h” meaning “those who may be”
# aq (syutam.h) = (n) a bag
#
# a@iqat (srotasaaM) = of flowing rivers
#
# eq (sva) = Self
#
# ef (svaM) = own
#
# eq: (svaH) = the nether world(?)
#
# eae (svakaM) = His own
#
# eaet (svakarma) = in his own duty
#
# eras (svakarmaNaa) = by his own duties
#
# eaeta (svakiiya) = (asj) private
#
# eaqgy (svachakShushhaa) = your own eyes
#
# tas (svachchha) = pure
#
# eqeaer (svachchha.ndii) = adj. self-absorbed
#
# eat (svajanaM) = kinsmen
#
# watt (svata.ntra) = Free
#
# eqaarat (svatejasaa) = by Your radiance
#
# *qegq_ (svadesha) = one’s own country
#
# eaat (svadharmaM) = your religious duty
#
# eaat: (svadharmaH) = one’s prescribed duties
#
# eq (svadharme) = in one’s prescribed duties
#
# e@eT (svadhaa) = oblation
#
# eat (svana) = sound
#
# eaafeart (svanushhThitaat.h) = perfectly done
#
# eatfa (svapati) = (2pp) to sleep
#
# eat (svapan.h) = dreaming
#
# eaqvtT (svapna) = dream
#
# tact (svapnaM) = dreaming
#
# eaqct: (svapnaH) = dreaming
#
# Saar (svapnashiilasya) = of one who sleeps
# eqeagryeq (svapnaavabodhasya) = sleep and wakefulness
# wqaTTeT  (svapnaavasthaa) = the state of the mind in a dream
# eqeq (svapne) = in dream
#
# wate (svabhaava) = nature, personal mental attributes
# wag: (svabhaavaH) = characteristics
#
# eqtqst (svabhaavajaM) = born of his own nature
#
# eas (svabhaavajaa) = according to his mode of material nature
# erat (svabhaavajena) = born of your own nature
# eanraftad (svabhaavaniyataM) = prescribed according to one’s nature
# eanteafoorrara fir (svamatipariNaamaavadhi) = according to one’s intellectual capacity
# eat (svayaM) = herself
#
# 214
#
# eqararteree (svayaMprakaashita) = self-illumined like stars(Sun)
# eaqaT (svayaa) = by their own
#
# wat (svara) = sound
#
# wat (svarandharaa) = (f) harmonium
#
# eq7eq (svaruupa) = one’s true nature
#
# eaeq (svaruupaM) = form
#
# eat (svarga) = heaven
#
# eat (svargaM) = to heaven
#
# waft (svargatiM) = passage to heaven
#
# Saige: (svargaparaaH) = aiming to achieve heavenly planets
# eatcte (svargalokaM) = heaven
#
# Sater (svargaat.h) = (Masc.abl.S)heaven
#
# eat (svarge) = in heaven
#
# eater (svaliilayaa) = sva+JIlaya, through one’s play-like action
# eaeqT (svalpa) = little
#
# eaeq (svalpaM) = a little
#
# wartast (svalpatantraM) = (n) oligarchy
#
# eqeaet (svasa.nvedana) = the understanding of oneself
#
# wafer (svasti) = all peace
#
# eaferaret (svastikaasana) = the prosperous posture
# eaferreaTeat  (svastinastaarkShyo) = let tArkshya or Garuda do good to us
# wafeqat (svastirno) = good to us
#
# wqer: (svasthaH) = being situated in himself
#
# rer: (svasthaiH) = by healthy persons (ie , healthy in minds , their minds being well
# eqeqt: (svasyaH) = by his own
#
# weet: (svahastaH) = Signature
#
# waar (svakShetra) = Planet in its own sign
#
# eat (svaaM) = of Myself
#
# eantamar: (svaagatakaxaH) = (m) drawing room
#
# carter (svaati) = The fifteenth nakshatra. Can be spelt Svati
# tale (svaada) = (m) taste
#
# ealaq (svaadate) = (1 ap) to taste
#
# alg (svaadu) = sweet
#
# arate (svaadhiina) = dependent on the self
#
# wareqTa (svaadhyaaya) = self-study
#
# wareaqTa: (svaadhyaayaH) = study of Vedic literature
#
# SareqTaT-AT (svaadhyaayaanmaa) = sva + adhyAyAt.h + mA:fromone’s learning + don’t
# wavy ~(svaapa) = (m) sleep
#
# ear]? (svaami) = master
#
# eavat (svaamii) = the master
#
# earaet (svaayatta) = dependent only one onself
#
# wakIsa (svaaraajya) = ‘self-rule’, i.e., not being subordinate someone else
# art (svaartha) = one’s own ends
#
# 215
#
# earit (svaarthii) = adj. self-centered
#
# earacte (sviikaroti) = to accept
#
# at (svena) = by your own
#
# eat (svairatantraM) = (n) autocracy
#
# eat (svyaM) = of one’s own
#
# earretr (svraa.njalii) = Musical notes
#
# @ (ha) = the sun
#
# @a (ha.nsa) = (masc) swan, goose
#
# @q: (ha.nsaH) = (m) swan
#
# gave (ha.nsaasana) = the swan posture
#
# @e (haTa) = force, against one’s will
#
# geant (haTayoga) = union with the supreme via discipline
# ad (hataM) = killed
#
# ad: (hataH) = being killed
#
# Sa (hataan.h) = already killed
#
# aah (hataani) = (past.part.)having been killed
# @q: (hataiH) = having been killed
#
# aeaT (hatyaa) = (f) assassination
#
# acaT_: (hatvaa) = by killing
#
# aq (hanana) = killing
#
# aft (hanishhye) = I shall kill
#
# aqaary: (hanumatprabhuH) = the lord of Hanuman
# @qatt (hanumaana) = a monkey chief, son of Anjana and Vayu
# eqaratat (hanumaanaasana) = the splits
#
# @a (hanta) = O!, Alas!
#
# @art (hantaaraM) = the killer
#
# aft (hanti) = kills
#
# @d (hantuM) = to kill
#
# @aq (hantRi) = desirous of killing
#
# @aq (hanyate) = is killed
#
# @aAry (hanyamaane) = being killed
#
# eq: (hanyuH) = may kill
#
# @a (haya) = horse
#
# @a@: (hayaiH) = horses
#
# @t (har.h) = to steal
#
# @t (hara) = shankara
#
# at: (haraH) = shiva
#
# acft (harati) = (1pp) to take (away)
#
# act (haranti) = throw
#
# acta (harasi) = you remove
#
# aft (hari) = vishnu
#
# aft: (hariH) = the Supreme Personality of Godhead, KRishhNa
# aftr (hariNa) = deer
#
# 216
#
# aftr (harita) = green
#
# aftaq (haritam.h) = (n) cabbage
#
# aq: (hariiH) = VishNu
#
# at: (hareH) = of Lord KRishhNa
#
# aatsfer (hartaa.asi) = are the usurper
#
# ga (harmya) = building
#
# eat (harsha) = (masc) joy
#
# @Y (harshha) = from happiness
#
# @Y (harshhaM) = cheerfulness
#
# avarartac: (harshhashokaanvitaH) = subject to joy and sorrow
#
# aa (hala) = a plough
#
# aclat (halaasana) = the plough posture
#
# acted (halaahala) = poison
#
# aff: (haviH) = butter
#
# afast (havishhaa) = offerings
#
# aeaft (hasati) = (1pp) to laugh
#
# aeq (hasta) = hand
#
# aeqaet (hastaghaTii) = (f) wristwatch
# (hastapaada.ngushhThaasana) = the hand-to-big-toe posture
#
# ee (hastaat.h) = from the hand
#
# eeaattzy_ (hastaakSharam.h) = (n) handwriting
#
# afearft (hastini) = in the elephant
#
# aferqe: (hastipakaH) = (m) mahout, one who rides the elephant
#
# aecffurt (hastairbibhraaNaM) = bearing in the hands
#
# atfauit (haakiNii) = the goddess in aGYaa chakra
#
# atft (haani) = damage
#
# atft: (haaniH) = destruction
#
# ait (haara) = Garland
#
# aft (haariNii) = remover
#
# alee (haalaahala) = poison
#
# ara (haasa) = laughter
#
# amet (haasya) = the sentiment of humor
#
# fe (hi) = really
#
# feaft (hi-nsati) = kills
#
# féatT (hi.nsaa) = violence
#
# fgat (hinsaaM) = and distress to others
#
# feateqs: (hinsaatmakaH) = always envious
#
# fea (hita) = benefit
#
# fet (hitaM) = beneficial
#
# feqarerar (hitakaamyayaa) = for your benefit
#
# feet (hite) = in welfare work
#
# feat (hitaishhin.h) = one who wishes good
#
# faear (hitvaa) = having given up/abandoned
#
# 217
#
# feafer (hinasti) = degrade
#
# fear: (himaalayaH) = the Himalayan mountains
#
# farang (hiraNyakashyapu) = a demon king, killed by Vishnu
# fewwamt (hiraNyagarbha) = Effulgent, a name of Sun
#
# feat: (hiraNyagarbhaH) = the Golden Embryo of life and form
# ar (hiinau) = bereft, having lost
#
# gd (huta) = offerings (usually made to a fire)
#
# ad (hutaM) = offered
#
# eqqq (hutabhuk.h) = fire (one who eats offerings)
#
# garaa¢t (hutaashavaktraM) = fire coming out of Your mouth
# @ (bRi) = to steal
#
# gad (hRita) = deprived of
#
# edq (hRitat.h) = heart
#
# geet (hRitsthaM) = situated in the heart
#
# @@ (hRid.h) = heart (neut)
#
# gaa (hRidaya) = heart
#
# geaq (hRidayaM) = heart
#
# geaqet (hRidayasthaM) = heart-stationed
#
# gearft (hRidayaani) = hearts
#
# waar (hRidayii) = in my heart
#
# @eay (hRidayeshhu) = in the hearts of
#
# ate (hRidi) = in the heart
#
# ges (hRiddeshe) = in the location of the heart
#
# gal: (hRidyaaH) = pleasing to the heart
#
# afi: (hRishhitaH) = gladdened
#
# evra (hRishhiikesha) = O master of all senses
#
# ewest (hRishhiikeshaM) = unto Lord KRishhNa
#
# eirag: (hRishhiikeshaH) = Hrsikesa (KRishhNa, the Lord who directs the senses of the
# devotees)
#
# gecar (hRishhTaromaa) = with his bodily hairs standing on end due to his great ecstasy
# gute (hRishhyati) = takes pleasure
#
# e=arft (hRishhyaami) = I am enjoying
#
# aad: (hetavaH) = causes
#
# @q (hetu) = intention
#
# @q: (hetuH) = aim (Here: cause)
#
# aqat (hetunaa) = for the reason
#
# agate: (hetumadbhiH) = with cause and effect
#
# Bar: (hetoH) = in exchange
#
# @A1 (heman.h) = gold
#
# ~
#
# @4=t (hemanta) = (masc) winter
#
# amt (horaa) = A Varga. The Division of a sign into Solar and Lunar or Division into halves.
# Used for determining Wealth amongst other things
#
# @: (hyaH) = yesterday
#
# 218
#
# Beat (hrasvaa) = (adj) short
#
# fRae (hriyate) = is attracted
#
# Bt: (hriiH) = modesty
#
# aut (kShaNaM) = one second
#
# auaeT (kShaNaprabhaa) = (f) lightning
#
# amfeanr (kShaNaviyoga) = momentary separation
# arratfert (kShaNaviikshita) = glance
#
# afaq (kShatriya) = the caste of princes and warriors
# atraaret (kShatriyabalaM) = the power or might of the kshatriyas or kings
# afrarer (kShatriyasya) = of the ksatriya
#
# afvat: (kShatriyaaH) = the members of the royal order
# ate: (kShantiH) = tolerance
#
# aaat (kShamataa) = ability
#
# @atT (kShamaa) = forgivance
#
# ait (kShamii) = forgiving
#
# aq (kShaya) = loss, weakening, scaricity
#
# aa (kShayaM) = destruction
#
# aaeq (kShayakRit.h) = the destroyer
#
# aaft (kShayati) = (1 pp) to decay
#
# a#atq (kShayaat.h) = (from) consunption/destruction
# aaTa (kShayaaya) = for destruction
#
# a@t (kShara) = prone to end, destructible
#
# at (kSharaM) = to the fallible
#
# a@t: (kSharaH) = constantly changing
#
# ava (kShaatraM) = ofa ksatriya
#
# attr: (kShaantiH) = tolerance
#
# ava (kShaamaye) = ask forgiveness
#
# att (kShaara) = salty
#
# aveaft (kShaalayati) = (10 pp) to wash
#
# ferferatet (kShitipaala) = (m) protector of the earth, king
# fart (kShip) = (root) to throw
#
# fargf (kShipati) = (6 pp) to throw
#
# fara? (kShipaami) = I put
#
# farce (kShipta) = neglected or distracted
#
# fat (kShipraM) = soon
#
# ait (kShii) = to dimnish
#
# atraeqyt: (kShiiNakalmashhaaH) = who are devoid of all sins
# ator (kShiiNe) = spent-up/weakened state of
#
# ax (kShiira) = milk
#
# a (kShudra) = insignificant, small
#
# ag (kShudraM) = petty
#
# aa (kShudh) = hunger
#
# a@eat (kShudhaa) = hunger
#
# 219
#
# gett (kShudhaarta) = hungry
#
# geaft (kShudhyati) = (4 pp) to be hungry
#
# apate (kShubhyati) = (4 pp) to tremble
#
# @t (kShura) = (masc) knife
#
# achrar (kShurakriyaa) = (fem) shaving, cutting with a knife
# gcqay (kShurapatram.h) = (n) blade
#
# ay (kShuudra) = weak (here)
#
# aq (kShetra) = field
#
# aa (kShetraM) = the field
#
# aast (kShetraGYa) = and the knower of the body
#
# &asi (kShetraGYaM) = the knower of the field
#
# aast: (kShetraGYaH) = the knower of the field
#
# aawqar: (kShetraGYayoH) = and the knower of the field
#
# ear (kShetrii) = the soul
#
# aay (kShetreshhu) = in bodily fields
#
# acres: (kShepaNaastraH) = (m) missile
#
# aqit (kShepaNii) = (f) rocket
#
# at (kShemaM) = protection
#
# aaaqt (kShemataraM) = better
#
# araft (kShouti) = to sneeze
#
# art (kShobhaM) = disturbance
#
# 3 (GYa) = one who knows (suffix)
#
# srTa@ie<e =(GYanakaaraka) = Significator of knowledge which is Jupiter
# 3T (GYaa) = to know
#
# WTqat (GYaatachara) = (adj) known
#
# ataet ~(GYaatavyaM) = knowable
#
# aft (GYaati) = community (people of the same caste etc.)
#
# at (GYaatuM) = to know
#
# wT (GYaate) = in the realised state
#
# att (GYaatena) = by knowing
#
# yieat (GYaatvaa) = knowing well
#
# Wt (GYaana) = knowledge
#
# a1? (GYaanaM) = knowledge
#
# at: (GYaanaH) = whose knowledge
#
# arrest (GYaanagamyaM) = to be approached by knowledge
# 3Tq4ay: (GYaanachakShushhaH) = those who have the eyes of knowledge
# atest (GYaanachakShushhaa) = by the vision of knowledge
# araaitye + (GYaanadiipite) = because of the urge for self-realisation
# aTqwiaat (GYaanaplavena) = by the boat of transcendental knowledge
# aad ~(GYaanamana.ntaM) = Knowledge and Infinity or Absoluteness
# wraaq: (GYaanamayaH) = (Masc. Nom.Sing.)full of knowledge
# aaa (GYaanamayo) = full of Gyana or knowledge
#
# aaa: (GYaanayaGYaH) = sacrifice in knowledge
#
# 220
#
# aaqaat: (GYaanayaGYaaH) = sacrifice in advancement of transcendental knowledge
# aaa (GYaanayaGYena) = by cultivation of knowledge
# array (GYaanayogena) = by the linking process of knowledge
# aTaadat ~(GYaanavataaM) = of the wise
#
# aTtaT{_ (GYaanavaan.h) = learned
#
# aatate: (GYaanavihinaH) = (but)bereft of knowledge of the Self
# STAT SeayT: (GYaanashabdayoH) = of knowledge and sound
#
# Wreeq (GYaanasya) = of knowledge
#
# aaT: (GYaanaaH) = knowledge
#
# aati: (GYaanaagniH) = the fire of knowledge
#
# arte (GYaanaat.h) = than knowledge
#
# aatat (GYaanaanaaM) = of all knowledge
#
# aratafera (GYaanaavasthita) = situated in transcendence
#
# aft: (GYaaninaH) = of the knower
#
# afr: (GYaanibhyaH) = than the wise
#
# art (GYaanii) = one who is in knowledge
#
# aT (GYaane) = in knowledge
#
# att (GYaanena) = with knowledge
#
# wate (GYaanenaiva) = GYAnena + eva:thro’ knowledge alone
# aritet (GYaanendriya) = an organ of knowledge, i.e. the five senses
# wad (GYaayate) = known
#
# ara (GYaayase) = can to be known
#
# areaft (GYaasyasi) = you can know
#
# at (GYeyaM) = be known
#
# 3a: (GYeyaH) = should be known
#
# sath (GYeyosi) = You can be known
#
# 221
#
#
#
# Mapping DataFrame:
# Empty DataFrame
# Columns: [Unique Sanskrit Word, Transliteration, Meaning]
# Index: []

# %%
import fitz  # PyMuPDF
import re
import pandas as pd

# Open the PDF file
pdf_path = 'dictallcheck.pdf'
doc = fitz.open(pdf_path)

# Extract text from page 3 (index 2 for 0-based indexing)
page_text = doc[2].get_text("text")

# Initialize lists to store transliterations and meanings
transliterations = []
meanings = []

# Regular expression to match transliterations in parentheses and meanings after "="
pattern = re.compile(r'\(([^)]+)\)\s*=\s*(.+)')

# Process each line individually to maintain order
for line in page_text.splitlines():
    # Search for transliteration and meaning pairs in each line
    match = pattern.search(line)
    if match:
        transliteration = match.group(1).strip()  # Text within parentheses
        meaning = match.group(2).strip()          # Text after '=' sign
        # Append to lists if they are not page numbers or irrelevant data
        if not re.search(r'\bpage\b|\bPage\b|\d+', transliteration) and not re.search(r'\bpage\b|\bPage\b|\d+', meaning):
            transliterations.append(transliteration)
            meanings.append(meaning)

# Create a DataFrame and save to CSV
df = pd.DataFrame({'Transliteration': transliterations, 'Meaning': meanings})
df.to_csv('ordered_transliterations_meanings.csv', index=False)

# Display the extracted data
for transliteration, meaning in zip(transliterations, meanings):
    print(f"Transliteration: {transliteration}, Meaning: {meaning}")

# %%
import fitz  # PyMuPDF
import re
import pandas as pd

# Open the PDF file
pdf_path = 'dictallcheck.pdf'
doc = fitz.open(pdf_path)

# Check the number of pages in the PDF
print(f"Number of pages in PDF: {doc.page_count}")

# Extract text from page 3 (index 2 for 0-based indexing)
page_text = doc[2].get_text("text")

# Initialize lists to store transliterations and meanings
transliterations = []
meanings = []

# Regular expression to match transliterations in parentheses and meanings after "="
pattern = re.compile(r'\(([^)]+)\)\s*=\s*(.+)')

# Process each line individually to maintain order
for line in page_text.splitlines():
    # Search for transliteration and meaning pairs in each line
    match = pattern.search(line)
    if match:
        transliteration = match.group(1).strip()  # Text within parentheses
        meaning = match.group(2).strip()          # Text after '=' sign
        # Append to lists if they are not page numbers or irrelevant data
        if not re.search(r'\bpage\b|\bPage\b|\d+', transliteration) and not re.search(r'\bpage\b|\bPage\b|\d+', meaning):
            transliterations.append(transliteration)
            meanings.append(meaning)
            print(f"Found: Transliteration: {transliteration}, Meaning: {meaning}")  # Debug print

# Create a DataFrame and save to CSV
if transliterations and meanings:  # Check if lists are not empty
    df = pd.DataFrame({'Transliteration': transliterations, 'Meaning': meanings})
    df.to_csv('ordered_transliterations_meanings.csv', index=False)
    print("Data saved to 'ordered_transliterations_meanings.csv'")
else:
    print("No data extracted. Please check the PDF content and regex patterns.")

# Close the document
doc.close()
# Out:
# Number of pages in PDF: 221
# No data extracted. Please check the PDF content and regex patterns.

# %%
import fitz  # PyMuPDF
import re
import pandas as pd

# Open the PDF file
pdf_path = 'dictallcheck.pdf'
doc = fitz.open(pdf_path)

# Extract text from page 3 (index 2 for 0-based indexing)
page_text = doc[2].get_text("text")

# Print the extracted text for inspection
print("Extracted Text from Page 3:")
print(page_text)

# Initialize lists to store transliterations and meanings
transliterations = []
meanings = []

# Regular expression to match transliterations in parentheses and meanings after "="
# Modify this pattern based on the actual format of your text
pattern = re.compile(r'\(([^)]+)\)\s*=\s*(.+)')  # Original pattern

# Process each line individually
for line in page_text.splitlines():
    print(f"Line: {line}")  # Log each line
    match = pattern.search(line)  # Try to find matches
    if match:
        transliteration = match.group(1).strip()  # Text within parentheses
        meaning = match.group(2).strip()          # Text after '=' sign
        if not re.search(r'\bpage\b|\bPage\b|\d+', transliteration) and not re.search(r'\bpage\b|\bPage\b|\d+', meaning):
            transliterations.append(transliteration)
            meanings.append(meaning)
            print(f"Found: Transliteration: {transliteration}, Meaning: {meaning}")  # Debug print

# Create a DataFrame and save to CSV if data was found
if transliterations and meanings:
    df = pd.DataFrame({'Transliteration': transliterations, 'Meaning': meanings})
    df.to_csv('ordered_transliterations_meanings.csv', index=False)
    print("Data saved to 'ordered_transliterations_meanings.csv'")
else:
    print("No data extracted. Please check the PDF content and regex patterns.")

# Close the document
doc.close()
# Out:
# Extracted Text from Page 3:
#
#
#
# 	 !
# "$#&%('*),+.-0/213546
# 7
# tJ
# 
# 
#
#
# 0Q;=\)2^0Q47;FIMD
# K
# 2>67,94
# 798;:=<
# 
#  NMIMIM03I
# 
#
# .
# @9A
# H1jeD=D=IMa9D
# A
# 2^\
# >
# 
# I
# 
#
# ,92^.
# >@?
# 8
# ACB
# 
# I
# _
# ,7Ne67H
# @
# I
# 
#
# IbG>2>IM4
# 
# \
# A
# .<IMD}H1.1;F81N|67H
# A
# 4W.128`2>,/.O0Q2>D
# A
# D
# A
# U
# @
# IM,/.<H
# 
# >
# ?
# 8
# A
# BED,:GFG<(HIKJ
# 
# I
# _
# ,7Ne69H
# @
# IM4
# @
# IMIM03;
# v
# IM\
# _
# @c
#
# a
# A
# IY0Q;F,7G.
# @9A
# E
# A
# IYU~2^,ML
# IM,5Ne69H
# @
# I@NcE;[.
# @
# E
# @
# ;=8
# @
# .
# @7ACA
# D
# A
# U
# @
# IM,/.
# >
# ?
# O
# 
# I
# _
# ,9G^I
# 
#
# a}2e47jTlc2T0QG>IM,
# >
# ?
# O
# H
# 
# I
# _
# ,7G>I
# v
# I
# 
#
# q
# A
# D=4
# >
# ?
# OPQ?
# F
# ORTS
# 
# I
# _
# ,9G^IMH<I
# _
# ,7G>;=,9IM6
# 
#
# EJ;=.
# @
# >
# ?
# O
# UWV
# 
# I
# _
# ,7G>IM;
# k%
#
# DF;=\ba9Hlea}2545jrU9IY03.<H
# >
# ?
# O
# U,XKY
# A[Z
# A@\
# :
# ?
# P]XKY,R_^
# FG`
# V
# 
# I
# _
# ,9G^IM;FHO.<67H
# @9@7?
# 6
# X
# ITI
# _
# ,9H1ITHO.<IM,P6767a
# @
# ;
# k%
#
# @
# I
# X
# ;=,9GoH<IY.1;FH
# q
# A
# 4rE;=.
# @
# HO.10Q2^,9GoD=;F\%acHba
# >
# ?
# cER
# 
# I
# _
# ,1IT,7I
# 
# IM,72>;=,/.<\
# A
# ,/.
# >
# ?
# Y
# <
# ?
# O
# 
# I
# _
# ,/.1IY0QI
# _
# ,7G>I
# 
#
# ;F,7,
# A
# 0xa}2e47j2^0d;=,9,
# A
# 0x,9IY.1670
# A
# l
# B
# AA
# D=;F,7G>Hl5;=,9H1;F4
# A
# >@?
# Y,OedGY
# 
# I
# _
# ,/.1IY0QG>IY.1I
# 
#
# ;=,/.
# A
# 03,9IMD
# >@?
# f
# :
# 
# IMacIMI
# 
# \)2T.
# @7A
# 0
# >
# ?
# B
# 
# I
# _
# ,7H
# @
# I
# 
#
# U9IM0<.lIM,7G>D
# A
# >
# ?
# B`
# ^gYh?
# 
# I
# _
# ,9H
# @
# IYa
# @
# 6767.1IM
# 
#
# @
# ITHJa
# AA
# ,WIUcIY03.J2
# B@9A
# 0
# >
# ?
# B
# V
# 
# I
# _
# ,9H
# @
# I
# k%
#
# B
# 0QIMG>\
# A
# ,/.1IMD
# UcIY03.1;=8D
# A
# >
# ?
# B
# A
# I:
# R
# J
# 
# I
# _
# ,7H
# @
# 69\)IMIM,
# _@
#
# 03IT47;FIM,/.
# >
# ?
# B
# i
# R
# 
# I
# _
# ,7H
# @7A
# ,9I
# 
#
# UcIY03.
# >
# 8
# Y
# :
# d
# <
# ?
# 
# IMNMIY03.1IMIY0QIM
# 
#
# IMHJ.
# @7A
# ,72>,7492
# A
# 0
# >
# 8;I
# d
# 
# IYNMIY0Q\)I
# 
# ;=,9IM8:.<;=2>,
# >
# 8;I
# d
# 8
# j
# Y
# J
# 
# IYNMIY0Q\)IMN
# s
# ;[.
# _@
#
# E;[.
# @
# 2>65.J472>;=,9GH12>\
# A
# .
# @
# ;=,9G
# >
# 8;I
# d
# H
# V
# 
# IYNMIY0Q\)I
# v
# I
# k%
#
# .
# @
# IM,,92En2T03N
# >
# 8;I
# d
# FGH
# 
# IYNMIY0Q\)I
# v
# ;
# 
#
# ;=,W,92T.492^;F,7GU90
# A
# H<8:0Q;=a
# A
# 4|4967.1;
# A
# H
# >
# 8;klIm
# ?
# 
# IYNMIMDF\)IMH
# @7@
# IM
# 
#
# B
# 0
# AA
# 4
# B
# 0Q2>\
# IMD=D
# UcIMH1.JH<;=,
# B
# 67D}0
# A
# IT8:.1;F2^,9H
# >
# 8
# X
# I:
# Y
# J
# 
# IMNMIMH1\IMIY.
# _
# @c
#
# aPj|8
# @
# IM,98
# A
# >
# 8;:=<
# V
# 
# IYNMITIY0QI
# k%
#
# .
# @7A
# q
# 0QHO.D
# A
# .1.
# A
# 0
# >
# 8;:=<on
# 
# IYNMITIY0Q2
# 
#
# .
# @9A
# D
# A
# .O.
# A
# 0pL
# I@N
# >
# 8;:=q
# d
# 
# IYNMIMIY03j^I
# 
#
# IM,94
# B
# 2T03ac;=494
# A
# ,IM8`.1;
# X
# ;[.1;
# A
# H
# >
# 8;:=q
# d
# ?
# 
# IYNMIMIY03j^IT
# 
#
# E
# @
# IY.x2^69G
# @
# .J,92^.S.<2a
# A
# 472>,
# A
# >
# 8;:=q
# i
# d
# 
# IYNMIMIY03j
# AM
# IM,74WE
# @
# IY.x2>67G
# @
# .,72^.S.<2a
# A
# 492^,
# A
# >
# 8srtF
# Yud
# 
# IYNe;=;=0<.<;
# 
#
# ;F,
# B
# IM\bj
# >
# 8srtF
# Yud
# ?
# 
# IYNe;=;=0<.<;=
# 
#
# ;F,
# B
# IM\bj
# >
# 8srtF
# YudKV
# 
# IYNe;F;[03.1;
# k%
#
# ;=DFD
# B
# IM\
# A
# >
# 8
# A
# \
# dGY
# J
# 
# IYNe650
# X
# IY.
# _@
#
# 49;=4
# >
# 8
# A
# \
# dGY
# 
# IYNe650
# X
# IY.<I
# 
#
# 49;=4|.
# @7A
# jW472
# >
# 8
# A
# Bv
# ?
# 
# IMNe67H
# @
# ITD=IM
# 
# ;=,9IM67H1Uc;=8`;F2^69H
# >
# 8
# j
# Y
# f
# A
# FGw]x
# \
# :
# Y
# J
# 
# IYN
# s
# ;=.1IYac69474
# @
# ;=.
# X
# IMIM.
# _@
#
# 496
# A
# .12o69,7;F,/.
# A
# D=DF;=G
# A
# ,98
# A
# >
# 8
# j
# Y
# :=xgI:
# RWV
# 
# IYN
# s
# ;[.<IMIY.1\IMIM,9I
# k%
#
# .
# @
# 2>H
# A
# E;[.
# @
# 2>67.RH
# A
# D
# B
# fz0
# A
# IMD=;FH1IM.1;=2>,
# >
# 8
# j
# Y
# i
# R
# 
# IYN
# s
# ;[.
# A
# ,9I
# 
#
# E;[.
# @
# 2>67.R49;=H<8
# @
# IY0QG
# A
# 2
# B
# 4767.mj
# >
# 8
# x
# \
# :
# 
# IYN
# s
# ;[.
# X
# ITI
# 
#
# E;[.
# @
# 2>65.J492^;F,7G
# B
# 0Q2>\
# N
# s
# ;
# 
# y
#
# Line:
# Line:
# Line:
# Line:
# Line:
# Line:
# Line:
# Line:
# Line:
# Line:
# Line: 	 !
# Line: "$#&%('*),+.-0/213546
# Line: 7
# Line: tJ
# Line: 
# Line: 
# Line:
# Line:
# Line: 0Q;=\)2^0Q47;FIMD
# Line: K
# Line: 2>67,94
# Line: 798;:=<
# Line: 
# Line:  NMIMIM03I
# Line: 
# Line:
# Line: .
# Line: @9A
# Line: H1jeD=D=IMa9D
# Line: A
# Line: 2^\
# Line: >
# Line: 
# Line: I
# Line: 
# Line:
# Line: ,92^.
# Line: >@?
# Line: 8
# Line: ACB
# Line: 
# Line: I
# Line: _
# Line: ,7Ne67H
# Line: @
# Line: I
# Line: 
# Line:
# Line: IbG>2>IM4
# Line: 
# Line: \
# Line: A
# Line: .<IMD}H1.1;F81N|67H
# Line: A
# Line: 4W.12
# Line: 8`2>,/.O0Q2>D
# Line: A
# Line: D
# Line: A
# Line: U
# Line: @
# Line: IM,/.<H
# Line: 
# Line: >
# Line: ?
# Line: 8
# Line: A
# Line: BED,:GFG<(HIKJ
# Line: 
# Line: I
# Line: _
# Line: ,7Ne69H
# Line: @
# Line: IM4
# Line: @
# Line: IMIM03;
# Line: v
# Line: IM\
# Line: _
# Line: @c
# Line:
# Line: a
# Line: A
# Line: IY0Q;F,7G
# Line: .
# Line: @9A
# Line: E
# Line: A
# Line: IYU~2^,ML
# Line: IM,5Ne69H
# Line: @
# Line: I@NcE;[.
# Line: @
# Line: E
# Line: @
# Line: ;=8
# Line: @
# Line: .
# Line: @7ACA
# Line: D
# Line: A
# Line: U
# Line: @
# Line: IM,/.
# Line: >
# Line: ?
# Line: O
# Line: 
# Line: I
# Line: _
# Line: ,9G^I
# Line: 
# Line:
# Line: a}2e47jTlc2T0QG>IM,
# Line: >
# Line: ?
# Line: O
# Line: H
# Line: 
# Line: I
# Line: _
# Line: ,7G>I
# Line: v
# Line: I
# Line: 
# Line:
# Line: q
# Line: A
# Line: D=4
# Line: >
# Line: ?
# Line: OPQ?
# Line: F
# Line: O
# Line: RTS
# Line: 
# Line: I
# Line: _
# Line: ,9G^IMH<I
# Line: _
# Line: ,7G>;=,9IM6
# Line: 
# Line:
# Line: EJ;=.
# Line: @
# Line: >
# Line: ?
# Line: O
# Line: UWV
# Line: 
# Line: I
# Line: _
# Line: ,7G>IM;
# Line: k%
# Line:
# Line: DF;=\ba9Hlea}2545jrU9IY03.<H
# Line: >
# Line: ?
# Line: O
# Line: U,XKY
# Line: A[Z
# Line: A@\
# Line: :
# Line: ?
# Line: P]XKY,R_^
# Line: FG`
# Line: V
# Line: 
# Line: I
# Line: _
# Line: ,9G^IM;FHO.<67H
# Line: @9@7?
# Line: 6
# Line: X
# Line: ITI
# Line: _
# Line: ,9H1ITHO.<IM,P6767a
# Line: @
# Line: ;
# Line: k%
# Line:
# Line: @
# Line: I
# Line: X
# Line: ;=,9GoH<IY.1;FH
# Line: q
# Line: A
# Line: 4rE;=.
# Line: @
# Line: HO.10Q2^,9GoD=;F\%acHba
# Line: >
# Line: ?
# Line: cER
# Line: 
# Line: I
# Line: _
# Line: ,1IT,7I
# Line: 
# Line: IM,72>;=,/.<\
# Line: A
# Line: ,/.
# Line: >
# Line: ?
# Line: Y
# Line: <
# Line: ?
# Line: O
# Line: 
# Line: I
# Line: _
# Line: ,/.1IY0QI
# Line: _
# Line: ,7G>I
# Line: 
# Line:
# Line: ;F,7,
# Line: A
# Line: 0xa}2e47j
# Line: 2^0d;=,9,
# Line: A
# Line: 0x,9IY.1670
# Line: A
# Line: l
# Line: B
# Line: AA
# Line: D=;F,7G>Hl5;=,9H1;F4
# Line: A
# Line: >@?
# Line: Y,OedGY
# Line: 
# Line: I
# Line: _
# Line: ,/.1IY0QG>IY.1I
# Line: 
# Line:
# Line: ;=,/.
# Line: A
# Line: 03,9IMD
# Line: >@?
# Line: f
# Line: :
# Line: 
# Line: IMacIMI
# Line: 
# Line: \)2T.
# Line: @7A
# Line: 0
# Line: >
# Line: ?
# Line: B
# Line: 
# Line: I
# Line: _
# Line: ,7H
# Line: @
# Line: I
# Line: 
# Line:
# Line: U9IM0<.lIM,7G>D
# Line: A
# Line: >
# Line: ?
# Line: B`
# Line: ^gYh?
# Line: 
# Line: I
# Line: _
# Line: ,9H
# Line: @
# Line: IYa
# Line: @
# Line: 6767.1IM
# Line: 
# Line:
# Line: @
# Line: ITHJa
# Line: AA
# Line: ,WI
# Line: UcIY03.J2
# Line: B@9A
# Line: 0
# Line: >
# Line: ?
# Line: B
# Line: V
# Line: 
# Line: I
# Line: _
# Line: ,9H
# Line: @
# Line: I
# Line: k%
# Line:
# Line: B
# Line: 0QIMG>\
# Line: A
# Line: ,/.1IMD
# Line: UcIY03.1;=8D
# Line: A
# Line: >
# Line: ?
# Line: B
# Line: A
# Line: I:
# Line: R
# Line: J
# Line: 
# Line: I
# Line: _
# Line: ,7H
# Line: @
# Line: 69\)IMIM,
# Line: _@
# Line:
# Line: 03IT47;FIM,/.
# Line: >
# Line: ?
# Line: B
# Line: i
# Line: R
# Line: 
# Line: I
# Line: _
# Line: ,7H
# Line: @7A
# Line: ,9I
# Line: 
# Line:
# Line: UcIY03.
# Line: >
# Line: 8
# Line: Y
# Line: :
# Line: d
# Line: <
# Line: ?
# Line: 
# Line: IMNMIY03.1IMIY0QIM
# Line: 
# Line:
# Line: IMHJ.
# Line: @7A
# Line: ,72>,7492
# Line: A
# Line: 0
# Line: >
# Line: 8;I
# Line: d
# Line: 
# Line: IYNMIY0Q\)I
# Line: 
# Line: ;=,9IM8:.<;=2>,
# Line: >
# Line: 8;I
# Line: d
# Line: 8
# Line: j
# Line: Y
# Line: J
# Line: 
# Line: IYNMIY0Q\)IMN
# Line: s
# Line: ;[.
# Line: _@
# Line:
# Line: E;[.
# Line: @
# Line: 2>65.J472>;=,9G
# Line: H12>\
# Line: A
# Line: .
# Line: @
# Line: ;=,9G
# Line: >
# Line: 8;I
# Line: d
# Line: H
# Line: V
# Line: 
# Line: IYNMIY0Q\)I
# Line: v
# Line: I
# Line: k%
# Line:
# Line: .
# Line: @
# Line: IM,,92
# Line: En2T03N
# Line: >
# Line: 8;I
# Line: d
# Line: FGH
# Line: 
# Line: IYNMIY0Q\)I
# Line: v
# Line: ;
# Line: 
# Line:
# Line: ;=,W,92T.492^;F,7G
# Line: U90
# Line: A
# Line: H<8:0Q;=a
# Line: A
# Line: 4|4967.1;
# Line: A
# Line: H
# Line: >
# Line: 8;klI
# Line: m
# Line: ?
# Line: 
# Line: IYNMIMDF\)IMH
# Line: @7@
# Line: IM
# Line: 
# Line:
# Line: B
# Line: 0
# Line: AA
# Line: 4
# Line: B
# Line: 0Q2>\
# Line: IMD=D
# Line: UcIMH1.JH<;=,
# Line: B
# Line: 67D}0
# Line: A
# Line: IT8:.1;F2^,9H
# Line: >
# Line: 8
# Line: X
# Line: I
# Line: :
# Line: Y
# Line: J
# Line: 
# Line: IMNMIMH1\
# Line: IMIY.
# Line: _
# Line: @c
# Line:
# Line: aPj|8
# Line: @
# Line: IM,98
# Line: A
# Line: >
# Line: 8;:=<
# Line: V
# Line: 
# Line: IYNMITIY0QI
# Line: k%
# Line:
# Line: .
# Line: @7A
# Line: q
# Line: 0QHO.D
# Line: A
# Line: .1.
# Line: A
# Line: 0
# Line: >
# Line: 8;:=<on
# Line: 
# Line: IYNMITIY0Q2
# Line: 
# Line:
# Line: .
# Line: @9A
# Line: D
# Line: A
# Line: .O.
# Line: A
# Line: 0pL
# Line: I@N
# Line: >
# Line: 8;:=q
# Line: d
# Line: 
# Line: IYNMIMIY03j^I
# Line: 
# Line:
# Line: IM,94
# Line: B
# Line: 2T03ac;=494
# Line: A
# Line: ,
# Line: IM8`.1;
# Line: X
# Line: ;[.1;
# Line: A
# Line: H
# Line: >
# Line: 8;:=q
# Line: d
# Line: ?
# Line: 
# Line: IYNMIMIY03j^IT
# Line: 
# Line:
# Line: E
# Line: @
# Line: IY.x2^69G
# Line: @
# Line: .J,92^.S.<2
# Line: a
# Line: A
# Line: 472>,
# Line: A
# Line: >
# Line: 8;:=q
# Line: i
# Line: d
# Line: 
# Line: IYNMIMIY03j
# Line: AM
# Line: IM,74WE
# Line: @
# Line: IY.x2>67G
# Line: @
# Line: .,72^.S.<2
# Line: a
# Line: A
# Line: 492^,
# Line: A
# Line: >
# Line: 8srtF
# Line: Yud
# Line: 
# Line: IYNe;=;=0<.<;
# Line: 
# Line:
# Line: ;F,
# Line: B
# Line: IM\bj
# Line: >
# Line: 8srtF
# Line: Yud
# Line: ?
# Line: 
# Line: IYNe;=;=0<.<;=
# Line: 
# Line:
# Line: ;F,
# Line: B
# Line: IM\bj
# Line: >
# Line: 8srtF
# Line: YudKV
# Line: 
# Line: IYNe;F;[03.1;
# Line: k%
# Line:
# Line: ;=DFD
# Line: B
# Line: IM\
# Line: A
# Line: >
# Line: 8
# Line: A
# Line: \
# Line: dGY
# Line: J
# Line: 
# Line: IYNe650
# Line: X
# Line: IY.
# Line: _@
# Line:
# Line: 49;=4
# Line: >
# Line: 8
# Line: A
# Line: \
# Line: dGY
# Line: 
# Line: IYNe650
# Line: X
# Line: IY.<I
# Line: 
# Line:
# Line: 49;=4|.
# Line: @7A
# Line: jW472
# Line: >
# Line: 8
# Line: A
# Line: Bv
# Line: ?
# Line: 
# Line: IMNe67H
# Line: @
# Line: ITD=IM
# Line: 
# Line: ;=,9IM67H1Uc;=8`;F2^69H
# Line: >
# Line: 8
# Line: j
# Line: Y
# Line: f
# Line: A
# Line: FGw]x
# Line: \
# Line: :
# Line: Y
# Line: J
# Line: 
# Line: IYN
# Line: s
# Line: ;=.1IYac69474
# Line: @
# Line: ;=.
# Line: X
# Line: IMIM.
# Line: _@
# Line:
# Line: 496
# Line: A
# Line: .12o69,7;F,/.
# Line: A
# Line: D=DF;=G
# Line: A
# Line: ,98
# Line: A
# Line: >
# Line: 8
# Line: j
# Line: Y
# Line: :=xgI
# Line: :
# Line: RWV
# Line: 
# Line: IYN
# Line: s
# Line: ;[.<IMIY.1\
# Line: IMIM,9I
# Line: k%
# Line:
# Line: .
# Line: @
# Line: 2>H
# Line: A
# Line: E;[.
# Line: @
# Line: 2>67.RH
# Line: A
# Line: D
# Line: B
# Line: fz0
# Line: A
# Line: IMD=;FH1IM.1;=2>,
# Line: >
# Line: 8
# Line: j
# Line: Y
# Line: i
# Line: R
# Line: 
# Line: IYN
# Line: s
# Line: ;[.
# Line: A
# Line: ,9I
# Line: 
# Line:
# Line: E;[.
# Line: @
# Line: 2>67.R49;=H<8
# Line: @
# Line: IY0QG
# Line: A
# Line: 2
# Line: B
# Line: 4767.mj
# Line: >
# Line: 8
# Line: j
# Line: x
# Line: \
# Line: :
# Line: 
# Line: IYN
# Line: s
# Line: ;[.
# Line: X
# Line: ITI
# Line: 
# Line:
# Line: E;[.
# Line: @
# Line: 2>65.J492^;F,7G
# Line: B
# Line: 0Q2>\
# Line: N
# Line: s
# Line: ;
# Line: 
# Line: y
# No data extracted. Please check the PDF content and regex patterns.

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import pandas as pd

# Open the PDF file
pdf_path = 'dictallcheck.pdf'
doc = fitz.open(pdf_path)

# Initialize lists to store transliterations and meanings
transliterations = []
meanings = []

# Loop through each page and convert to an image
for page_num in range(len(doc)):
    # Get the page and convert it to an image
    page = doc[page_num]
    pix = page.get_pixmap()
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    
    # Use Tesseract to do OCR on the image
    text = pytesseract.image_to_string(img)

    # Print extracted text for debugging
    print(f"Extracted Text from Page {page_num + 1}:")
    print(text)
    
    # Process the extracted text for transliterations and meanings
    # Adjust regex pattern as necessary based on the extracted text format
    pattern = re.compile(r'\(([^)]+)\)\s*=\s*(.+)')
    
    for line in text.splitlines():
        match = pattern.search(line)
        if match:
            transliteration = match.group(1).strip()
            meaning = match.group(2).strip()
            transliterations.append(transliteration)
            meanings.append(meaning)

# Create a DataFrame and save to CSV if data was found
if transliterations and meanings:
    df = pd.DataFrame({'Transliteration': transliterations, 'Meaning': meanings})
    df.to_csv('ordered_transliterations_meanings.csv', index=False)
    print("Data saved to 'ordered_transliterations_meanings.csv'")
else:
    print("No data extracted. Please check the PDF content and regex patterns.")

# Close the document
doc.close()
# Out:
# Extracted Text from Page 1:
# Online Sanskrit Dictionary
# February 12, 2003
#
# te transliterated form
# cannot be a substitute for a good
#
# ‘The following
# ‘and a short meaning provided as a reference source, Thi
# printed Sanskrit-English dictionary
#
# the on-line world,
#
# of Sanskrit words printed in Devanagart wit
#
# nha, raamarakshaa et ectera, and other
# files accessible on the web. The words are encoded in ITRANS transliterat
# ping chem in Devanagari
#
# scheme x0 a8 to
#
# ‘There is a copyright on this file to the extent of preventing misuse on other internet sites
# and ego-trips of individuals.
#
# We recommend not to copy and post this fle on any other site since we periodically update
# list and we do not wane different versions of file floating around the internet.
# We have soem people copying this work and calling of their own.
#
# and correct th
#
# ‘Wo request you to provide corrections, and more importantly many suc addi
# your own collection.
#
# kkh g gh N’
#
# ch ohh j jh IN
#
# TThD DLN
#
# tihddha
#
# bohm
#
# yr Lv sh shh sh L(maraaThit) kSh(x keh) GY (hindi)
# joe anusvaara, .a avagraha, .b haLa.nta
#
# - Only a dot . or a vertical line 0 8 da.nDa .
#
# ‘ne and anc produce ard!
# ‘The vowels need to be
#
# consonant, unless one wants joDankshat
# No other letters (upper oF lower eases) are allowed.
#
#
# Extracted Text from Page 2:
# For other examples, see texts on Sanskrit Documents
#
# ‘at htp://sanskrit.gde.to/ or ite
# mirror at het
#
# /sanskrit.bhaarat.com the document project.
#
# ‘There is an excellent freeware available for Ttrans users, called Ttranslator08/00, written by
# Swamis at Onkarananda Ashram. Please download and install i from,
# Ihetp://www.omkarananda-ashrani.org/Sanskrit/Ieranalt.html The tx version of this fle is
# directly viewable in the software allowing text display’ in Devanagari as well as
# Romansdiacrities marks.
#
# For those interested in volunteering to encode, proofread, of translate Sanskrit documents
# ‘wo suggest you access volunte
# Inttp://sanskrit.gdo.to/ OR
# ‘ntep://sansheit.bhaarat.com in the
# ‘The site contains additions
#
# fle from
#
# scument project.
#
# information on Sanskrit projects. A Gl of frequently:
#
# asked-answered questions (FAQ) is available at
# Inttps//sanskeit.gele.to/sanskeitfag. html
#
# Please join us in collecting word = meaning lists with word encoded in striet ITRANS
#
# scheme format.
#
# Please contact sanskritMcheerful.com for additional details
#
# We appreciate your contsibution to make this effort success
#
#
# Extracted Text from Page 3:
# Glossary of Sanskrit Terms
# eps wer
# 3 (AUM) = Primordial Sound
# ‘Sem (OMkaara) = the syllable om
#
# 2 (a) = not
# FET (a.nkusha) = a goad (metal stick used to control elephants)
#
# stymatfrmm (ankushadhaariNam-h) = bearing the weapon ‘ankusha’ with which the elephant
# SIT (a.nga) = body, organ
#
# 7 (a.ngaNa) = fold
# strat (a.ngaca.nginay) = with
#
# limbs, body parts
# (aungaistushhTuvaa.neastaniubhilf)
#
# having satiafled with strong limbs?
#
# nointment
# #77 (antara.nga) = innor body or inner nature, feelings, inside
# iat (a.ntargata)
#
# fat (aMbas)
#
# without doing something
# than no work
#
# are (alarmaNi) = in not doing preseribed duties
#
# TWEE (akalmashhaM) = freed from all past sinful reactions
#
# SFFrETE (aknamaath) = by chance
# _ the first Iettor
#
# wr the letter
#
# oe
#
# a
#
# ant
#
# net
#
# ret
#
# rin:
#
# PFT (akurvat.h) = aid
#
# SPAT (akurvate) = did they do
#
# Sry (ahushalaM)
#
# SETHE (akfhtabuddhitvaat.h) = due to uninteligence
# STPTTETT: (akRitaatmaanall) = those without selfreal
# SPAT (akRitena) dlincharge of duty
#
# SFT (akTievan) doing (rom KR)
#
#
# Extracted Text from Page 4:
# SRPFTITET: (akRitenavidasH) = persons with a poor fund of knowledge
#
# afi: (akriyaall) = without duty
#
# orHNT(akrodha) = freedom from anger
#
# SANT: (akrodhaFl) = freedom from anger
#
# arvire: (akledyaHl) = insoluble
#
# sxfiret (akhila)
#
# sft (akhilaM) = whole
#
# afRerTT (akhilaguru) = preceptor for al, also all cypes of long syllable letters
#
# SET (agata) = not past
#
# SITET. (agatasuu.nach inch + chacundeparted
# thou going (from gam.)
#
# = agate + as
#
# + and (living people)
#
# saftrviT: (agniparvatatt) = (m) volcano, volcanic cone
#
# saftrafteT (agnipetikan) = (F) matchbox
#
# saftrararer_(agnishalankaa) = (f) matchstick
#
# fT] (agnishbhu) = in the fires
#
# SFrAT (agnau) = in the Bre of consumma
# yout in this sense) tip
#
# at the tip
#
# SET: (ageatall)
#
# sreT: (agradiipalf) = (om) headlight
#
# SFT (agre) = in front of/ahead /heforchand
#
# SFETT: (aghaMmanall) = (adj) evil-minded
# srievous sine
#
# ‘number
# limb, oF body part
#
# a finger
# ha) = the big too
# - (angushhThaHf) = (m) thumb
# ot (acharaht)
#
# SET (acharasya
# Fer (achala)
# SFT (achalaM)
# Se: (achalal)
# areerfre (achalapratishhThaM) = steadily s
#
# ted
#
# Extracted Text from Page 5:
# aT (ach without its b
# SFT (achakShus.h)
#
# SFaTTt (achaapalaM)
# after (achintya) = inconceivable
# aff (achintyaM) = beyond contemplation
# ssf: (achintyall) = inconecivable
# safeTre (achirand.h) = without delay /in no t
# ferret (achirandbhava) = in no time from
# safer (achireNa)
# FTTH: (achotasaHl) = without KRishbNa consciousness
# HT: (achehhedyaHl) = unbreakable
#
# FFT (achyuta) = O infallible one
#
# FFT (achyutam.h) = the who doos not slip
#
# 57 (ain)
# 57 (ain
# =
#
# 1 eyele of birthiudeath
#
# ‘very soon,
#
# SFT (aiapaa) = involuntary repetition (as with a ma
# ST (ajnsraM) = the unborn one
#
# Sar (nina) = (8) goat
#
# SFT (alannah)
#
# STAT (ajaanat-h) = knew
# STITT (ajpanataa) = without knowing
# STITT: (ajaanantalf) = without knowing
# STFTH: (aJNehala]) = (m) aanehal in
# TFET (alNjana) = the name ofthe mother of Hanuman
# SDERTET (alNjancyaneana
#
# seat (@JNjoi) = (m) folded hands
# sxeft_(aTati) = (1 pp) to roam
#
# lo not understand
#
# = the spliee
#
# srehait (aNilyna.neaM) = smaller
# ae (at
# sar (aNoH) stom,
#
# Foret (aNvastraMf) = (n) nuclear weapon,
#
# SITE (ataHT) = hence
#
# SrTTETETT (atattvnarthavat.h) = without knowledge of
# with great care
#
# 10 one who
#
# not austere
#
# aay)
#
# = excessive familiarity
# super power
#
# fret (atichaara) = Accelerated planetary motion
# arfrefat (atitaranti) = transcend
#
#
# Extracted Text from Page 6:
# “afrere (otitaralah = oti starala, very unstable
# Fe (sith) = (m) runt
# Ste atithil) = (ase: Nomaing)gust (literally undated)
# sairerewt (atidaneuuNaman h) ~ adj. very dreadfal
# ‘rivet atiduryRitta) = of exceodingly bad conduct
# stiri atschyate) = becomes more
# ‘iret (aivariate) ~ anne
# sire (otshaya) = wonder
# srireater(ashevokl) ~ exnoraion
#
# aurpaeed
# traneondiog
# oritftrt (atiindriyaM) = transcendental
# rire (atiiva) = very much
# Tater (atulaniiya) = uncomparable
#
# STE (atyantaM) = the highest
# rent (atynrthaht) = highly
#
# very hot
#
# arrqeT (atyushhNe
#
# SRI (athashabda) = the word atha (prayers are started with words atha or AUM)
# ant: (atha.rlf) = object, meaning
#
# anriveret_(atharvaNvaakyaM)
# snrtt. (atharvashiineh
# prt (atharvashiirsbhaM)
# spre (athavaa)
# GRETT: (athantaHf) = atha and ataHf : then and therefore
#
# ‘or in other words
#
# charvaNa” word:piece
#
# 1 to the priests
# SRerm: (adaahysH) = ws
#
# aafetr (aditi) = the mother of the gods
# Sgt (adRishhTa) = Unseen, fortune, luck
# srgeTe (adRishhTaps never seen before
# afer (adetha) = at an unpurified place
#
#
# Extracted Text from Page 7:
# (sdbhuta) = the sentiment of marvel
# SF (adbhutadt = wonderful
#
# SFE (adbhuutaM) = wonderfull
#
# 37a (aya) = today
#
# FTE: (adrohal)
#
# SEIT (avlvansana)
# safgfre: (advitiiyalt)
#
# freedom from envy
#
# on-duaiy ofthe universal spirit
# Gandectinabte) below
#
# se without money
# inferior
# reat (adhamand
# SIRT (adhamaadhama) = the worst among the inferior
# sret (adhara)
# set: (adhorait
# seer (adharaa
# once (adharma)
# srcit(adharmaNy =
# areth (adharmal)
# areirarfr (adharmachaasi
# cee (adharmasya) = of ireligion
# ‘afi (athika) = additional
# safe (adhitaNh
# orf: (adhikall) = greater
# srfiert: (adhikatarall) = very much
# safer (adhikaara) = ttle
# srfierr: (adhiasealt) = right
# sefeerPert (adhikanrtantead)
# sefefrait(oanikshipat)
# sft: (adhikShepalf) = (m) a
# seferemft (adhigacchnai) = attains
#
# condemned
#
# safefram: (adhiniyama) = (1m) act
# she ( protector
#
# axfetft (adhipatiy = lord
#
# ‘fegT (adhibhuta) = the principle of objective existence
# arfegt (adhibhuutaM) = the material manifestation
#
# safer (adhimastea) = superior
#
# saferrarrm (adhimaatrastama) = the highest, the aupreme one
#
#
# Extracted Text from Page 8:
# sfeex (adhiyaGYa) = the principle of
# fees: (adhiyaGYalt) = the Supersoul
# atfrrre (adhivansa) = dwelling
#
# feta (adhiveshanaM) = (n) conference
# atfemT (adhishhThaana) = seat, abode
# arfemrt (adhishhThaanaM) = sitting place
# safeera (adhishhThaaya) = being so situated
# srfenit (adhisari) = competent candidate
# snftt (adhiita)
#
# rifles, incarnation,
#
# he dog stret
#
# srorrrrfrar_(adhyaatmavidyaa) = spiritual knowledge
# span: (adhyaadeshaH) = (m) ordinance
# snare. (adhyanpayituM) = to teach (infinitive of causative of adi:
# sranfoer (adhyaapikaa) = (f) lady teacher
# SPOT (adhyaasa) = a cate of mistaken identity
# srrert (adhyoshhyate) = will study
# speiret (adhyopatya) = Lordship
# SNE (adhruvaht) = temporary
# SRT (adhvan.h) = road
# (mm) rond, path, way
# ‘unstoadiness of the body
#
# Infinite, a name of Vishns
# 77% (anantaMt) = unlimited
# 7-7: (anantaHt) = Ananta
# STAT (qnantaraM) = after
# © unlimited form
#
# unlimited form,
# the conch named Ananta-vijaya,
# ar-That(anantavilryaa) = unlimited potency
#
# SFT: (anantaatT) = unlimited
#
# SETTTAT (ananteasans) = Ananta’s posture
#
# SHITE: (ananyachetaaHl) = without deviation of the mind
# SFI-TITE.(ananyabhaakch) = without deviation
#
# to study)
#
# Extracted Text from Page 9:
# without deviation of the mind
# indeviating
#
# by unalloyed devotional service
# raving no other object
#
# SETA: (ananyamanasalt)
#
# sry-TAT (ananyayan) = unalloyed,
# SATE (ananyayoge
#
# ithout division
# neutral
#
# sere (onapekShya)
# sSrrfrep: (anabhishva.ngall)
# srafineeere (anabhinandhaaya)
# rvfie: (anabhisohatT) = without affection
# ignorant of, unacquainted wit
# them
#
# ppurposotess/in vain/danger-produective
#
# by the fre
# wavalokayaan.h) = not looking
# wanted
#
# orereT: (anashnatalt)
# sPrret (anashnan.h)
# SPrETT (anauyave)
# SETTe: (anasuuyall)
# STTET: (anamuuyantaH) = without envy
# SrrETTAE (anaha.nvaadi) = without false exo
# SIRETT: (anaha.nkaaralf) = being without false egoism
# SFT: (anaatmanall) = of one who has failed to control the mind
# aFTTET (anaadara) = Inck of respect
# without beginning
#
# ‘without beginning
# srrfeer (anaaditva) = non-boginning
# SeTHFRTT (anaaditvaat.h) = due to eternity
# SFTTTAHTT (anaanasaphalam-h) = (n) pineapple
#
# Jing from eating
# without eating (having fasted)
# to the nonenvious
#
# 1 envious
#
# serra (anaavittia)
# seria: (anaashinalt)
# serifaa: (anaashritelt)
#
# no return
# never to be destroyed
# ‘without taking shelter
#
# SET (annahate) = unbeaten
#
# “uncertain temporary /ephemeral/transient
# = temporary
#
# Extracted Text from Page 10:
# aie ( ‘nonpermanent
# srfrafer (aniyamita)
#
# afferent (ani without deviation
# fre: (anilalt)
#
# afrargier (anilachulll) = (f) gas (LPG)
#
# safrartt (anivaarya) = (adj) compuleary
#
# sxfre (anishhT»M) =
# srfret (aniishvaraNt)
#
# 57 (anu) = following
# SETFEMP_(anukampanrthaM) = to show special merey
# seqerft (anukaari) = tke
#
# SFTATTE (anuchaaraya) = (causative of annear) follow
# STPTATET (anuchintayan.h) = constantly thinking of
# SqPREPT (anutishhThanti) = regulary perform
# SFT (amuttamadt) = the Rest
#
# FTTH (anuttamaaht) = the highest
#
# Sry (anudarshanaM)
#
# TYE (anudaanaM) = (0) donation, grant
# SFTP (anudinadMt) = daily
#
# SrYPERE (anuuddiahya) =
#
# observing
#
# SeYfeTHT: (anudvignamanaalf) = without being agitated in mind
# STTETIT (anudvegakaraM) = not agitating
# Tyra (anupakaariNe)
# seqTrcir(anupashynt)
# SeTTFGET (anupashyanti)
# SeTTRTTAT (anupashyaam’)
# SFTFTAT: (anuprapannanif) = folowing
# STE (anubandha) = (m) result, effect
# TET (anubandhadt
# STEN: (anubandhakt) = (m) annexure
# spent (am
# SrqER (anubandhe)
# Sry: (anubhava)
# wumantas) = permitter
#
# irrespective of return
#
# of future bondage
#
# (ablat.)from guessing or induction
# (enuyaayinall) = followers
#
# 10
#
# Extracted Text from Page 11:
# STS (amuraiyate)
# SET (anuradhs
# FIAT (anulipta) = smeared
# SFT (anlekha) = destiny
# STAT (anwlepanaM)
# STAT (anuloma) = with the gr
#
# ie becoming attached
#
# seventeenth nakshatra
#
# smeared with
# 1 naturally
#
# STR (anuvartate) = follows in the footsteps
# SFTP (anuvartante) = would follow
# srqrtaft (amuvartayati) = adopt
#
# SETTTE (amuvandaM) = translation
#
# SFTRTE (anuvandya) = having translated
# srqfnfiet (amuvidhiiyate) = becomes constantly engaged
# rym (anushaasitaaraM) = the controller
#
# ashrusma) = Thave heard by disciplic secession
# TAT AT (anushochanti) = Inment
# STAI (amushochitunt = to lament
# STOTT (ancl
# TET (anushbtwp)
# SFqET (anushhThana) = (n) performance, execution
# aryrermfr (anusantatann’) = extended
# SryTATt (anusandha (0) investigation
# SFTATT (anusnara) = following, eustomary(minse)
# ‘FAT (anusuuchii) = schedule
#
# £0 on remembering
#
# ch) = remembering
# SFT (anamaret.h) = always thinks of
# STE: (amunvanra) = the accompanying sound or letter (the letter form ‘n! M2)
# SETWTETT  (anuGYaayataaMf) = (verb) be given leave/permission
# SETI (anuichaanaM) = (teacher?)
# STF (anRita) = fase
# Te (ancka) = Many
# SFTeIT (anckadhas) = into many
# FETE (anckavachaneM) = plural
# srt (anekann’)
# SF (anna) = by th
# art (angaMt) = body
# ort (anta)
# STF (antaMt)
# ST: (ental) = (adv) inside
# seorinra.(antaffharaNa) = Mind
# STTFERT (antal{peTikan) = (f) drawer
# srerinetfs (antalfsthaani) = within
# SroTET (antakaale) = at the end of life
#
# n
#
# Extracted Text from Page 12:
# =I (antara)
# arr (antaraM)
#
# STITT (antarnatmanaa) = within himself
#
# ST-TTTAT (antarantmaa)
#
# the inner self, residing in the heart
# (m) obstacle
#
# ST=TTTTTR: (antaraaraamal) = actively enjoying within,
# srerftar (antariksha) = (n) space
#
# srotfrat (antarikShaM) = space, sky
#
# 3-97 (antare) = betwoon
#
# rato (antaroNa) = without
#
# SE-TTTIPT: (antarjyolifl) = aiming within
#
# SATETET (antaryutakam.h) = (n) vost
#
# Serpe: (antarsukhaH)
#
# orf (antike) = near
#
# SE (ante) = after
#
# arr (ands)
#
# ‘ere (andhakaara) = darkness
# ) = food
#
# FF (anna = foodstutt
#
# S7HTT (annaatsh) = from grains
#
# SFT (anya) = other person
#
# SF (anyaMt) = other
#
# S-7F (anyatra)
# sn (anyathaa)
#
# rout (anyaaM)
#
# TT (anyaan.t)
#
# sr=aFF (anyaani) = different
#
# r= (anyaayens) = illegally
# hers
#
# by another
#
# by others
# mutual
#
# Family
#
# SEAT: (anvashochsall) = you are lamenting
#
# 2
#
# Extracted Text from Page 13:
# safer (anvichchha) = try for
#
# ‘afer (anvite) = (p.p) Followed or attended by, in company with, joined by;
#
# coverpowerd by, connected grammatically;
#
# sxfermt: (anvitaall) = absorbed
#
# are (anveshhaNam.h) = (1) search, exploration
#
# SFTF_(apakR) = to harm
#
# TET (apakendraNa)
# handicapped
#
# to decrease
#
# dof,
#
# centrifugation,
#
# TT (apara) = other
#
# sreTt (aparaanch)
# srvfrme (aparigraha)
# rafrae: (aparigrahall)
# soft (aparimeysM) = immeasurable
# srefrar (aparihanrye) = of that which i unavoidable
# are (apare
#
# reat (aparyaaptant) =
# srTaTe (epalaayanaM)
#
# seducetion
# TATE (apavanda) = exceptional
# SFGPTET: (apavighnaH) = without obstacles
#
# hie cou
# forgetful
#
# SFTERTT: (apasmaaraHl) = (mm) epilepey
#
# SFTETT (apaharaNa) = stealing
#
# STTETH (apaharaNaM) = abduction, kipnapping
#
# arveTit (apahartaaraM)
# STURT (apabRita) = stolen
# SFURTITAT (apahRitachetasaaM) = bewildered in mind
#
# he remover}destroyer
#
# a
#
# Extracted Text from Page 14:
# Srorr (apnana)
# srert (epnanaM)
# STU (epane)
# ara (apaapo)
# arafeT: (apaayinall) = disappearing
# TTT (apaaraa) = one who has no limite
# SUT (apaavRicany
#
# sft (api) = also
# sr4Ty (epiteshin) = (Mase.Loe-PL) having not drunk(taken water)
# SFT (apunya) = view
#
# STTATTEP. (apunaraavRtiM) = to theration
#
# STF (apushlipa) = one without Sowers
#
# gfrer (apRithivyoH) = to the earth
#
# dow:
# sets downward
#
# wide open.
#
# (f) expectation, hope
# sion to fault-find
#
# SmrWT: (aprakaashaHl) = darkness
# SrxfTHEATE (apratimapeabhaava) = O immeasurable power
# StxfTE (apratishh Tha)
#
# aaxfe: (apratishhThaH) = without any position
# sarirert (apratiikaaraM) = without being resistant
# SOTETT (apradaaya) = without offering
#
# SImFT (aprameya) = the ununderstandable
#
# amt (aprameyaM)
# SEFTTET (aprameyasya) =
# saraft: (apravRittiHt) = inactivity
# SEITAT (apranptat.h) = uttained, obtained
# SET (apraapya) = filing to attain
# SEITTATHT (apraamaamaaNya) = Unjustifiod
# sft (apriyaM) = the unpleasant
#
# sft: (apriyaHt) = and the undesirable
#
# ithout foundation
#
# SrTaITTT (aphalaprepsunan) = by one without desire for fruitive result
# SreaTATPEat: (aphalankan.nkShi
#
# STE (ahandhu) = one who dove not have any brothers / kinmen
# STR (abla) = helpless (woonan)
#
# area (abalas)
#
# STTET: (abuddhayaHt) = leu intelligent persons
# STATE (ahodha) = Ignorance
#
# HT) = by those devoid of desire for result
#
# (helpless) Woman,
#
# 4
#
# Extracted Text from Page 15:
# (1m) ocean, sen
# ch) = spoke
#
# SEmET (abrahmaNys) = Not kosher
# SPATE (abhaktanys) = to one who ie not a devote
#
# rt (abhayaM)
#
# SFT (abhaye) = and fearlossnoss
#
# SPAT (abhavat.h) = became
#
# srafrert (abhavishivat,
#
# seat: (abhnavaHt)
#
# SATTTT: (abhaavayataHl) = of one who is not fixed
#
# SFATET (abhnashhiata) = began to speak
#
# safir_ (abhi) = proposition
# i-+taD.h) = to
# ikathanaMt) = (n)
#
# 18) = In endeavouring
#
# 14) = black magic
#
# afKTATE (abhijanavann.h) = surrounded by aristocratic relatives
#
# ssf: (abhijeatall) = born of
#
# finrTeT (abhijaatasys) = of one who is born of
#
# ssfirnfet (abhijaananti) = they know
#
# asfiraratit (abhijaanaati) = does know
#
# safiraret (abhijasyate) = becomes manifest
#
# safirt (abhijita) = A nakshatea between uttaraashhDhas and shravaNa mainly centred on the
#
# star Vega. For some reason itis not usually included in the 27 nakshatras although it would
#
# ‘make 28 if it was. adhipatit- Lord
#
# jinchmubwurta) = the most auspicious moment
#
# covorywhere
# 1aHt) = (m) Insurgency.
# in) designation
#
# oxfirrg:
#
# ‘afafs@ (abhinivesha) = possessiveness
# (om) layout
#
# fergie: (abhipushhTiH) = (f) affirmation
#
# StfETTT: (abhipravRittsH) = being fully engaged
#
# safe: (abhiprasyalf) = (m) opinion
#
# axfinreft (abhibhavati) = transform
#
# ssfinrem (abhibhavaat.h) = having become predominant
#
#
# Extracted Text from Page 16:
# safer: (abhimansH)
#
# firs (abhimaana) = seltimportance
#
# afirgest (abhiyuktan
# sxfire (abhivoga)
# sxfirdt: (abhiyogal) = (m) prosecution
# ssfirrr: (abhirataHt) = following
#
# ssfirraey (abhirakshant
# ssfirfirt (abhirakShitaMt
#
# perform’ ps
# ablation
#
# fon the idol
#
# sreafire: (abhyadhikall) = greater
# srerTeet (abhysnunaadayan.h)
# seat (abhyarchya) = by worshiping
# sRaTt (abhyasanaM) = practice
#
# srerpreT:. (abhyasuuyskaalt)
# srarpait (abhyasuuyati) = is onvios
# sRerTTT:. (ablyastuyantal)
#
# srt (ablyaasa)
# SFATMATT (abhyansayoga) = by practice
# SAMMUT (abhyaasayogena) = by the practice of devotional service
# SPOTATE. (abhyaasaat, 1m practice
#
# FATT (abhyaase) = in practice
#
# srepert (al
# sreqeT (abhyudayn)
# ort (abhranty
#
# arr (amala) = without rubbish
# art (amalaM) = clean,
#
# 6
#
# Extracted Text from Page 17:
# seer (amalaan.h)
# srrifset_ (amaanitvaM)
#
# spre: (amuuDhasH)
# STeT (amuulya)
#
# riceleas, excellent
#
# f ambrosia, potion to cause immortality
#
# 8 drop of nectar
#
# howe who have tasted auch nectar
#
# SEPA: (amRitabhyjoH)
# SFATET (amRitasya) = of the immortal
#
# aryATET (amRitodbhavaM) = produced from the churning of the ocean
# FATT (amRitopamaM) = just like nectar
#
# SeTETT(ambuvegan) ~ waves ofthe waters
# Sam (ambhanh) = (x) water
# the water
#
# om the water
# ATF (ombhruhaht) = fnew
# > fomin ~ (m) se
# 2 (opaht) = him (hom idaX4)
# SET (oyajanls) = third person plu imperfect aatmanopade of ya, to worship
# waft: (ayatifl) = the unsuccessful transcendentalist
# Serre (ayathanvath) = imperfectly
# SATE (oyanesina) = inthe statege plats
# TT (yum) = length, extension, restraint
#
# 1) = infamy
# rr (apnntt) ~ (ron
# {FET ayaGVasya) ~ for one who performs no sacrtce
# ERT: (ayubtall) = one whofe notin KB
#
# IhNa consciousness
#
# (a) a wooden barrel
# Srrer (araNyam.h) = (a) jungle, forest
#
# 7
#
# Extracted Text from Page 18:
# arretie: (araNyaukassH)
#
# = (Mase.poss.sing.) forester's
#
# being without attachment
# SETTTETT: (araagadvesbhata)
#
# thout love or hatred
#
# afr. (arishhu) = on enemies
# srfrenit: (arishhTanemitt)
#
# srfrpet (arinsudans)
#
# the appelation ¢o Garuda?
# killer of the enemies
#
# ‘omonce, & name of Sun
# ore (argha) = value
#
# ard (archati) = (1 pp) to worship
# fF (orehitun
#
# SF (jana) =
# orf (arjanad)
# er (ani
#
# SF (ori
#
# or
#
# STE: (ardunayoH) = a
# one (artha)
# ane (arthaMy
#
# ania (arthayate) = (10 pp) to request
# snbart_ (arthavaan.h) = one with money
#
# fmase.poss.sing.) wealth or meaning
#
# ‘one who desires material gain
# sr (arth) = in meaning
#
# antiertarz (arthopaarianaaya) = for ea
# af
# arith (ardhiagola) = semicircle, dome
# oRIS=FTAT (ardhachandrnasas
# onframry (ardhanavansana) = the
# anfarhater (ardhanaariinaTeshvara)
#
# 1 half-moon posture
#
# (1m) frock
# the halflotus posture
# che half spinal-ewist posture
# anffieiys (ardhashirshhaasana) = the half headstand posture
#
# 18
#
# Extracted Text from Page 19:
# onfratyrrs (ardhasarvanngassana) = the be
# afr (ardhasalabhaasana) = the hal€locust posture
# anvinw (ardhoruka) = (n) half-pant
#
# anyivwT (ardhorukam.h) = (n) half-pant , shorts
#
# oulderstand posture
#
# safftr (arpita) = surrendering
# athe (arbhaka) = small
#
# rts (aryamaa) = Aryama
#
# orf (arha) = deserving
#
# sft (arhataa) = (f) qualifeation
#
# ref (arhati)
# rift (arhasi)
# 3 (alaM) = especially
# ‘nkaaradiiptaMt) = shining with adornments, decorations
# decorated / ornamented
# ho fooling that it is impossible to see reality
#
# pp) to deserve
#
# RTA (alakShamnana) = one who disregards
# arefim: (alakShmiFl) = poverty (alaxmill is opp. of laxiniFf)
# rire (alia) = (adj) flee, untrue
#
# STATYZT (aloluptvaMt) = freedom from greed
#
# eT (alpa) = small, letle
#
# Fe (alpaM) = a few, little, inadoauate
#
# srengr (alpadhii) = mental deficiency
#
# SeTEET: (alpabuddhayalT) = the leas intelligent
#
# retineat (alpamedhasnaM) = of those of small intelligence
# SFeTTTEE (alpavayaskaM) = young (small) ago
#
# FeTT (alpaays) = Short life between 8 and 32 years
#
# area: (avachyaH) = unblamable
#
# arvarsfor (avajannanti) = deride
# STITT (avataara) = a divine incarnation particularly of Vishnu, e.g- Buddha
#
# 19
#
# Extracted Text from Page 20:
# becomes established
#
# srr: (avadhyal)
# SFT (avana) = protection
# raft (avaniM) = oarth
#
# srafrort (avanipaala) = of warrior kings
#
# the daughter of the Barth (sits)
#
# SFTFETT (avaruddhavoga) = retardation
# TERE (avaruuNaddhi) = to obstruct
# SETHEPT (avarohati) = to descend
# af (avalipta) = proud, haughty
# rae: (avalehaH)
# arafaeT(avashishhynte)
# sree (avashoshhaNa)
# STE (avashhTabhyn)
# automatically
# TT pl. imperfect of vas, to live
#
# SFTHT:_(avasarall) = (m) opportunity, chance
# srerti (avasarpati) = to slide (as from a waterslide)
# SFTATEIT (avasnadayet-h) = put into degrade
# SrTRET (avaathna) = a state of the mind
# srTeIrt (avasthaatuM) = to stay:
#
# emt: (avasthantrayaHt)
# afer (avnathitaM)
# safer:
#
# tiaree states of bodily consciousness (awake, sleep, dream)
#
# srafheart(avasthitann.h) = arrayed
# srayrené (avahaasaarthaM) = for joking
# ‘contempt
# without proper attention
#
# srTTeT (avaachya) = unkind
#
# SRT=TaE (avnaptavyaM)
# SFT (avasptuM) = to achieve
# srarertit (avaapnoti) = gets
#
# 0 be gained
#
#
# Extracted Text from Page 21:
# sear (avanpy)
# STAT (avanpyate) = is achie
# SrT=TE (avanpayatha) = you will achieve
# srereeafr (avaapayasi) = will gain
# rfewett (avikalpens) = without division
# afrerd: (avikaaryaH) = unchangeable
#
# - thoughtless
#
# achieving
#
# of one who does not know
# ‘metaphysical ignorance
# srfegtt: (avidvas.nsaHl) = the ignorant
# safefirrhe (avidhipuurvakaM) = in a wrong way
# FfrrrTt (avinashyantaM) = not destroyed.
# sft (avinnasha) = wndestrictible, name of Vil
# safemifz (avinanshi) = imperishable
# ssferifet(avinaashinaM) = indestructible
# sefrtfer: (avipashchitalt) = men with a poor fund of knowledge
# saferet (avibhaktaM)
# saferfa (aviratl) = sensuality
# atfring (avirodha) = no oppositi
# frie (aviGYeyaM) = unknowable
# SFR (avekShe) = let me see
# Fier (avekShya) = considering
# (aaj) Megat
#
# wattaatch) = protect me from the northern direction,
# onmanifested
#
# onmanifested
# rarer: (avyaktall) = invisible
# sroreraffat (avyaktamurtinas) = by the unmanifested form.
#
# toward the tnmanifested
#
# SOTETT (avyaktantsh) = to the wnmanifest
# srarerrétft (avynktandiin’)
#
# ithout division
#
# in the beginning unmanifested
# ‘without any break
#
# sroreTt: (avyayavargall) = the class of indeclinable words
# srorUre (avyaynsy)
# stort (avyayiibhanva)
# srarenrfeat (avyavasaayinaaM) = of those who are not in KRishhNa consciousness
# SRATPTT (avyaakRitas) = not expressed
#
# a
#
# Extracted Text from Page 22:
# are (asha.nks)
# Sra (ashakta)
# SrweT: (ashaktalZ)
# arat (athana)
#
# SFR: (ashamal
# SFFTTT (ashayant-h)
# SFT (ashasteaM)
# SFAT=TET (ashaantasya) = of the unpeacoful
# FTE (athaashwvataM) = temporary
#
# SFETET (ashaastra) = not in the scriptures
# safer (ashishhya) = untonchable (adj)
#
# safer (ashishhyaaya)
#
# to the unclean
#
# from their source
# shout being fully equipped
#
# non-disciple Le.non-believer
#
# to one who is not engaged in devotional se
#
# Stare (athoshha) = total
# arrUT:  (asheshhatalt)
# aru (asheshhaaNi)
# SFR (atheshheNa) = in deta
# STATE (athochyaan.h) = not worthy of lamentation
# FATE: (athoshhyalf) = not able to be dried
#
# SETH: (ashnatadt)
# S72 (ashnan.h)
# =P (ashnanti)
#
# FIT (ashnute) = achioves
# ‘= (ashma) = stone
#
# SEEMT (ashraddhayan) = without faith
# aq (asheu) = (n) tears
#
# SETHET (ashruupuueNaskula) = full of tears
# andi (ashraushhaM) = have heard
#
# SFTATET (athlaaghya) = adj. virtucleas
#
# 2
#
# Extracted Text from Page 23:
# SPER: (ashvatthaHl) = the banyan tree
# SPERTTAT (ashvatthaamas) = Aevatthama
# FEAT (ashvamedha
# SPETTt (ashvaansaM) = among horses
#
# ‘form of sacrifice where a horse is sent around to estiblish supremacy
#
# safer (ashvini) = a mudeaa, contraction of the anal sphincter muscles
# safeat (ashvinau) = the two Asvinis
# FE (ashhTa) = cignt
#
# EATTTTT (ashhTadalakamalabandha) = eight-petalled lotus pattern, a form of bandha
# poetry
# set (ashhTadhaa) = eightfold
# FETE (achhTandasha) = eighteen
# ETE (ashhTanvakra) = name of a deformed(at eight places) sage
# SEITATET (ashhTottariidashaa)
# chooses it secording to certain eriteria
# inTau) =
# SSTFTT (ashhtakavarge)
# upon planetary pos
# SITET (asannyasta) = without giving up
# SFATTT (asa.nyataa) = unbridled
# thayaM) = undoubtedly
# ashayaH) = beyond « doubt
# ‘unattached
# SrUT (asaktaM) = with
# arr: (ataktall) = withos
# arravafg: (ssaktabuddhill) = having unattached intelligence
# SFUTTEAT (aeaktantmas) = one who is not attached
# srafet: (osaktift) = being without attachment
# SATT:_(asa.nkhyaHl) = (m) countless
# ETPFEMT (naa.ngashastroNa)
# SFT (asat-h)
# Ser (asatalt)
#
# ‘A lunar based Dasha system tres 108 yr cycle and one
#
# predictive method of Astrology that uses a system of points base
#
# by the weapon of detachment
#
# armnd: (asamarthall) = unable
# SFTOTETT (asampenGYanta
#
# aTETE: (asammuuDhalt)
# SRFETET: (atammuuDhaalt)
# STE: (atammohall) = freedom from doube
#
# unconscious samadhi
#
# 2
#
# Extracted Text from Page 24:
# rat (asnaraMt) = worthloss/without essence
# rarer: (asnavandityaH) = asau and AdityaHf: this(person) and Sun,
# you are
#
# sxfire: (asitaHl) = Asi
# fener: (asid-hahyoH)
# fret (asiddhau)
# Sy (asukhaN
#
# failure
#
# SAYTM (asuraaNaaM) = of demons
# SET (asuraan.h) = demons
#
# 1) = fall (set)
# stroyed , vanat
# SreHaT (astamavelan) = (fem) evening twilight
# safer (asti) = (2 pp) ie
# ST (stu) = there should be:
# Se (asteya) = nonstealing
# SFT (astra) = Weapon
# safer (asthi) = Bone
# arferrerTm (aethipaJNjaram.h
# safeet (asthiraM) = unsteady
# SFETHT (aiparshana) = not touching
# SEE (asmad.h)
# rere: (asmadiiyaiff) = our
# SFPHTH (asmankaM)
# SPATE (asmaat.h)
#
# (0) setoton
#
# SFeTRTT (aevasthataa) = illness
#
# By
#
# Extracted Text from Page 25:
# tendency to identify oneself with external phenomena, "the maker’
# goism, selfishness, ignorance
#
# 5) = roron (atonyan of hia)
# Stier: (abit) ~ ene
# “efeqi"Fe: (ahituNDDilall) ~ (m) a snake charmer
# SPOT (ahatukaht) ~ without eauee
#
# lay and night
# (aa) incapable
#
# Snr (akShama) =
# SRet (akShayaM)
# SneT: (akShayalt)
# SRT (akShara)
#
# srt (akSharaMt) =
# SRT (akSharalt)
#
# rar (akSharaaNanM)
# sre (akSharaat.h) =
#
# am: (aGYaH)
# HTT (aGYatan)
# SHIT (aGYaana) = ignorance
# srart (aGYaanaM)
#
# ara (aGYannajaMt)
# srarTert (aGYaanasambhutaMs)
# STW (aGYannasM) = of the foolish
# SFaFT (aGYaanena) = by ignorance
# mT (
# SFINHT (aa-+ghras) = to smell
# STITT (antchar.h) = to peactice
#
# from
#
#
# Extracted Text from Page 26:
# HTFTT (an-yaa) = to come
#
# STATE (an4-rub.h) = to climb
#
# orm (aaudau) = in the beginning
#
# Herat (aa.ndolana) = movement
#
# sifare (aa.nshika) = partial
#
# ar (anHl) = to sit
#
# samt (aakarNa) = towards the ear
#
# aHTmTTIAT (aakarNadhanuraasana) = the shooting bow posture
#
# samt (aakarshha) = attracted
#
# ‘sTehyt (aakaa.nkShaa) = wish, ambition
#
# (mase) form, shape
#
# SHTeTTaTT (aakaaramaana)
# = (0) doorbett
#
# aera (ankaasha) = other
#
# saerafert: (ankaashasthitall)
# ‘aera (eakaashaat-h) =
#
# uated in the sky
# 1.S)from space oF
#
# aarp (aakula) = full of
# sarpferrt (ankulitam.h) = sad, worried
# apt (aakMitini) = forme
#
# SET (aakRishhTa) = (past part, of an + KRREsbh) attracted
# SITE (aakeam.h) = to attack
#
# ITER (ankramaNa) = attacks
#
# SITT: (aakShepall) = (m) insinuation, opposition
#
# PT (aakhu) = mouse
#
# doseribed
# sarong (onkhyaahi) = please explain
# STTOHT (angachehhet.h
#
# ‘one should come
#
# Prat
# nglabhanshhas) ~ English language
# rer (anchar-h)
#
# Serer: ancharatalf) ~ ating
# srrevit(ancharat) = he doce
# TET (ancharsan.h) = performing
#
# 10 behave, interact
#
#
# Extracted Text from Page 27:
# sareTT:  (anchaaraH}
# Tart (anchaarya)
# STITH) (anchaarya(F)
# SrreTt (anchaaryaM) = the teacher
# arava: (anchaarynall) = teachers
# SHYTTHT (anchaaryaan.h) = teachers
#
# approaching a bona fide spiritual master
# fn) covering sheet, chaddar
#
# STATTTTG (aajaanubaahuM) = the one whose arms extend upto his knees
# TT (aajyaM) = melted butter
#
# samTy_(anta.nka)
#
# ready
# ‘rt (aattha) = have spoken
# Sart (antmaa) = of the self
# Stree. (antmakaM) = consisting of
# SET: (antmakal}
#
# SETWTTHTT (aatmakaaraNaat:h) = for sense enjoyment
# Sar (astmaja)
#
# SETH: (aatmajalt) = son
# STAT (antmajaa) = daughter
# STATA: (antmatRiptaHt)
# SETH (antman.h) = So
# ETAT (antmana
# STA? (aatmanaHt)
#
# posiessing oF controlling
#
# eitluminated
#
# (sfaseinate-sing.) thro’ the self
#
# arts
# by My internal energy
# by My internal poteney
# pleasure in the self
#
# SATA. (aatmayogeat-h)
# srrerrit: (aatmaratiFl) = tal
# uated in the self
#
# ‘under one’s control
# SETaTT (aatmavaan.h) = established in the self
# rrfefrag: (aatmavinigrahall) = self-control
#
# Ea
#
# Extracted Text from Page 28:
# muutayaH) = personal opulences
# ') confidence
#
# of controlling the mind
#
# sree: (antmasa.nstutill) = and praise of himself
#
# SATE. (antmasa.nsthaM) = placed in transcendence
#
# SATAN (aatmasaat.h)
#
# SITET (aatmahatyas
#
# SETEATT (aatmaGYaana)
#
# TT (aatmaa) = soul
#
# araroTeTft (aatmas.atattvamasi) = Thou art That Not (self + Self are differnt:Dualiey)
#
# he mind
#
# in the pure state of the soul
#
# sararenifirt: (aatmansambhavitasHl) = selfcomplacent
#
# ssiferaT (antmiyntaa) = the feeling of onencas
#
# to imbibe, to make one’s own, to train oneselt
# ieide
# knowledge of self
#
# i) = beginning
# nf (aadiM)
#
# ome: (aadiFf)
# arrfeett(aadikartre) = to the supreme creator
# amrferg(andikeshhu) = ote ote
#
# sree (andy) = a name of Sun, Vishnu is among twelve Aditya
# artfere: (andityall) = the Adityas
#
# smtferemt(andityagataM) = in the sunshine
# srfemrem_(anltyavath) = lke the rising sun
#
# srffereet (aadityavarNaM) = luminous Uke the sun
# srtferar®_(andityaan.h) = the twelve sone of Adit
#
# snterarat (andityaannaMt) = of the Aaityas
#
# sree (andidevaM) = the original Lord
#
# sf&=@: (andidevall) = the original Supreme God
#
# (Masesloe.sing.) the fest
# SHTeTe (andhateva) = fix
# arent (andhaaya) = resigning
#
# 28
#
# Extracted Text from Page 29:
# anfirtr (andhikyn)
# anfircre (andhipatya) = overlordship
# anfrtt (andhipatyaM) = supremacy
# srrortere (aadhynatmikaM)
#
# STAT (aanana) = Paco
# STF (aananaM) = face
# TF (aananda) = happiness
# STAT (aanandana) = happiness
# area: (aanandamayatl)
# arate (aantaradeshliya) = within the country mainly for transaction?
# arora (aantarjanlaM) = (n) internot
#
# SHE (aap-h) = to obtain
#
# TT (aapalt) = water,
# ‘TF: (aapaNaH) = (m)
#
# I of great happiness
#
# Tost (aapannaM) = achieved
# sre: (aapannaalt) = gaining
#
# STE (wap) = water
#
# sarge (aapuryamaaNaM) = always being filled
#
# TPF (aapuurya) = covering
# ke leave of
#
# ‘The Sed, Oth, Oth and 12th Houses
#
# sar[at (aapnuynaM)
# sarttat (onpnuvanti
# sarah (napnoti) = achieves
#
# ramet (anpravaasi!) = (m) immigrant
#
# SETA (aaplutas) = immersed
# ‘Ter (anbda) = year
#
# »gnostication, also varshhaphala
# tavanaat.h) = up to the Brsbmaloka planet
# (2) ornaments, jewellery
#
# ampere (aabhansaM) = the original source
# STATT (aamanaska)
#
# Sarre (aamaya)
# STTTTT (aamraphalam.h) = (a) mango (the king of fruits)
# SITET (aamla) = sour
#
# he mind free from desire
#
#
# Extracted Text from Page 30:
# ‘rt (aamlaM) = (n) acid
#
# ‘TET (aayatam.h) = (n) rectangle
#
# arama (aayanaa.nsha) = Precession of Equinoxes, Used to convert Tropical positions to
#
# Sidereal
#
# SHreTT: (aaynatall) = (mm) import
#
# SFTETTT (aayaatana) = abode, resting place
#
# TE: (anya) = [long] life
#
# TEE (aayudhaM) = weapons
#
# TEeT=t (aayudhaanaaM)
# rake) = Significator of Longevity which is Saturn
#
# (2m) commision
#
# crying out of desperation for help, ritual
#
# saree (aarabdhat.h
#
# saree (narabdharn.
#
# HTT (aarabhate)
#
# ogun
#
# ion in the beginning
#
# (en) policeman
# (9 policewoman
#
# ITE (aaruDha) = The sign which is as distant from the lord as the lord is from the house
# concerned
#
# SIFT: (aarurukShoH) = who has just begun yora
#
# sre (ear
# sreett (nar
# reat? (anruuDhaani)
# STATE (anrogya)
# SEIMOEATE (anrogyashanstea) = hygeine
# TMT: (aaropatl)
#
# ort (ancta)
#
# fer (aardita)
# STF (aardea) = wot
#
# Extracted Text from Page 31:
# ofa (aardratan)
# argh (ane)
#
# TF (aarys)
# srrimen(naryaeamaaja) = Aryan group
# airat (aaryaa) =
# saret: (aarhaatl)
# Tree (lamba) = support
# STEER (alambate) = to recline
#
# ones
#
# Sixth nakshatra
#
# ) a respected! woman
#
# snfargfi (aall.ngati) = to embrace
# STATE (anlokyalckhanaM) = graph
# to think, to contemplate
#
# quarters
# form or incarnation
#
# overwhelmed
# fee: (aavishhTaHt) = overwhelmed
# satfefirt (aavikShita) = descendent of avikshit
#
# .e, marutea)
#
# sagt (aavRitaM)
# SET: (aavRitaHt)
# SET (aavRitaa)
# STEM: (anvRitanH)
# (oawniteing)
#
# to wish, to hope, to desire
# HTT (aashaya) = (mase) resting place
# srrafeenr: (aashayasthitaalf) = situated within the heart
#
# a
#
# Extracted Text from Page 32:
# ‘aTaTTTH (aashanpaasha) = entanglements in a network of hope
#
# arrmfevt(aashaapiNDaM)
#
# nfs (anshita) = (a) Baten, given to ent;
#
# anfat (aashitaM) = eating
#
# nfs (anshina) = old (also heard as asi
# 0 give aashievaad,
#
# AshA-+pindaM, desire +lump(piNDaM also mea
#
# STIPE (aashulkaM) = (n) import duty
# Tet (aashcharyaM)
# caret (aashcharyamayaM) = wonderful
#
# with wonder, surprise
#
# sare (aashcharyaaNi)
# SITET (anshrama) = a yoga centre oF school
# dependence, leaning
#
# all the wonders
#
# srat (aashrayan)
# TTT (aashrayet-h)
# wife (anshi) = to take shelter
# Mt) = aseuming
# refuge
# accepting
# shelter of
#
# (0) assurance
# STRPPETETH (aashvansayaamansa) = encouraged
# snfet (aashvinii) = First nakshatra
#
# [THTRIE (aasanastham.h) = (lotus lke.)posture.stood
#
# TFT (aasane)
#
# aTMTET (ansandaya)
# (oasandya)
# (asit.h) = was/existed
# (aasina) = by the weapon
#
# rere
# ante
# ante
# anfet (aati
# antes:
# amit
#
# nthe seat
# (causative of aa-+sad) resort to
#
# (easinalf) = eaters
# (easiitch) = was
#
# 2
#
# ce-ball given
#
# Extracted Text from Page 33:
#  (aasiinalt)
#
# SAT (ansurad)
# Sarr: (aasural)
# sarqrfreart(aasuranishchayaan.h) = demons
# SATA (aasurii) = demonine qualities
#
# atheistic
#
# (6) confidence, interest
# following
# ‘boing situated
#
# Fm _(ichehh
# ‘Fuf (ichehhati)
#
# resent participle of ish, to wish
# performed
# by worship
#
# Far (iDaa) = the channel on the left of the spine
#
# FE (jDyaM) = worshipable
#
# TFT: (ital) = besides this
#
# TFT (itara) = Other
#
# TET: (itaralf) = common
#
# Extracted Text from Page 34:
# ‘mutual, each-other
#
# (Gndecl) here and there
#
# [FATETR(:)_(itihaasa(H)) = history; epic
# Fee (itthaM) = lke that
#
# ‘wert (idaaniiM)
# FT Gani,
# FF (inaw)
# FF (indraHf) = the god Indra
# {FETT (indeachaapa)
#
# iiyagocharanll) = the objects of the senses
# [SPURT (indriyngraamaM) = the full set of senses
#
# ‘epee (indriyajaya) = mastery of the senses by controlling the desires
# ‘Topaea_(ndriyasya) = of the senses
#
# ‘parent (indriyasyaarthe) = in the sense objects
# ‘eyarat_(indsiyaaNaaM) = of the senses
#
# opaifr_(indriyaaNi) = the senses
#
# oparrtm: (indriyaaraamalt) Jed in sense gratification
# brunet (indriyaarthaan.h) = sense objects
#
# forarihet: (indriyaarthebhyalf) = from the sense objects
# aorarity(indriyanrthoshhu) = in sonse gratification
#
# rie: (indriyebhyall)
# PFE (indrivaitt)
# FF (indro) =
# 67 (indhana)
# ‘et (imaNt) = (from
# ‘ear: (imaakt) =
# ‘ET (imnan.h)
#
# more than the senses
#
# by the sensor
# Lord Indra
# fuel
#
# Just lke or as if
# Fat (lshat.h) = a little
#
# TFA: (ishhubhiFl) = with arrows
# FE (ishhTs) = of all desirable things
#
# au
#
# Extracted Text from Page 35:
# FE (ishhTwM)
# err: (ishhTaalt)
# Fert (ishhTaan.h)
# fet (ishhTikna)
#
# od
# et (lidRishhant)
# fect (irshiyyan)
#
# E87 (lishvarn)
# E8t (lishvarant)
#
# ShaNaM)
# Ear (iikShate) = (1 ap) t0 see
# Fer (uktaM) = sai
#
# Fer: (uktatt)
# ETT: (uktank) = are said
#
# infu activi
#
# ‘FATT (ugraasana) stretch posture
#
# 3: (ugraifl) = by terrible
#
# TSR (uchchaars) = prom
# TOME (uchchaarya) = having uttered oF pronounced
# Te (uchchailty
#
# FRATH (uchehalffahravasaM) = Ucesiharava
# eq (uchehha) = Exalted Planet
#
# ition,
#
#
# Extracted Text from Page 36:
# ‘yoqe (uchchhabda) = loud sound (masc)
# “SPST (uchchhishhTaM) = remnants of food eaten by others
#
# RET (uchchhoshhaNeM) = deying up
#
# afegA (uchehheiteM) = high
#
# Tee (uchynte) = ie said
#
# FTF (ulivala) = radiant
#
# aprraft (ubDaayayat) = to fly
#
# APT (uDDiyaana) = a fetcer oF binding involving the raising of the diaphragm
# ) = it in anid
#
# FRET (utkaTaasana) = the the hunkering posture
# RTE (utkaNThayaa) = (instesing.) feelings
# AFIT (uthRityamaana)
# FEE (utkRishhTa) = excellent
#
# FET (uthochakl) = (m) bribe
#
# TeRPT (utkraanti) = evolution
#
# ‘TeRT (utkenamati) = gives up
#
# ‘TERT (uthraamanteM) = quitting the body
# ‘THAAT (utta.ngatas) = greatness
#
# FAR (uttama) = exceptional
#
# me who is ent up.
#
# Ft (uttaraM) = covering
# aeraifert (uttaradaayitvaM) = (2) responsibility
#
# FATET (uttararuupaM) = having it in the northern direction.
# aerrarertr (u i) = Twolfth nakshatra
#
# TATENETE (uttaranbhandrapada) = Twenty-sixth nakshatra
#
# FATT (uttaraayaNaM) = when the sun passes on the northern side
# FATT (utearaashhaDhaa) = Twenty-first nakshatra
#
# ‘FATT (uttaana) = an intense stretch
#
# “aFme (uttiehh Tha) = got up.
#
# ‘afrer (uttish
#
# TAF (uttu.nga)
# ‘Fe (utthaM)
# ‘fear (utthita) = stretched
# aframt (utthitas) = present
#
# eh (utpattt) = production
#
# FR (utpad.h) = to obtain
#
# FTF (utpannaM) = produce
#
# afer (uepaaTin.h) = (mase) pullerup
#
# {aranphia
#
# Imp.lt P.pLPP)get ups
#
#
# Extracted Text from Page 37:
# TEA (utpandashulkaM)
# ehfemT (utpiiThikan)
#
# HAT: (utprapantaHl)
# err (utpravaasii)
# ere (ueplavate)
# FAT (utsanna) = spoiled
#
# (Mfae.Nom.sing.) festival
# rarernt (utenadanaarthaM) = for the sake of eausing annihilation
# FATE (utsandyante) = are devastated
# FAT (wtsnahia) = onthusinam
# {slideyult) = would he put into ruin
# ive up.
# send forth
#
# () water
# fe (wdadhi) = son
# FET (udapaane) = in a wll of water
#
# ET (dara) = generous
# FETT: (udanraaHt) = magnanimous
# seh (a
#
# sat:
# TEETE (udaabRitya) = i
# erty (udlitchii) = (f) north
# ETAT (uduudashan) = Vinshottari Dasha
# ESEAT (udgachehhati) = to overflow
# [FATT (udgnara) = expression
#
# a
#
# Extracted Text from Page 38:
# to dcaw up (water fom a well)
# FET (uddharet.h) = one must deliver
# Far (ddhaaraNs) =
# ‘T_T (uddhRitaM) = that which had been lifted
# ETI (ddhvahanut) = she whos hearing oF carrying the load
# FFF (udbhavaM) = produced
# ‘onaetion
# lined
# FETT (ndyatanlf) = trying
# EF (udyama) = industriousness
# ORT (udyamena) = (mtcinteS) offort; exercise
#
# (m) gardener, mali
#
# iyogin.h)
# Fat (udvarta)
#
# 3a (udvasha)
# HAT (advice
# HET (udvijeth) = become agitated
#
# (m) project, undertaking
# ITE: (upagraball) = (mn) satellite, spacceraft
# ITE (upachayn) = Houses of earning (2,0,10,11)
# TTT: (upachaarsH) = (m) remedy, treatment
# aTifreT (upachaarikaa) = (f) nurse
#
# FATT (upajaayate) = takes place
#
#
# Extracted Text from Page 39:
# ‘FraTET (upajnayante) = are born
# ‘FrTBET (upnjuhvati) = offer
# VET (upadaanaM) = (n) gratuity
# AEH (upadesha) = advice
# Wm: (upadeshalt)
# ita (upadeshay
# air (upadekShyant!
# FVFET (wpadrashhTaa) = overseer
# TET (upadhaanam.n) = (2) pillow
# RATT (upadhaaraya) = know
# TUT (upanagarain.h) = (a) suburb
# TTT (upananma) = alias
# ARE (upanishhit.h) = says the Supanishat.
# ZAPF (upanishhad.h) = the philosophical parts of the Vedas
# ATT (upaneteam.h) = (n) spectactes, glasses
# FTAUTTe: (upanyaasakaF) = (m) lecturer
#
# having obtain
# ign which is as apart from the 12th lord as the latter
#
# advice
#
# from the 120,
#
# THOR (upapadyate)
#
# TTF (upapannad)
# TEA (upabandhal)
# HHT (upabhoga) = consumption
# TF (upamaM)
#
# RT (upamaa)
# emer (upayaan
#
# compared to
#
# comparative
#
# et (upayogitas) = Utility
# ITH (uparataM) = consed
#
# ATATE (uparanjitaitt)
# 97H (uparamate)
#
# splendid, resplondant
# cease (because one feels transcendental happiness)
# ‘one should
#
# ‘TTHTT (upalablyate) = can be perceived
# THAT (upalipyate) = mixes
# FATT (upavastu) = (a) by-product
# afefe: (upavidhiFt) = (ma) by-law
#
# sat down again
#
# AE (upavishhTha) =
#
# Extracted Text from Page 40:
# THTET (upasevate)
# TERT (upasthaa
# THA (upasthe) =
#
# (2m) Iubeicane
#
# aries (upandhitt)
# IF (opaaya) =
# ATT: (upanyataHl) = by appropriate means
# 3947 (upaarjana)
#
# ‘FerEaT: (upaashritaslt) = being fully
# ‘FerEe (upanshritya) = taking shelter of
# FATE (upstate) = worship
# FUATTTE (upsahaaragRiha) = restaurant
# FUETTET (upaahaaragRiham.h)
# FAT: (upetaHl) = haaving reached or at
# FHT (upetya) = achieving
# disregsed
#
# FAH (uruka) = (n) pant
# ahit (urjitaM) = glorious
#
# “0
#
# Extracted Text from Page 41:
# FHT (uvancha)
# Baar (ushanas) =
# afeeaT (ushhitvaa)
# 5 (ushhTra) = a camel
# 5: (wehiTeaHt) = (m) camel
#
# FETA (ushhTrapakShit) = (m) ostrich
# FETT (ushhTrassana)
# eT (usihNa)
#
# after dwelling
#
# Far (auyate)
# FE (wun) =
# FF: (wurwult)
# HF (witha) = (P) enceey
# aT: (asNannabhaHl) = (m) spider
# Bet (uurNaa) = (f) wool
#
# x ‘alse
#
# redhvamukha) = face upwards
# wetrr: (wurdhvaretalt)
#
# “FOnEATTATAT _(wurdhwvahastattanaasana)
#
# FE (iu
# FT (RNa)
# TT (RiNapatraM) = (n) debenture
# eT (RitaM) = truth
#
# RT (Ritu) = seasos
#
# RTH (RituunaaM) = of all seasons
# BRT (Rite) = withour, except for
#
# BRE (RiddhaM) = prosperous
#
# a
#
# Ihvaprasaaritackapaadaasana) = balancing forward posture
#
# celibate intending to control(upward) the semen
#
#
# Extracted Text from Page 42:
# erent sages
# by the wise sages
#
# OF: (okalt) = one
# TTR (okatvaMt) =
# THT (chatvona)
# FET (ckada.ntaM)
# UFEATT (ckadasntaaya) = to the one-tusked
#
# TETEE (ckamakSharaM) = pranava
#
# TeAmfett (ckamovandvitiiyaM) = one without a second
#
# fone who his a single tase
#
# emt (ckasthaM)
# TefeT_ (ckasmin.h) = in one
# Tyr: (ekaaH) = one
#
# aT (ckaakii)
# RTT (ckaagra) = one-pointed
# with one attention,
# with fal
# TTRTAT (ckaantaM) = overly
# TAT (ckaskSharaM) = the one syllable
# TR (eke)
# TT (ckena) = alone
# DF (chaikaM) = one by one
# TERS (claikamakSharaM)
# T¥TEE (cko.ahaM) = T the one single being
#
# coach and every word
#
# TTA (etann.h) = all these
# ‘Tm (etaaniy = all these
# TET (etaavat.h) = this much
# ft (oti) = atta
#
# Th (ote) = they
# TT (etena) = by ein
#
# 2
#
# Extracted Text from Page 43:
# ‘Rat (eteshhaaM) = of the Pandavas
# OR: (etait) = all these
# ‘Ta (edhate) = (1 ap) to grow
# ‘ath (edhan.nsi) = Brewood
# TT (enaM) = this
# ‘ft: (ebhiFt) = by them
#
# to these demigods
# 1d t0 put emphasis )
# it (evaM) = thus
#
# Jnvarya) = desire for power
# STETIAT (o.nkaraasana) = the OM posture
# THT (ajant) = concentrated paychic power
# SHTAT (ojataa) = by My energy
# sre (oshhati) = (1 pp) to burn
# stifine (audyogika) = industrial
# by comparison
#
# = bracelet
# anyone (oF someone)
# (Mase.Nomsing.) throat
# ‘neck
#
# RE (ka.nThe) = in yhe neck
#
# a
#
# Extracted Text from Page 44:
# (inate) tortoise
# amp black
# STR: (laJNehulall) = blouse
# ‘Fer (ka TAHT) = (m) earpot
# ‘Fen (kaTaakSha) = glance
# we (kai) = hip
# ‘wie: (laTiH) = waist
# ‘sews (kaTitnasana)
# HETERE (kaTivasteam.h) = (n) underwear
# int
# (2) pungent, hot
# a) = tougl
# small bie
# [FIT (laNatvn) = particularity
# ‘wfrerirar (kaNikaapiitas) = little droplet, drunk
# ‘Tar (kaNiiya) = particulate
#
# thorns
#
# fm) throat, neck
# ROE (kaNThabhuushhaa) = (f) necklace
# {RORT: (kaNThahsaralf) = (m) necklace
#
# ‘weytit (kaNDuuyati) = to scratch
#
# RET: (laNDolalf) = (m) a wooden basket
# [FATT (lataratih) = whieh
#
# Fe (athe)
# HET (kathanta)
#
# ‘UT (kathayate) = (10 up) to narrate, to tell
# re: (lathayantaHt) = talking
#
# ‘waferafoT (kathayishhyanti) = will speak
# ‘wafeentft (kathayishhyaami) = shall speak
# ‘Far (hatha) = story
#
# [RITTT (kathaamRita) = Gospel
#
# TRIAT (kathaamRitaM) = Gospel
#
#
# Extracted Text from Page 45:
# = (n) banana
#
# weet (kadai)
# weiter (hada
# ‘Fer (kadaa) = when
# ‘WEET (hadanchan.h)
# {WeTeT (kadaachana) = at any time
# ‘warfet (ladaachitsh) = at any time (past, present or future)
# ‘waft (kndaapi) = at any time
#
# TT (kanaka)
# ‘withrer (kaniinikas)
# Fe (lanTha)
# (Ganthatt)
#
# ilaM) = banana oil
#
# (m) root
#
# laasana)
# EF (landuka)
#
# ‘FAT _(Kanyaa) = Zodiacal sign Virgo
# FICHT:  (kapwTayogaHt) = (on) inti
#
# ‘wofew (kapaTika) = cunning, acheming
# FIT (kapataM) = (n) plot, conspiracy
# [ITT (kapaala) = forehead
#
# {FUT (apaalalf) = (m) human skull
#
# ‘worerft (kapaalabhati)
# [FIT=TT (kapaalnala) = fire in the forehead (227 again perhaps wrong)
# ‘FFF (kapi) = monkey
#
# ‘wit: (kapift) = (mm) monkey
#
# ‘FiTerm: (kapidlivajalf) = he whose flng was marked with Hanuman
# ‘FAT (lapota) = pigeon, dove
#
# FTTAT (lapotansana) = the dove posture
#
# process to clear the sinuses
#
# [FETTER (kamalapatenakSha)
# ‘ra (kamalas
#
# [FTATTTAE (kamalansanasthaM) = sitting on the lotus flower
# [FETT (kampate) = (1 ap) to shake
#
# ‘FeTaft (kampayati) = to shake
#
# (FT (kara) = Hand
#
# [FT (kara) = the cause of
#
# 0 lotus-eyed one
# raswat
#
#
# Extracted Text from Page 46:
# ‘Frain (karstalabbikShaa) = alms in the palms
# [FrTAR (keratalam.h) = (a) palm
#
# ‘Free: (karadtipall) = (m) torch, flashlight
#
# ‘FTA (karabhorw) = fair-limbed
#
# ‘FTF (karalaM) = terrible
#
# {FTTH (karavanla) = sword
#
# [Fret (Karavanvahai) = may we do
#
# [FTRTT: (karasthanHf) = oblaining(literally standing) in hie very hands
# [TATE (Laran.nshukam.h) = (n) fll-slooved shirt
#
# ‘TT (Laranla) = drondful
#
# ‘wire (katishhye)
# ‘rm: (karuNaH)
# ‘wre (karuNan)
# [Tort (karuNaakara.n) = the one induces compassion,
# ‘Frame (karuNaarNavaM) = the ocean of ‘karuna’ (compassion)
#
# the sentiment of sorrow
#
# witft (karoti)
#
# ‘witht (laromi
#
# ‘HTP (karosi) = you do
#
# ‘FAT (Jara) = hands (lower arms)
#
# ‘FF (larka) = The Zodincal sign Cancer
#
# HE GarkaT) = (f) eueumbor
# {FETT (karkarogatt) = (m) cancer
#
# ‘eh (kara) = car, also KarNa from Mahabharata
# wt (larNaM)
# swe (kara
# ‘wifeTTeT (karNapiDansans)
# ‘weferr (karNikaar
# switir: (karNebhifl
# ‘winfr (lartayati) = to cut
#
# ‘WHT (kartari) = (f) seissors
#
# ‘wt (kartavya) = should be done
#
# ‘whet (kartavyaM) = prescribed duty
#
# ‘wtenfr (kartavyaani) = should be done as duty
#
# ‘ent (kartas) = doer, also attributed to main person in a household
#
# rs
#
# Extracted Text from Page 47:
# ‘wit (kartanraM)
# ‘rt (kartuM) = to perform
#
# ‘wirffir (kartumarhasi) = kartuMt + ashasi:to do + deserve (You are entitled or you should)
# ‘wtrt (kartRtitvaM) = proprietorship
#
# ‘FET (karmajaM) = duo to fruitive activitios
# {FET (karmajaa) = trom fruitive work
# FETTE (karmajaan.h) = born of work
# ‘FET: (karmaNaHl) = than fruitive action
# ‘wer (larmaNaa) = by work
#
# ‘watt (larmaNaaM)
#
# ‘wet (karmaphalant) tivities
# ‘eherart: (karmaphalatyaagall) =
#
# ‘ere (karmaphalansa.ngaM)
# ‘THTT (karmaphale) = in feutive action
#
# {THTY (karmabandhaM) = bondage of reaction
#
# ‘WHeATT: (karmabandhanall) = bondage by work
#
# ‘Ter: (karmabhiff) = from the bondage ofthe law of fruitive actions
# ‘FEET (harmayoga) = unselfish actions
#
# ‘rit (karmayogaM) = devo
#
# {EET (karmayogall) = work in devotion
# ‘FATT (larmayogeNa) = by the linking process of devotion
# ‘SEETATT (harmasa-nnyansaat.
#
# ‘TiTfyTT (karmasa.nginaaMt)
# ‘TTF (larmasa.ngshiy)
# ‘wiinyT (karmasa.ngena)
# ‘FHT (Karmasu) = in all activi
# ‘wit (karmasNaM)
# ‘wviat (LarmaaNaaM)
# ‘waif (harmaaNi)
#
# nunctation of the results of fruitive acto
#
# in comparison to the renunciation of fruitive work
# ho are attached to fruitive work
# in the association of those engaged in fritive activities
#
# ion with fruitive activity
#
# dees
# ‘sfther: (karmibhyaHf) = than the fruitive workers
#
# ‘THPrT_(karmendriya) = an action organ, e.g. the hands or feet
# ‘witraifi (karmendriyaaNi) = the five working sense organs
# ‘THPFR: (harmendriyailt) = by the active sense organs
#
# {FE (karshha) = attracted, contacted
#
# {TE (harsh) = farmer
#
# fa
#
# Extracted Text from Page 48:
# (AlivayanukaraNa) like a iver flow
# ifleator of marriage partner which is Venus
# 1M) = of subduers
#
# fight discord /argumene
#
# FATE (kalatrakaaraka) =
# TUT (kala
#
# FE (lalaha)
# eT (Jalas)
# FAT (boalannaad
#
# T may be wrong here)
#
# the current, pleasure-oving age
# ‘wit (lalilaM)
# ‘FST (LalushhaHt) = smeared, blot
#
# dense forest
#
# the tree tha will give you anything you ean
# ...
#
# ATRTAT (cukRitasya) = pious
#
# TBF (eukRitiM = good deed
#
# {ATR (oukRitinall) = those who are pious
#
# ATA («ukRitinasM) = of the good-door
#
# TRF (sukRiti) = the man with good deeds
#
# the principle of goodness
#
# TT (sukha)
# TT (sukhaMt)
#
# ATT: (aukhalf) = and happiness
#
# ATA: (sukhatall) = for happiness
#
# RT (suklinda) = the one giving comfort
#
# Iuappiness and distroas
# ppinees, obtains
# (oven a little) happiness
#
# of the happiness and wealth
#
# (of) a man seeking
# ATRTET (sukhaasana) = the easy posture
# {TRTTT (cukhaasanam.h) = (n) a reclining chair, rocking chai
# fet: (eulhinal) = happy
#
# (oui) = happy
#
# ATR (sukhe) = in happiness
#
# {THT (sukhena) = in transcendental happiness
#
# TRY (sukheshhu) = i happiness
#
#
# Extracted Text from Page 208:
# at (sugandhing
# apt: (sugrliveshaH)
# erertnysrat (sughoshhamaNipushhpakau) = the
#
# sna) = good man
#
# rally meaning the one
# ches named Sughosa and Manipuspaka
#
# TTT (sutaa)
#
# ref (sudati)
#
# (fom.Ace. Sing)nectar
# Moon
#
# banka)
#
# (eudhaakhaNDadt)
#
# PTT (suniyamanaya)
#
# {fafet (cuniehchitaMt) = definitely
#
# AEF (oundara) = beautiful
#
# {APTA (sundariiM) = (sundari in objective case)
#
# ATT (euputen) = good son
#
# qaPeTT (supuuiitam.h) = well worshipped
#
# FT (supta) = asleep
#
# TTT AMTITT (cuptajsanushirshhaasans) = the supine head-knee posture
#
# qarTfeTeMTATHT (suptapaschimottanaasana) = the supine back-stretching posture
#
# AUTTETPETTT (suptapandaa.ngushh Thassana)
#
# ATRETHAT (suptabaddhapadmansana) = the supine bound lotus posture
#
# TMTATET (suptavajeaatana) = the supine thunderbolt posture
# benevolence
#
# Adnsharath’s wife, laeman’s mother
#
# ‘also with na, ya, ma, na, ya gaNaas
#
# the supine big toe posture
#
# the demigods
# of Brihagpati (the teacher of Gods)
# f) a small tunnel
#
# ‘groups of domigods
#
# TTT: (suragurokt)
# arf (sura.ngiha
# [ATNGT: (ornsn.nghaat
#
# ATE (surya) = A name for the Sun
#
# artier (curyod
#
# 208
#
# Extracted Text from Page 209:
# ‘qorafeant (suvynvasthitan) = well organised
#
# TA (sushilla) = of good character
#
# apaere (eushiilaten)
#
# ATAAT (sushumnan) = the spinal cord
#
# AYA: (sushhuptill) = deep sleeping
#
# {qyETT (ushhuptikaraNa) = hypnosis
#
# {TYAN (sushhuptiiavasthaa) = the state of the mind in dreamless sleep
# very happy
#
# sndowed with good smiles
#
# to well-wishers by nature
#
# ood charactor
#
# FET (sunt. n)
# IWT (ouhid.h)
# ARE (suhRidamt)
# TEE: (subRidalt)
#
# Ts
#
# to produce
#
# TAT (suukta) = good words
# TTT (suuchanaa) = suggestion
#
# FEET (suuchikas) =
#
# arg (suuchii) = (f) needle, Hist
#
# ATT (suuchiipatraM) = (n) catalogue
#
# ATT (euuta) = the chariot driver
#
# ATIF: (suutaputeal) = Karna
# thread
#
# = (8) spinning wheel, charkha
#
# TE (suutre)
# ATT (suuyate) = manifests
#
# yyalaanta) = Bfulgent lke Sun
# ‘TETE (suuryagRihe) = in the home of #1
# qpeaHRNT (cuuryanamaskaara)
# qTearTraT (suuryananraayaNa)
# TET (suuryavarchasvi
#
# (during the solar eclipse)
#
# aie: (snuryodayalt)
# {ART (eukShea) = minute, extremely emall, Keen
# [RETENT. (eu Shimatvaat.h) = on account of being subtle
# {ReTesre.(euhShmadarshakam.h) = (a) microscope
# errr (ek Smash
#
# aTafr (aRijati) = (6 pp) to create
# {ME (aRijanmi) = manifoat
#
# he asteal body
#
# 200
#
# Extracted Text from Page 210:
# arerim: (scchananaalal)
# HT (set) = a bridge
# TET (setukRitpaats) = may the builder of bridge (over the sea) protect
# TITTT (setubandhaasana) = the bridge posture
#
# ATE (sctuba.ndhanaM) = bridging
#
# aot:
#
# (m) a water-gun used during Holi, pichkaari
#
# fall commanders
#
# ‘ArTRTAT (sendriyamannasa) = sn+indriya+mAnasa, wwith senses and mind
# AT (sev-h) = to serve
#
# {RE (oval) = (m) servant
#
# ET (covato) = (1 ap) to sorve
#
# in) apple
#
# by the rendering of service
# rat (sovaa) = service
#
# ‘aT (sovaamahe) = (verb.Pr.t Per.PLLAtma
# ‘fare (sevitvaM) = aspiring
#
# ‘RFR: (sxinikaHt) = (mn) soldier
#
# ‘Heart (cainyaryn) = of the soldiers
#
# ‘Ter (ssishhas) = anasesbhA, that feminine form
# AE (soDhuM) = to tolerate
#
# {RTTTEE (sopaanam.h) = (n) staircase, steps
#
# IT (soma) = The Moon
#
# drinkers of soma juice
# ‘Monday
#
# tere (eaumyatvaM) =
# ETTT: (saumyavapull
# ‘for (snurabha) = fragrance
#
# TATE: (sauravy = (om) the solar system
# ‘mh (sauvarNa) = golden
#
# a0
#
# Extracted Text from Page 211:
# FRAT: (skandhall) = (m) shoulder
# PETA (ekhalanashiila) = adj.
# FT: (stall) = is
#
# ible to lapse
#
# Ibroasts that arofull-witl
# impudent
#
# (oot) to make immobile, to stun
# FIRE: (stambhadt) = (m) pillar
#
# TET (stambhiana) = Stationary planet
#
# FTF (stuta)
# IPF (stutty
# aFr: (stutiey
# ‘pine: (stub
# qeftr_(stuva.nt) = pra
#
# Fhe (steys)
# HT (states) = hymn
# itt (stotraM) = hymn
#
# IT (atotee) = in comporing & hymn
#
# TF (styana) = aloth
#
# HR (otranaate) = i aliping
#
# ‘erat (stravati) = (1 pp) to flow
#
# fora: (sriyalt) = women
#
# feraefre (striyashehartraM) = the charscater of « woman
#
# = Signifieator of wife or partner Venus
# by the womanhood
# uated
#
# ‘Rat (sthaa) = to stand
# ‘ar(PTeft) (athan(tishhThati)) = to stand
#
# [RITA (athaanaka) = (m) station, base
#
# au
#
# Extracted Text from Page 212:
# RITTE_(athaapaya) = please keep.
# ETTa?™ (sthaapayati) = to put, to keep
#
# ‘naryferar (sthaapayievaa) = placing
#
# ‘eaifarer (sthaalikan) = (f) plate, dish
#
# [RITET (ethaavara) = not moving
#
# [RITETIHT (ethaavaraaNaaM) = of immovable things
# ‘nareafir (sthassyati)
# fart (ethitaM)
# farm: (sthitalt)
# Prem: (ethitnahiitt)
#
# Na consciousness
#
# feerar_(ethievaa)
# fee (thiea) = fixed
# ferrite (athiraraashi) = Fixed Signs
# feet (sthieaMt) = frm
# fer: (othiralt) = stil
# fer. (othientan) = steadiness
# feergfe: (sthirabuddhitt)
# fret (sthiraaM) = stable
# fret: (thirsadl) = enduring
# an NkaHf) = (m) constant number /eai
# with frm oF strong (1
# ) strong, big
#
# intelligent
#
# PETAAT (sthuulashariira)
# neaetiegt («thuulasphaTiki
# Bh} (sthairyaM) = steadfastness
# ERITHTTe (snastakottara) = post graduate
# ‘ert (snaati) = to bathe
#
# [FIT (snaana) = bath, ablution
#
# a2
#
# Extracted Text from Page 213:
# [FITTS (snaanashills) = (metaphorically) pure
#
# FIFA (enaanagRiham.h) = (n) bathroom
# FT (snaayu) = sinew
#
# rrgferrt (snaayuvitananaM) = sprain
# Ferme (snigdha) = affectionate; also oily.greasy,
# Ferme: (enigdhaall) = fatt
#
# FTW (snushhaa)
#
# (f) daughter-in-law
#
# friendship (ol)
#
# [FFETT (enchaat-h) = (Mase.absolsing.) from affection.
# [FRET (enchona) = (Mase.instr sing.) through affection.
# FEET (epandate) = (1 ap) to throb
#
# FIT (eparshanaM) = touch
#
# .) = Longitude of planet or how
# to touch
#
# TAPE (opRishati) = (6 pp) to touch
#
# FPA (apRishan.h) = touching
#
# FE (spRiahhTwat) = (past participle) touched
# ET («pRihas) = aspiration
#
# fFerefret (aprihaNivaruupsM) = desirable form (personal appenrance)
# het (ephite) = (ad) prosperous
#
# afer (aphuTita) = overt
#
# (naava)
#
# FRITE: (ephotakaHt) = (m) bomb, explosive
# ‘FT (sma) = an indeclinable chat changes the sentence to past tense from present tense
#
# [FT (amayate) = (1 ap) to smile
# ‘Brit (smarati) = (1 pp) to remember, recollect
# FTTH (amaranch) = thinking of
#
# arti (amaraami)
#
# aft (omRi
# ‘maf: (amRitiFt) = memory
# ‘nyfraart («mRitibhea.nshaat.h) = after bewilderment of memory
#
# tt (omRi
# ‘IE (syandane) = chariot
# ‘raft (ayandiach) = oozing
#
# 213
#
# Extracted Text from Page 214:
# aT may be
# a ( will we become
#
# FE: (ey) = form from “auch” meaning “thove who may be”
# ram (in) a bag
#
# TTTTT (erotasaaM) = of fowing rivers
#
# Fr (ova) = Self
#
# FE (aM)
#
# in his own duty
# ‘ereciet (svakarmaNaa)
# sree (evakliya)
# ‘FITHTET (svachakShushhiaa) = your own eyes
#
# FETTAT (evatajasea) = by Your re
# ‘Far (evadeshn) = one’s own countey
# ‘ravi (evadharmaM) = your religious duty
# avi: (svadharmall)
# ‘Fav (evadharme) = in one’s prescribed duties
# ‘Fat (evadhaa) = oblation
#
# FET (tvana) = sound
#
# ‘eeqieTTT (svanushhThitaat-h) = perfectly done
#
# ‘Frit (evapati) = (2pp) to sleep.
#
# e's prescribed dt
#
# ‘er (svapnaM) = dreaming:
# FRA: (evapnaHl) = dreaming
# ereviraer(evapnashillasya) =
#
# 18) = the state of the mind
# = in dream,
#
# FETE (6vabhaava) = nature, persor
# ‘Fare: (evnbhaavalZ)
#
# eres (evabhanvajeM)
# FEWTTIT (svabhaavajaa) = according to his mode of material nature
#
# ‘FETT (svabhaavajena) = born of your own nature
#
# ‘FErrafrat (evabhaavaniyntaM) = prescribed according to one's nature
# renfraframmrafi (avamatipariNaamaavadhi) = according ¢o one’s intellectual capacity.
# PEt (evayaM) = herself
#
# 1 mental attributes
#
# haracteristics
#
# of his own nature
#
#
# Extracted Text from Page 215:
# FEErEPeT (evaysMprakaashite) = self.illumined like stars(Sun)
# ‘Feat (evayaa) = by their own
#
# Far (svara) = sound
#
# ETAT (evarandharan)
# FEET (evaruupa)
#
# EET (svaruupaMt) = form
#
# ‘eat (evarga) = heaven
#
# ‘rat (evargaM) = to heaven
#
# ‘emift (evargatiM) = passage to heaven
#
# [FRITTT: (svargaparaaHl) = aiming to achieve heavenly planets
# ‘eaare (svargalokaM)
#
# ‘erat (svaliilayan) = sva+Iflaya, through one's play-like action
# FRET (evalpa) = Ut
# Fret (ovalpaM) = a little
# FEETIT (evalpatantenM) = (n) oligarchy
#
# the understanding of oneself
#
# the prosperous posture
# ‘raferrerredt (crnstinastaatkShyo) = let ¢Arkshya or Garuda do good to us
#
# rafertt (svastinno) = good to ue
#
# ‘FRrE: (evasthaH) = being situated in himself
#
# ‘eee (cvasthaiff) = by healthy persons (je , healthy in minds , their minds being well
# ‘FRET: (evasyall) = by his own,
#
# FURET: (avahastall) = Signature
#
# [FRET (avakShetra) = Planet in ite own sign
#
# at (svaaM) = of Myself
#
# ‘FETTaRar: (evangatakaxaH) = (m) drawing room
#
# ‘earft (avnati) = The fifteenth nakshatra. Can be spelt Svati
#
# ‘FRE (evanda) = (m) taste
# Fret (evandate) = (1 np) to taste
#
# ER (evaadu) = sweet
#
# rhe (svaadl opendent on the self
#
# FeTeTT: (evandhyaayaHt) Hterature
#
# FerraT=rT_ (evandhynaynanman) = ava + adhyAyAt.h 4 mAsfromone’s learning + don't
#
# (m) sleep
# the master
#
# ‘FEET (svnayatta) = dependent only one onselt
#
# PETTITT (avanranjya) = ‘self-rule’, i, not being subordinate someone else
#
# ‘Fant (avaartha) = one's own ends
#
# Extracted Text from Page 216:
# lj, self-centered
# to accept
#
# ard (evant
#
# ling
# hye) = T shall kill
# jumatprabbuFl)
#
# Far (hantaaraM) = the killer
# afer (han) = kills
#
# Ft (haneudt) = to ki
# FAT (hantRi) = desirous of killing
# AT (hanyate) =
#
# (App) to take (away)
# efor (haranti) = throw
# rf (harasi) = you remove
# afr (hati) = vishow
# the Supreme Personality of Godhead, KRishhNa
# frm (hariNa) = deer
#
# 216
#
# Extracted Text from Page 217:
# et (harshha) = from happiness
# BY (harshhaM) = cheorfulnoss
# gtierfarr: (harshhashokasnvitaHl) = subject to joy and sorrow
#
# FATT (halansana)
# FATET (halaahala)
# ft: (havilt) = butter
#
# (app) to laugh
# hand
# FeTedh (hastaghaTil)
#
# (he
# eT (hasteat-h)
# Tere (hast
# fF (hastini) = in the elephant
# fer: (hastipaksH) = (m) mahout, one who rides the elephant
# Retfart (hastairbibheaaNaM) = bearing in the hands
#
# the goddess in aGYaa chakra
#
# () wristwatch
# \gushhThaasana) = the hand.to-big-toe posture
#
# (haanitf) = destruction
# TT (haara) = Garland
#
# frat (haariNt
# TATE (haalanhala) = poison
# IT (hnasa)
#
# distress to others
# rarer: (hisnsnatmakall) = always envious
#
# fit (hita) = bone
#
# fret (hitaM) = bonofiial
#
# ferererar (hitakaanyayaa) = for your benefit
# fe (hi welfare work
#
# fetter (hitaishhinch) = one who wishes good
# fireT (hitvaa) = having given up/abandoned
#
#
# Extracted Text from Page 218:
# fester (hinaat) = degrade
# freee: (himaalayaHt) = the Himalayan mounts
# Preanzey_(hiraNyakashyapu) = a demon king, killed by Vi
# frreamt (hirwNyngarbha) = Effulgent, « name of Sun
# frreamt: (hiraNyagarbhaHl) = the Golden Enubryo of life and form
# AT (hiinaw) = bereft, having lost
#
# FT (huta) = offerings (usually made to a fre)
#
# FT (hutaMt) = offered
#
# TTT (hutabhuk.h) = fire (one who eats offerings)
#
# TFTDTTPE (hutaashavakteaM) = fire coming out of Your mouth,
#
# [FAT (Ritat.n) = heart
# RE (RitathaM) = situ
# FE (hRid.h) = heart (ne:
# FET (hRidaya) = heart
# Et (4RidayaMt) = heart
# Framt (hiRidaynsthaM) = heart-stationed
# Femi (hRidayaani) = hearts
# FeA (bRidayii) = in my heart
# Frey (bRidayeshhw
# ‘FFE (MRidi) = in the heart
# FEW (lRiddeshe) = in the locate
# TTT (hRidyaatf) = pleasing to the heart
# ‘fer: (hRishhitalt) = gladdened
#
# (© master ofall senses
# IFAW (hRishhiikeshaM) = unto Lord KRishhNa
# ‘Fit: (hRishhiikeshalT) = Hesikesa (KRishhNa, the Lord who directs the senses of the
#
# devotees)
#
# nthe hearts of
#
# of the heart
#
# ‘with hi bodily hairs standing on end due to his great ccstary
# takes pleasure
# Tam enjoying
#
# ‘raat (itishhyaami)
# FAT: (hetavatt)
#
# A (hetoff ~ in exchange
# 1 (hemanch) ~ gold
#
# Bert hemanta)
# BT (hora
# ‘Used for determining Woalth among other things
# IB: (hyat) = yesterday
#
# (mae) winter
# {A Varga. ‘The Division of a sign into Solar and Lunar or
#
# as
#
# Extracted Text from Page 219:
# JFFaT (hrasvan) = (adi) short
# FRAT (hriyate) = is attracted
#
# Fr (heii) = modesty
#
# BW (kShaNaM) = one second
#
# WmTAT (kShaNaprabhaa) = (f) lightning
# mfr (kShaNaviyoga) = mon
# weiter (kShaNaviikshita) = glance
# wir (kShatriva) = the easte of princes and warriors
# fires (kShatriyabalaM) = the power or might of t
# firmer (kShatriyacya) = of the ksatriya
#
# sehen: (kShatrivaatl) = the members of the royal order
# fer: (kShanti#f) = tolerance
#
# bitty
#
# eshacriyas oF kings
#
# forgiving
#
# a (kShaya) = loss, woakoning, sea
#
# we (kShayaM) = destruction
#
# OPT (kShayakRit.h) = the destroyer
#
# waft (kShayati) = (1 pp) to decay
#
# wart (kShaynat.h) = (from) consunption destruction,
#
# wart (kShaynay)
#
# prone to end, destructible
# to the fallible
#
# WT: (kSharalf) = constantly changing
#
# Tt (kShaateaM) = of a keatriya
#
# for: (kShaantift) = tolerance
#
# THT (kShaamays) = ask forgiveness
#
# TT (kShaara) = salty
#
# erraft (kShaslayati) = (10 pp) to wash
#
# fisfers (kShitipania)
#
# PEPE (&Ship) = (root) to throw
#
# Rit (kShipati) = (6 pp) to throw
#
# PIRTPT (kShipaami) = T put
#
# Per (kShipta) = neglected or
#
# Mt)
#
# to dimnish,
#
# horeTeT: (KShiiNakalmashhanH) = who are devoid of al sins
#
# thir (KShiINe) = spent-up/weakened state of
#
# ‘Er (kShiira) = milk
#
# GF (kShuden) = insignificant, small
#
# WF (kShudeaM) = petty
#
# F (kShudh) = hunger
#
# EST (kShudhas) = hunger
#
# for destruction
#
# (Gm) protector of the earth, king
#
# tracted
#
# 210
#
# Extracted Text from Page 220:
# tert (kShudhaarta)
# qerfe (kShudhyatiy
# tpaft_(kShubhyati) = (4 pp) to tremble
# {T_(kShura) = (mase) kaife
#
# tqrfrar (kShurakriyas) = (fem) a
# APTA (KShurapatenm.h) = (a) blade
# A (KShuvdra) = weak (here)
#
# 7 (uShetra) = ta
#
# a7 (ksheerant)
# BAT (kShoteaG¥a)
#
# with « knife
#
# fold
# land the knower of the body
# We knower ofthe eld
# the knower of the fod
# feet: (kshetraGYayoHT) = and the knower ofthe Beld
# fA (ushotrit) = he soul
# #7 (KShotreshi) = in bodily Rotts
# eon:
#
# ft (kShemansy
# ert (kShemataradt)
# raf (kShouti) = to sneeze
# nt (kShabhaM) = disturbance
#
# F (GYa) = one who knows (suffix)
#
# ETHIE (GYanskaaraka) = Signifeator of knowledge which ie Jupiter
# ‘aT (GYaa) = to know
#
# TITET (GYaatachara) = (adj) known,
#
# ‘wrvet (GYaatavyaht) = knowable
#
# ‘mrft (GYaati) = community (people of the same caste ete.)
#
# TTT (GYantuM) = to know
#
# ‘wR (GYanto) = in the realised state
#
# ‘sit (GYaatena) = by knowing
#
# ‘sr (GYantvaa)
#
# ‘STIT=T (GYannagamyaM)
#
# STTET: (GYaanachakSh
#
# ‘srrmeTT (GYnanachakShushhaa)
#
# Deca
#
# by the boat of transcendental knowledge
# Knowledge and Infinity or Absoluteness
#
# (Mase, Nom-Sing, full of knowledge
#
# HRI (GYaanamayo) = fill of Gyana oF knowledge
#
# WTTTH: (GYaanayaGYall) = sacrifice in knowledge
#
# 220
#
# Extracted Text from Page 221:
# ‘srrTaT: (GYannayaGYaall) = sacrifice in advancement of transcet
# ‘srr (GYaanayaGYena) = by cultivation of knowledge
# srrait (GYaanayogens) = by the linking process of knowledge
# ‘wrvaTt (GYaanavatanM) = of the wise
#
# wrrm_(GYannavaan.h) = learned
#
# wrafehes: (GYaanavihinall) = (butybereft of knowledge of the Self
# were: (GYaanashabdayoHt) = of knowledge and sound.
#
# TTT (GYaanasya) = of knowledge
#
# TT: (GYaanaalf) = knowledge
#
# ratfit: (GYaanaagniff) = the fre of knowledge
#
# HTT (GYaanaat-h) = than knowledge
#
# ‘STITT (GVannaanaaM) = ofall knowledge
#
# ‘srarafert (GYaanaavasthita)
# ‘st: (GYanninalf) = of the knower
# ‘srfrez: (GYannibhyaHf) = than the wise
#
# lental
#
# ituated in transcendence
#
# ‘sf (GYaanit) = one who ie in knowledge
# ‘s (GYanne) = in knowledge
# ‘str (GVannens) = with knowledge
#
# -wrrta (GYaanenaiva) = GYAnena + evathro’ knowledge alone
# wrifa7e (GVamendriya) = an organ of knowledge, ie. the fve senses
# ret (GYaayate) = known
#
# ‘ara (GYanyase) = can to be known
# artaft (GYansyatl) = you can know
# Fe (GYeyant) = be known,
#
# ‘a: (GYeyall) = should be known,
# ‘arith (GYeyosi) = You can be known
#
# Ea
#
# knowledge
#
# Data saved to 'ordered_transliterations_meanings.csv'

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import re
import pandas as pd

# Open the PDF file
pdf_path = 'dictallcheck.pdf'
doc = fitz.open(pdf_path)

# Initialize lists to store transliterations and meanings
transliterations = []
meanings = []

# Loop through each page and convert to an image
for page_num in range(len(doc)):
    # Get the page and convert it to an image
    page = doc[page_num]
    pix = page.get_pixmap()
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    
    # Use Tesseract to perform OCR on the image
    text = pytesseract.image_to_string(img)

    # Print extracted text for debugging
    print(f"Extracted Text from Page {page_num + 1}:")
    print(text)
    
    # Regular expression to match transliterations in parentheses and meanings after "="
    pattern = re.compile(r'\(([^)]+)\)\s*=\s*(.+)')

    # Process the extracted text for transliterations and meanings
    for line in text.splitlines():
        match = pattern.search(line)
        if match:
            transliteration = match.group(1).strip()
            meaning = match.group(2).strip()
            transliterations.append(transliteration)
            meanings.append(meaning)

# Create a DataFrame and save to CSV if data was found
if transliterations and meanings:
    df = pd.DataFrame({'Transliteration': transliterations, 'Meaning': meanings})
    df.to_csv('ordered_transliterations_meanings.csv', index=False)
    print("Data saved to 'ordered_transliterations_meanings.csv'")
else:
    print("No data extracted. Please check the PDF content and regex patterns.")

# Close the document
doc.close()
# Out:
# Extracted Text from Page 1:
# Online Sanskrit Dictionary
# February 12, 2003
#
# te transliterated form
# cannot be a substitute for a good
#
# ‘The following
# ‘and a short meaning provided as a reference source, Thi
# printed Sanskrit-English dictionary
#
# the on-line world,
#
# of Sanskrit words printed in Devanagart wit
#
# nha, raamarakshaa et ectera, and other
# files accessible on the web. The words are encoded in ITRANS transliterat
# ping chem in Devanagari
#
# scheme x0 a8 to
#
# ‘There is a copyright on this file to the extent of preventing misuse on other internet sites
# and ego-trips of individuals.
#
# We recommend not to copy and post this fle on any other site since we periodically update
# list and we do not wane different versions of file floating around the internet.
# We have soem people copying this work and calling of their own.
#
# and correct th
#
# ‘Wo request you to provide corrections, and more importantly many suc addi
# your own collection.
#
# kkh g gh N’
#
# ch ohh j jh IN
#
# TThD DLN
#
# tihddha
#
# bohm
#
# yr Lv sh shh sh L(maraaThit) kSh(x keh) GY (hindi)
# joe anusvaara, .a avagraha, .b haLa.nta
#
# - Only a dot . or a vertical line 0 8 da.nDa .
#
# ‘ne and anc produce ard!
# ‘The vowels need to be
#
# consonant, unless one wants joDankshat
# No other letters (upper oF lower eases) are allowed.
#
#
# Extracted Text from Page 2:
# For other examples, see texts on Sanskrit Documents
#
# ‘at htp://sanskrit.gde.to/ or ite
# mirror at het
#
# /sanskrit.bhaarat.com the document project.
#
# ‘There is an excellent freeware available for Ttrans users, called Ttranslator08/00, written by
# Swamis at Onkarananda Ashram. Please download and install i from,
# Ihetp://www.omkarananda-ashrani.org/Sanskrit/Ieranalt.html The tx version of this fle is
# directly viewable in the software allowing text display’ in Devanagari as well as
# Romansdiacrities marks.
#
# For those interested in volunteering to encode, proofread, of translate Sanskrit documents
# ‘wo suggest you access volunte
# Inttp://sanskrit.gdo.to/ OR
# ‘ntep://sansheit.bhaarat.com in the
# ‘The site contains additions
#
# fle from
#
# scument project.
#
# information on Sanskrit projects. A Gl of frequently:
#
# asked-answered questions (FAQ) is available at
# Inttps//sanskeit.gele.to/sanskeitfag. html
#
# Please join us in collecting word = meaning lists with word encoded in striet ITRANS
#
# scheme format.
#
# Please contact sanskritMcheerful.com for additional details
#
# We appreciate your contsibution to make this effort success
#
#
# Extracted Text from Page 3:
# Glossary of Sanskrit Terms
# eps wer
# 3 (AUM) = Primordial Sound
# ‘Sem (OMkaara) = the syllable om
#
# 2 (a) = not
# FET (a.nkusha) = a goad (metal stick used to control elephants)
#
# stymatfrmm (ankushadhaariNam-h) = bearing the weapon ‘ankusha’ with which the elephant
# SIT (a.nga) = body, organ
#
# 7 (a.ngaNa) = fold
# strat (a.ngaca.nginay) = with
#
# limbs, body parts
# (aungaistushhTuvaa.neastaniubhilf)
#
# having satiafled with strong limbs?
#
# nointment
# #77 (antara.nga) = innor body or inner nature, feelings, inside
# iat (a.ntargata)
#
# fat (aMbas)
#
# without doing something
# than no work
#
# are (alarmaNi) = in not doing preseribed duties
#
# TWEE (akalmashhaM) = freed from all past sinful reactions
#
# SFFrETE (aknamaath) = by chance
# _ the first Iettor
#
# wr the letter
#
# oe
#
# a
#
# ant
#
# net
#
# ret
#
# rin:
#
# PFT (akurvat.h) = aid
#
# SPAT (akurvate) = did they do
#
# Sry (ahushalaM)
#
# SETHE (akfhtabuddhitvaat.h) = due to uninteligence
# STPTTETT: (akRitaatmaanall) = those without selfreal
# SPAT (akRitena) dlincharge of duty
#
# SFT (akTievan) doing (rom KR)
#
#
# Extracted Text from Page 4:
# SRPFTITET: (akRitenavidasH) = persons with a poor fund of knowledge
#
# afi: (akriyaall) = without duty
#
# orHNT(akrodha) = freedom from anger
#
# SANT: (akrodhaFl) = freedom from anger
#
# arvire: (akledyaHl) = insoluble
#
# sxfiret (akhila)
#
# sft (akhilaM) = whole
#
# afRerTT (akhilaguru) = preceptor for al, also all cypes of long syllable letters
#
# SET (agata) = not past
#
# SITET. (agatasuu.nach inch + chacundeparted
# thou going (from gam.)
#
# = agate + as
#
# + and (living people)
#
# saftrviT: (agniparvatatt) = (m) volcano, volcanic cone
#
# saftrafteT (agnipetikan) = (F) matchbox
#
# saftrararer_(agnishalankaa) = (f) matchstick
#
# fT] (agnishbhu) = in the fires
#
# SFrAT (agnau) = in the Bre of consumma
# yout in this sense) tip
#
# at the tip
#
# SET: (ageatall)
#
# sreT: (agradiipalf) = (om) headlight
#
# SFT (agre) = in front of/ahead /heforchand
#
# SFETT: (aghaMmanall) = (adj) evil-minded
# srievous sine
#
# ‘number
# limb, oF body part
#
# a finger
# ha) = the big too
# - (angushhThaHf) = (m) thumb
# ot (acharaht)
#
# SET (acharasya
# Fer (achala)
# SFT (achalaM)
# Se: (achalal)
# areerfre (achalapratishhThaM) = steadily s
#
# ted
#
# Extracted Text from Page 5:
# aT (ach without its b
# SFT (achakShus.h)
#
# SFaTTt (achaapalaM)
# after (achintya) = inconceivable
# aff (achintyaM) = beyond contemplation
# ssf: (achintyall) = inconecivable
# safeTre (achirand.h) = without delay /in no t
# ferret (achirandbhava) = in no time from
# safer (achireNa)
# FTTH: (achotasaHl) = without KRishbNa consciousness
# HT: (achehhedyaHl) = unbreakable
#
# FFT (achyuta) = O infallible one
#
# FFT (achyutam.h) = the who doos not slip
#
# 57 (ain)
# 57 (ain
# =
#
# 1 eyele of birthiudeath
#
# ‘very soon,
#
# SFT (aiapaa) = involuntary repetition (as with a ma
# ST (ajnsraM) = the unborn one
#
# Sar (nina) = (8) goat
#
# SFT (alannah)
#
# STAT (ajaanat-h) = knew
# STITT (ajpanataa) = without knowing
# STITT: (ajaanantalf) = without knowing
# STFTH: (aJNehala]) = (m) aanehal in
# TFET (alNjana) = the name ofthe mother of Hanuman
# SDERTET (alNjancyaneana
#
# seat (@JNjoi) = (m) folded hands
# sxeft_(aTati) = (1 pp) to roam
#
# lo not understand
#
# = the spliee
#
# srehait (aNilyna.neaM) = smaller
# ae (at
# sar (aNoH) stom,
#
# Foret (aNvastraMf) = (n) nuclear weapon,
#
# SITE (ataHT) = hence
#
# SrTTETETT (atattvnarthavat.h) = without knowledge of
# with great care
#
# 10 one who
#
# not austere
#
# aay)
#
# = excessive familiarity
# super power
#
# fret (atichaara) = Accelerated planetary motion
# arfrefat (atitaranti) = transcend
#
#
# Extracted Text from Page 6:
# “afrere (otitaralah = oti starala, very unstable
# Fe (sith) = (m) runt
# Ste atithil) = (ase: Nomaing)gust (literally undated)
# sairerewt (atidaneuuNaman h) ~ adj. very dreadfal
# ‘rivet atiduryRitta) = of exceodingly bad conduct
# stiri atschyate) = becomes more
# ‘iret (aivariate) ~ anne
# sire (otshaya) = wonder
# srireater(ashevokl) ~ exnoraion
#
# aurpaeed
# traneondiog
# oritftrt (atiindriyaM) = transcendental
# rire (atiiva) = very much
# Tater (atulaniiya) = uncomparable
#
# STE (atyantaM) = the highest
# rent (atynrthaht) = highly
#
# very hot
#
# arrqeT (atyushhNe
#
# SRI (athashabda) = the word atha (prayers are started with words atha or AUM)
# ant: (atha.rlf) = object, meaning
#
# anriveret_(atharvaNvaakyaM)
# snrtt. (atharvashiineh
# prt (atharvashiirsbhaM)
# spre (athavaa)
# GRETT: (athantaHf) = atha and ataHf : then and therefore
#
# ‘or in other words
#
# charvaNa” word:piece
#
# 1 to the priests
# SRerm: (adaahysH) = ws
#
# aafetr (aditi) = the mother of the gods
# Sgt (adRishhTa) = Unseen, fortune, luck
# srgeTe (adRishhTaps never seen before
# afer (adetha) = at an unpurified place
#
#
# Extracted Text from Page 7:
# (sdbhuta) = the sentiment of marvel
# SF (adbhutadt = wonderful
#
# SFE (adbhuutaM) = wonderfull
#
# 37a (aya) = today
#
# FTE: (adrohal)
#
# SEIT (avlvansana)
# safgfre: (advitiiyalt)
#
# freedom from envy
#
# on-duaiy ofthe universal spirit
# Gandectinabte) below
#
# se without money
# inferior
# reat (adhamand
# SIRT (adhamaadhama) = the worst among the inferior
# sret (adhara)
# set: (adhorait
# seer (adharaa
# once (adharma)
# srcit(adharmaNy =
# areth (adharmal)
# areirarfr (adharmachaasi
# cee (adharmasya) = of ireligion
# ‘afi (athika) = additional
# safe (adhitaNh
# orf: (adhikall) = greater
# srfiert: (adhikatarall) = very much
# safer (adhikaara) = ttle
# srfierr: (adhiasealt) = right
# sefeerPert (adhikanrtantead)
# sefefrait(oanikshipat)
# sft: (adhikShepalf) = (m) a
# seferemft (adhigacchnai) = attains
#
# condemned
#
# safefram: (adhiniyama) = (1m) act
# she ( protector
#
# axfetft (adhipatiy = lord
#
# ‘fegT (adhibhuta) = the principle of objective existence
# arfegt (adhibhuutaM) = the material manifestation
#
# safer (adhimastea) = superior
#
# saferrarrm (adhimaatrastama) = the highest, the aupreme one
#
#
# Extracted Text from Page 8:
# sfeex (adhiyaGYa) = the principle of
# fees: (adhiyaGYalt) = the Supersoul
# atfrrre (adhivansa) = dwelling
#
# feta (adhiveshanaM) = (n) conference
# atfemT (adhishhThaana) = seat, abode
# arfemrt (adhishhThaanaM) = sitting place
# safeera (adhishhThaaya) = being so situated
# srfenit (adhisari) = competent candidate
# snftt (adhiita)
#
# rifles, incarnation,
#
# he dog stret
#
# srorrrrfrar_(adhyaatmavidyaa) = spiritual knowledge
# span: (adhyaadeshaH) = (m) ordinance
# snare. (adhyanpayituM) = to teach (infinitive of causative of adi:
# sranfoer (adhyaapikaa) = (f) lady teacher
# SPOT (adhyaasa) = a cate of mistaken identity
# srrert (adhyoshhyate) = will study
# speiret (adhyopatya) = Lordship
# SNE (adhruvaht) = temporary
# SRT (adhvan.h) = road
# (mm) rond, path, way
# ‘unstoadiness of the body
#
# Infinite, a name of Vishns
# 77% (anantaMt) = unlimited
# 7-7: (anantaHt) = Ananta
# STAT (qnantaraM) = after
# © unlimited form
#
# unlimited form,
# the conch named Ananta-vijaya,
# ar-That(anantavilryaa) = unlimited potency
#
# SFT: (anantaatT) = unlimited
#
# SETTTAT (ananteasans) = Ananta’s posture
#
# SHITE: (ananyachetaaHl) = without deviation of the mind
# SFI-TITE.(ananyabhaakch) = without deviation
#
# to study)
#
# Extracted Text from Page 9:
# without deviation of the mind
# indeviating
#
# by unalloyed devotional service
# raving no other object
#
# SETA: (ananyamanasalt)
#
# sry-TAT (ananyayan) = unalloyed,
# SATE (ananyayoge
#
# ithout division
# neutral
#
# sere (onapekShya)
# sSrrfrep: (anabhishva.ngall)
# srafineeere (anabhinandhaaya)
# rvfie: (anabhisohatT) = without affection
# ignorant of, unacquainted wit
# them
#
# ppurposotess/in vain/danger-produective
#
# by the fre
# wavalokayaan.h) = not looking
# wanted
#
# orereT: (anashnatalt)
# sPrret (anashnan.h)
# SPrETT (anauyave)
# SETTe: (anasuuyall)
# STTET: (anamuuyantaH) = without envy
# SrrETTAE (anaha.nvaadi) = without false exo
# SIRETT: (anaha.nkaaralf) = being without false egoism
# SFT: (anaatmanall) = of one who has failed to control the mind
# aFTTET (anaadara) = Inck of respect
# without beginning
#
# ‘without beginning
# srrfeer (anaaditva) = non-boginning
# SeTHFRTT (anaaditvaat.h) = due to eternity
# SFTTTAHTT (anaanasaphalam-h) = (n) pineapple
#
# Jing from eating
# without eating (having fasted)
# to the nonenvious
#
# 1 envious
#
# serra (anaavittia)
# seria: (anaashinalt)
# serifaa: (anaashritelt)
#
# no return
# never to be destroyed
# ‘without taking shelter
#
# SET (annahate) = unbeaten
#
# “uncertain temporary /ephemeral/transient
# = temporary
#
# Extracted Text from Page 10:
# aie ( ‘nonpermanent
# srfrafer (aniyamita)
#
# afferent (ani without deviation
# fre: (anilalt)
#
# afrargier (anilachulll) = (f) gas (LPG)
#
# safrartt (anivaarya) = (adj) compuleary
#
# sxfre (anishhT»M) =
# srfret (aniishvaraNt)
#
# 57 (anu) = following
# SETFEMP_(anukampanrthaM) = to show special merey
# seqerft (anukaari) = tke
#
# SFTATTE (anuchaaraya) = (causative of annear) follow
# STPTATET (anuchintayan.h) = constantly thinking of
# SqPREPT (anutishhThanti) = regulary perform
# SFT (amuttamadt) = the Rest
#
# FTTH (anuttamaaht) = the highest
#
# Sry (anudarshanaM)
#
# TYE (anudaanaM) = (0) donation, grant
# SFTP (anudinadMt) = daily
#
# SrYPERE (anuuddiahya) =
#
# observing
#
# SeYfeTHT: (anudvignamanaalf) = without being agitated in mind
# STTETIT (anudvegakaraM) = not agitating
# Tyra (anupakaariNe)
# seqTrcir(anupashynt)
# SeTTFGET (anupashyanti)
# SeTTRTTAT (anupashyaam’)
# SFTFTAT: (anuprapannanif) = folowing
# STE (anubandha) = (m) result, effect
# TET (anubandhadt
# STEN: (anubandhakt) = (m) annexure
# spent (am
# SrqER (anubandhe)
# Sry: (anubhava)
# wumantas) = permitter
#
# irrespective of return
#
# of future bondage
#
# (ablat.)from guessing or induction
# (enuyaayinall) = followers
#
# 10
#
# Extracted Text from Page 11:
# STS (amuraiyate)
# SET (anuradhs
# FIAT (anulipta) = smeared
# SFT (anlekha) = destiny
# STAT (anwlepanaM)
# STAT (anuloma) = with the gr
#
# ie becoming attached
#
# seventeenth nakshatra
#
# smeared with
# 1 naturally
#
# STR (anuvartate) = follows in the footsteps
# SFTP (anuvartante) = would follow
# srqrtaft (amuvartayati) = adopt
#
# SETTTE (amuvandaM) = translation
#
# SFTRTE (anuvandya) = having translated
# srqfnfiet (amuvidhiiyate) = becomes constantly engaged
# rym (anushaasitaaraM) = the controller
#
# ashrusma) = Thave heard by disciplic secession
# TAT AT (anushochanti) = Inment
# STAI (amushochitunt = to lament
# STOTT (ancl
# TET (anushbtwp)
# SFqET (anushhThana) = (n) performance, execution
# aryrermfr (anusantatann’) = extended
# SryTATt (anusandha (0) investigation
# SFTATT (anusnara) = following, eustomary(minse)
# ‘FAT (anusuuchii) = schedule
#
# £0 on remembering
#
# ch) = remembering
# SFT (anamaret.h) = always thinks of
# STE: (amunvanra) = the accompanying sound or letter (the letter form ‘n! M2)
# SETWTETT  (anuGYaayataaMf) = (verb) be given leave/permission
# SETI (anuichaanaM) = (teacher?)
# STF (anRita) = fase
# Te (ancka) = Many
# SFTeIT (anckadhas) = into many
# FETE (anckavachaneM) = plural
# srt (anekann’)
# SF (anna) = by th
# art (angaMt) = body
# ort (anta)
# STF (antaMt)
# ST: (ental) = (adv) inside
# seorinra.(antaffharaNa) = Mind
# STTFERT (antal{peTikan) = (f) drawer
# srerinetfs (antalfsthaani) = within
# SroTET (antakaale) = at the end of life
#
# n
#
# Extracted Text from Page 12:
# =I (antara)
# arr (antaraM)
#
# STITT (antarnatmanaa) = within himself
#
# ST-TTTAT (antarantmaa)
#
# the inner self, residing in the heart
# (m) obstacle
#
# ST=TTTTTR: (antaraaraamal) = actively enjoying within,
# srerftar (antariksha) = (n) space
#
# srotfrat (antarikShaM) = space, sky
#
# 3-97 (antare) = betwoon
#
# rato (antaroNa) = without
#
# SE-TTTIPT: (antarjyolifl) = aiming within
#
# SATETET (antaryutakam.h) = (n) vost
#
# Serpe: (antarsukhaH)
#
# orf (antike) = near
#
# SE (ante) = after
#
# arr (ands)
#
# ‘ere (andhakaara) = darkness
# ) = food
#
# FF (anna = foodstutt
#
# S7HTT (annaatsh) = from grains
#
# SFT (anya) = other person
#
# SF (anyaMt) = other
#
# S-7F (anyatra)
# sn (anyathaa)
#
# rout (anyaaM)
#
# TT (anyaan.t)
#
# sr=aFF (anyaani) = different
#
# r= (anyaayens) = illegally
# hers
#
# by another
#
# by others
# mutual
#
# Family
#
# SEAT: (anvashochsall) = you are lamenting
#
# 2
#
# Extracted Text from Page 13:
# safer (anvichchha) = try for
#
# ‘afer (anvite) = (p.p) Followed or attended by, in company with, joined by;
#
# coverpowerd by, connected grammatically;
#
# sxfermt: (anvitaall) = absorbed
#
# are (anveshhaNam.h) = (1) search, exploration
#
# SFTF_(apakR) = to harm
#
# TET (apakendraNa)
# handicapped
#
# to decrease
#
# dof,
#
# centrifugation,
#
# TT (apara) = other
#
# sreTt (aparaanch)
# srvfrme (aparigraha)
# rafrae: (aparigrahall)
# soft (aparimeysM) = immeasurable
# srefrar (aparihanrye) = of that which i unavoidable
# are (apare
#
# reat (aparyaaptant) =
# srTaTe (epalaayanaM)
#
# seducetion
# TATE (apavanda) = exceptional
# SFGPTET: (apavighnaH) = without obstacles
#
# hie cou
# forgetful
#
# SFTERTT: (apasmaaraHl) = (mm) epilepey
#
# SFTETT (apaharaNa) = stealing
#
# STTETH (apaharaNaM) = abduction, kipnapping
#
# arveTit (apahartaaraM)
# STURT (apabRita) = stolen
# SFURTITAT (apahRitachetasaaM) = bewildered in mind
#
# he remover}destroyer
#
# a
#
# Extracted Text from Page 14:
# Srorr (apnana)
# srert (epnanaM)
# STU (epane)
# ara (apaapo)
# arafeT: (apaayinall) = disappearing
# TTT (apaaraa) = one who has no limite
# SUT (apaavRicany
#
# sft (api) = also
# sr4Ty (epiteshin) = (Mase.Loe-PL) having not drunk(taken water)
# SFT (apunya) = view
#
# STTATTEP. (apunaraavRtiM) = to theration
#
# STF (apushlipa) = one without Sowers
#
# gfrer (apRithivyoH) = to the earth
#
# dow:
# sets downward
#
# wide open.
#
# (f) expectation, hope
# sion to fault-find
#
# SmrWT: (aprakaashaHl) = darkness
# SrxfTHEATE (apratimapeabhaava) = O immeasurable power
# StxfTE (apratishh Tha)
#
# aaxfe: (apratishhThaH) = without any position
# sarirert (apratiikaaraM) = without being resistant
# SOTETT (apradaaya) = without offering
#
# SImFT (aprameya) = the ununderstandable
#
# amt (aprameyaM)
# SEFTTET (aprameyasya) =
# saraft: (apravRittiHt) = inactivity
# SEITAT (apranptat.h) = uttained, obtained
# SET (apraapya) = filing to attain
# SEITTATHT (apraamaamaaNya) = Unjustifiod
# sft (apriyaM) = the unpleasant
#
# sft: (apriyaHt) = and the undesirable
#
# ithout foundation
#
# SrTaITTT (aphalaprepsunan) = by one without desire for fruitive result
# SreaTATPEat: (aphalankan.nkShi
#
# STE (ahandhu) = one who dove not have any brothers / kinmen
# STR (abla) = helpless (woonan)
#
# area (abalas)
#
# STTET: (abuddhayaHt) = leu intelligent persons
# STATE (ahodha) = Ignorance
#
# HT) = by those devoid of desire for result
#
# (helpless) Woman,
#
# 4
#
# Extracted Text from Page 15:
# (1m) ocean, sen
# ch) = spoke
#
# SEmET (abrahmaNys) = Not kosher
# SPATE (abhaktanys) = to one who ie not a devote
#
# rt (abhayaM)
#
# SFT (abhaye) = and fearlossnoss
#
# SPAT (abhavat.h) = became
#
# srafrert (abhavishivat,
#
# seat: (abhnavaHt)
#
# SATTTT: (abhaavayataHl) = of one who is not fixed
#
# SFATET (abhnashhiata) = began to speak
#
# safir_ (abhi) = proposition
# i-+taD.h) = to
# ikathanaMt) = (n)
#
# 18) = In endeavouring
#
# 14) = black magic
#
# afKTATE (abhijanavann.h) = surrounded by aristocratic relatives
#
# ssf: (abhijeatall) = born of
#
# finrTeT (abhijaatasys) = of one who is born of
#
# ssfirnfet (abhijaananti) = they know
#
# asfiraratit (abhijaanaati) = does know
#
# safiraret (abhijasyate) = becomes manifest
#
# safirt (abhijita) = A nakshatea between uttaraashhDhas and shravaNa mainly centred on the
#
# star Vega. For some reason itis not usually included in the 27 nakshatras although it would
#
# ‘make 28 if it was. adhipatit- Lord
#
# jinchmubwurta) = the most auspicious moment
#
# covorywhere
# 1aHt) = (m) Insurgency.
# in) designation
#
# oxfirrg:
#
# ‘afafs@ (abhinivesha) = possessiveness
# (om) layout
#
# fergie: (abhipushhTiH) = (f) affirmation
#
# StfETTT: (abhipravRittsH) = being fully engaged
#
# safe: (abhiprasyalf) = (m) opinion
#
# axfinreft (abhibhavati) = transform
#
# ssfinrem (abhibhavaat.h) = having become predominant
#
#
# Extracted Text from Page 16:
# safer: (abhimansH)
#
# firs (abhimaana) = seltimportance
#
# afirgest (abhiyuktan
# sxfire (abhivoga)
# sxfirdt: (abhiyogal) = (m) prosecution
# ssfirrr: (abhirataHt) = following
#
# ssfirraey (abhirakshant
# ssfirfirt (abhirakShitaMt
#
# perform’ ps
# ablation
#
# fon the idol
#
# sreafire: (abhyadhikall) = greater
# srerTeet (abhysnunaadayan.h)
# seat (abhyarchya) = by worshiping
# sRaTt (abhyasanaM) = practice
#
# srerpreT:. (abhyasuuyskaalt)
# srarpait (abhyasuuyati) = is onvios
# sRerTTT:. (ablyastuyantal)
#
# srt (ablyaasa)
# SFATMATT (abhyansayoga) = by practice
# SAMMUT (abhyaasayogena) = by the practice of devotional service
# SPOTATE. (abhyaasaat, 1m practice
#
# FATT (abhyaase) = in practice
#
# srepert (al
# sreqeT (abhyudayn)
# ort (abhranty
#
# arr (amala) = without rubbish
# art (amalaM) = clean,
#
# 6
#
# Extracted Text from Page 17:
# seer (amalaan.h)
# srrifset_ (amaanitvaM)
#
# spre: (amuuDhasH)
# STeT (amuulya)
#
# riceleas, excellent
#
# f ambrosia, potion to cause immortality
#
# 8 drop of nectar
#
# howe who have tasted auch nectar
#
# SEPA: (amRitabhyjoH)
# SFATET (amRitasya) = of the immortal
#
# aryATET (amRitodbhavaM) = produced from the churning of the ocean
# FATT (amRitopamaM) = just like nectar
#
# SeTETT(ambuvegan) ~ waves ofthe waters
# Sam (ambhanh) = (x) water
# the water
#
# om the water
# ATF (ombhruhaht) = fnew
# > fomin ~ (m) se
# 2 (opaht) = him (hom idaX4)
# SET (oyajanls) = third person plu imperfect aatmanopade of ya, to worship
# waft: (ayatifl) = the unsuccessful transcendentalist
# Serre (ayathanvath) = imperfectly
# SATE (oyanesina) = inthe statege plats
# TT (yum) = length, extension, restraint
#
# 1) = infamy
# rr (apnntt) ~ (ron
# {FET ayaGVasya) ~ for one who performs no sacrtce
# ERT: (ayubtall) = one whofe notin KB
#
# IhNa consciousness
#
# (a) a wooden barrel
# Srrer (araNyam.h) = (a) jungle, forest
#
# 7
#
# Extracted Text from Page 18:
# arretie: (araNyaukassH)
#
# = (Mase.poss.sing.) forester's
#
# being without attachment
# SETTTETT: (araagadvesbhata)
#
# thout love or hatred
#
# afr. (arishhu) = on enemies
# srfrenit: (arishhTanemitt)
#
# srfrpet (arinsudans)
#
# the appelation ¢o Garuda?
# killer of the enemies
#
# ‘omonce, & name of Sun
# ore (argha) = value
#
# ard (archati) = (1 pp) to worship
# fF (orehitun
#
# SF (jana) =
# orf (arjanad)
# er (ani
#
# SF (ori
#
# or
#
# STE: (ardunayoH) = a
# one (artha)
# ane (arthaMy
#
# ania (arthayate) = (10 pp) to request
# snbart_ (arthavaan.h) = one with money
#
# fmase.poss.sing.) wealth or meaning
#
# ‘one who desires material gain
# sr (arth) = in meaning
#
# antiertarz (arthopaarianaaya) = for ea
# af
# arith (ardhiagola) = semicircle, dome
# oRIS=FTAT (ardhachandrnasas
# onframry (ardhanavansana) = the
# anfarhater (ardhanaariinaTeshvara)
#
# 1 half-moon posture
#
# (1m) frock
# the halflotus posture
# che half spinal-ewist posture
# anffieiys (ardhashirshhaasana) = the half headstand posture
#
# 18
#
# Extracted Text from Page 19:
# onfratyrrs (ardhasarvanngassana) = the be
# afr (ardhasalabhaasana) = the hal€locust posture
# anvinw (ardhoruka) = (n) half-pant
#
# anyivwT (ardhorukam.h) = (n) half-pant , shorts
#
# oulderstand posture
#
# safftr (arpita) = surrendering
# athe (arbhaka) = small
#
# rts (aryamaa) = Aryama
#
# orf (arha) = deserving
#
# sft (arhataa) = (f) qualifeation
#
# ref (arhati)
# rift (arhasi)
# 3 (alaM) = especially
# ‘nkaaradiiptaMt) = shining with adornments, decorations
# decorated / ornamented
# ho fooling that it is impossible to see reality
#
# pp) to deserve
#
# RTA (alakShamnana) = one who disregards
# arefim: (alakShmiFl) = poverty (alaxmill is opp. of laxiniFf)
# rire (alia) = (adj) flee, untrue
#
# STATYZT (aloluptvaMt) = freedom from greed
#
# eT (alpa) = small, letle
#
# Fe (alpaM) = a few, little, inadoauate
#
# srengr (alpadhii) = mental deficiency
#
# SeTEET: (alpabuddhayalT) = the leas intelligent
#
# retineat (alpamedhasnaM) = of those of small intelligence
# SFeTTTEE (alpavayaskaM) = young (small) ago
#
# FeTT (alpaays) = Short life between 8 and 32 years
#
# area: (avachyaH) = unblamable
#
# arvarsfor (avajannanti) = deride
# STITT (avataara) = a divine incarnation particularly of Vishnu, e.g- Buddha
#
# 19
#
# Extracted Text from Page 20:
# becomes established
#
# srr: (avadhyal)
# SFT (avana) = protection
# raft (avaniM) = oarth
#
# srafrort (avanipaala) = of warrior kings
#
# the daughter of the Barth (sits)
#
# SFTFETT (avaruddhavoga) = retardation
# TERE (avaruuNaddhi) = to obstruct
# SETHEPT (avarohati) = to descend
# af (avalipta) = proud, haughty
# rae: (avalehaH)
# arafaeT(avashishhynte)
# sree (avashoshhaNa)
# STE (avashhTabhyn)
# automatically
# TT pl. imperfect of vas, to live
#
# SFTHT:_(avasarall) = (m) opportunity, chance
# srerti (avasarpati) = to slide (as from a waterslide)
# SFTATEIT (avasnadayet-h) = put into degrade
# SrTRET (avaathna) = a state of the mind
# srTeIrt (avasthaatuM) = to stay:
#
# emt: (avasthantrayaHt)
# afer (avnathitaM)
# safer:
#
# tiaree states of bodily consciousness (awake, sleep, dream)
#
# srafheart(avasthitann.h) = arrayed
# srayrené (avahaasaarthaM) = for joking
# ‘contempt
# without proper attention
#
# srTTeT (avaachya) = unkind
#
# SRT=TaE (avnaptavyaM)
# SFT (avasptuM) = to achieve
# srarertit (avaapnoti) = gets
#
# 0 be gained
#
#
# Extracted Text from Page 21:
# sear (avanpy)
# STAT (avanpyate) = is achie
# SrT=TE (avanpayatha) = you will achieve
# srereeafr (avaapayasi) = will gain
# rfewett (avikalpens) = without division
# afrerd: (avikaaryaH) = unchangeable
#
# - thoughtless
#
# achieving
#
# of one who does not know
# ‘metaphysical ignorance
# srfegtt: (avidvas.nsaHl) = the ignorant
# safefirrhe (avidhipuurvakaM) = in a wrong way
# FfrrrTt (avinashyantaM) = not destroyed.
# sft (avinnasha) = wndestrictible, name of Vil
# safemifz (avinanshi) = imperishable
# ssferifet(avinaashinaM) = indestructible
# sefrtfer: (avipashchitalt) = men with a poor fund of knowledge
# saferet (avibhaktaM)
# saferfa (aviratl) = sensuality
# atfring (avirodha) = no oppositi
# frie (aviGYeyaM) = unknowable
# SFR (avekShe) = let me see
# Fier (avekShya) = considering
# (aaj) Megat
#
# wattaatch) = protect me from the northern direction,
# onmanifested
#
# onmanifested
# rarer: (avyaktall) = invisible
# sroreraffat (avyaktamurtinas) = by the unmanifested form.
#
# toward the tnmanifested
#
# SOTETT (avyaktantsh) = to the wnmanifest
# srarerrétft (avynktandiin’)
#
# ithout division
#
# in the beginning unmanifested
# ‘without any break
#
# sroreTt: (avyayavargall) = the class of indeclinable words
# srorUre (avyaynsy)
# stort (avyayiibhanva)
# srarenrfeat (avyavasaayinaaM) = of those who are not in KRishhNa consciousness
# SRATPTT (avyaakRitas) = not expressed
#
# a
#
# Extracted Text from Page 22:
# are (asha.nks)
# Sra (ashakta)
# SrweT: (ashaktalZ)
# arat (athana)
#
# SFR: (ashamal
# SFFTTT (ashayant-h)
# SFT (ashasteaM)
# SFAT=TET (ashaantasya) = of the unpeacoful
# FTE (athaashwvataM) = temporary
#
# SFETET (ashaastra) = not in the scriptures
# safer (ashishhya) = untonchable (adj)
#
# safer (ashishhyaaya)
#
# to the unclean
#
# from their source
# shout being fully equipped
#
# non-disciple Le.non-believer
#
# to one who is not engaged in devotional se
#
# Stare (athoshha) = total
# arrUT:  (asheshhatalt)
# aru (asheshhaaNi)
# SFR (atheshheNa) = in deta
# STATE (athochyaan.h) = not worthy of lamentation
# FATE: (athoshhyalf) = not able to be dried
#
# SETH: (ashnatadt)
# S72 (ashnan.h)
# =P (ashnanti)
#
# FIT (ashnute) = achioves
# ‘= (ashma) = stone
#
# SEEMT (ashraddhayan) = without faith
# aq (asheu) = (n) tears
#
# SETHET (ashruupuueNaskula) = full of tears
# andi (ashraushhaM) = have heard
#
# SFTATET (athlaaghya) = adj. virtucleas
#
# 2
#
# Extracted Text from Page 23:
# SPER: (ashvatthaHl) = the banyan tree
# SPERTTAT (ashvatthaamas) = Aevatthama
# FEAT (ashvamedha
# SPETTt (ashvaansaM) = among horses
#
# ‘form of sacrifice where a horse is sent around to estiblish supremacy
#
# safer (ashvini) = a mudeaa, contraction of the anal sphincter muscles
# safeat (ashvinau) = the two Asvinis
# FE (ashhTa) = cignt
#
# EATTTTT (ashhTadalakamalabandha) = eight-petalled lotus pattern, a form of bandha
# poetry
# set (ashhTadhaa) = eightfold
# FETE (achhTandasha) = eighteen
# ETE (ashhTanvakra) = name of a deformed(at eight places) sage
# SEITATET (ashhTottariidashaa)
# chooses it secording to certain eriteria
# inTau) =
# SSTFTT (ashhtakavarge)
# upon planetary pos
# SITET (asannyasta) = without giving up
# SFATTT (asa.nyataa) = unbridled
# thayaM) = undoubtedly
# ashayaH) = beyond « doubt
# ‘unattached
# SrUT (asaktaM) = with
# arr: (ataktall) = withos
# arravafg: (ssaktabuddhill) = having unattached intelligence
# SFUTTEAT (aeaktantmas) = one who is not attached
# srafet: (osaktift) = being without attachment
# SATT:_(asa.nkhyaHl) = (m) countless
# ETPFEMT (naa.ngashastroNa)
# SFT (asat-h)
# Ser (asatalt)
#
# ‘A lunar based Dasha system tres 108 yr cycle and one
#
# predictive method of Astrology that uses a system of points base
#
# by the weapon of detachment
#
# armnd: (asamarthall) = unable
# SFTOTETT (asampenGYanta
#
# aTETE: (asammuuDhalt)
# SRFETET: (atammuuDhaalt)
# STE: (atammohall) = freedom from doube
#
# unconscious samadhi
#
# 2
#
# Extracted Text from Page 24:
# rat (asnaraMt) = worthloss/without essence
# rarer: (asnavandityaH) = asau and AdityaHf: this(person) and Sun,
# you are
#
# sxfire: (asitaHl) = Asi
# fener: (asid-hahyoH)
# fret (asiddhau)
# Sy (asukhaN
#
# failure
#
# SAYTM (asuraaNaaM) = of demons
# SET (asuraan.h) = demons
#
# 1) = fall (set)
# stroyed , vanat
# SreHaT (astamavelan) = (fem) evening twilight
# safer (asti) = (2 pp) ie
# ST (stu) = there should be:
# Se (asteya) = nonstealing
# SFT (astra) = Weapon
# safer (asthi) = Bone
# arferrerTm (aethipaJNjaram.h
# safeet (asthiraM) = unsteady
# SFETHT (aiparshana) = not touching
# SEE (asmad.h)
# rere: (asmadiiyaiff) = our
# SFPHTH (asmankaM)
# SPATE (asmaat.h)
#
# (0) setoton
#
# SFeTRTT (aevasthataa) = illness
#
# By
#
# Extracted Text from Page 25:
# tendency to identify oneself with external phenomena, "the maker’
# goism, selfishness, ignorance
#
# 5) = roron (atonyan of hia)
# Stier: (abit) ~ ene
# “efeqi"Fe: (ahituNDDilall) ~ (m) a snake charmer
# SPOT (ahatukaht) ~ without eauee
#
# lay and night
# (aa) incapable
#
# Snr (akShama) =
# SRet (akShayaM)
# SneT: (akShayalt)
# SRT (akShara)
#
# srt (akSharaMt) =
# SRT (akSharalt)
#
# rar (akSharaaNanM)
# sre (akSharaat.h) =
#
# am: (aGYaH)
# HTT (aGYatan)
# SHIT (aGYaana) = ignorance
# srart (aGYaanaM)
#
# ara (aGYannajaMt)
# srarTert (aGYaanasambhutaMs)
# STW (aGYannasM) = of the foolish
# SFaFT (aGYaanena) = by ignorance
# mT (
# SFINHT (aa-+ghras) = to smell
# STITT (antchar.h) = to peactice
#
# from
#
#
# Extracted Text from Page 26:
# HTFTT (an-yaa) = to come
#
# STATE (an4-rub.h) = to climb
#
# orm (aaudau) = in the beginning
#
# Herat (aa.ndolana) = movement
#
# sifare (aa.nshika) = partial
#
# ar (anHl) = to sit
#
# samt (aakarNa) = towards the ear
#
# aHTmTTIAT (aakarNadhanuraasana) = the shooting bow posture
#
# samt (aakarshha) = attracted
#
# ‘sTehyt (aakaa.nkShaa) = wish, ambition
#
# (mase) form, shape
#
# SHTeTTaTT (aakaaramaana)
# = (0) doorbett
#
# aera (ankaasha) = other
#
# saerafert: (ankaashasthitall)
# ‘aera (eakaashaat-h) =
#
# uated in the sky
# 1.S)from space oF
#
# aarp (aakula) = full of
# sarpferrt (ankulitam.h) = sad, worried
# apt (aakMitini) = forme
#
# SET (aakRishhTa) = (past part, of an + KRREsbh) attracted
# SITE (aakeam.h) = to attack
#
# ITER (ankramaNa) = attacks
#
# SITT: (aakShepall) = (m) insinuation, opposition
#
# PT (aakhu) = mouse
#
# doseribed
# sarong (onkhyaahi) = please explain
# STTOHT (angachehhet.h
#
# ‘one should come
#
# Prat
# nglabhanshhas) ~ English language
# rer (anchar-h)
#
# Serer: ancharatalf) ~ ating
# srrevit(ancharat) = he doce
# TET (ancharsan.h) = performing
#
# 10 behave, interact
#
#
# Extracted Text from Page 27:
# sareTT:  (anchaaraH}
# Tart (anchaarya)
# STITH) (anchaarya(F)
# SrreTt (anchaaryaM) = the teacher
# arava: (anchaarynall) = teachers
# SHYTTHT (anchaaryaan.h) = teachers
#
# approaching a bona fide spiritual master
# fn) covering sheet, chaddar
#
# STATTTTG (aajaanubaahuM) = the one whose arms extend upto his knees
# TT (aajyaM) = melted butter
#
# samTy_(anta.nka)
#
# ready
# ‘rt (aattha) = have spoken
# Sart (antmaa) = of the self
# Stree. (antmakaM) = consisting of
# SET: (antmakal}
#
# SETWTTHTT (aatmakaaraNaat:h) = for sense enjoyment
# Sar (astmaja)
#
# SETH: (aatmajalt) = son
# STAT (antmajaa) = daughter
# STATA: (antmatRiptaHt)
# SETH (antman.h) = So
# ETAT (antmana
# STA? (aatmanaHt)
#
# posiessing oF controlling
#
# eitluminated
#
# (sfaseinate-sing.) thro’ the self
#
# arts
# by My internal energy
# by My internal poteney
# pleasure in the self
#
# SATA. (aatmayogeat-h)
# srrerrit: (aatmaratiFl) = tal
# uated in the self
#
# ‘under one’s control
# SETaTT (aatmavaan.h) = established in the self
# rrfefrag: (aatmavinigrahall) = self-control
#
# Ea
#
# Extracted Text from Page 28:
# muutayaH) = personal opulences
# ') confidence
#
# of controlling the mind
#
# sree: (antmasa.nstutill) = and praise of himself
#
# SATE. (antmasa.nsthaM) = placed in transcendence
#
# SATAN (aatmasaat.h)
#
# SITET (aatmahatyas
#
# SETEATT (aatmaGYaana)
#
# TT (aatmaa) = soul
#
# araroTeTft (aatmas.atattvamasi) = Thou art That Not (self + Self are differnt:Dualiey)
#
# he mind
#
# in the pure state of the soul
#
# sararenifirt: (aatmansambhavitasHl) = selfcomplacent
#
# ssiferaT (antmiyntaa) = the feeling of onencas
#
# to imbibe, to make one’s own, to train oneselt
# ieide
# knowledge of self
#
# i) = beginning
# nf (aadiM)
#
# ome: (aadiFf)
# arrfeett(aadikartre) = to the supreme creator
# amrferg(andikeshhu) = ote ote
#
# sree (andy) = a name of Sun, Vishnu is among twelve Aditya
# artfere: (andityall) = the Adityas
#
# smtferemt(andityagataM) = in the sunshine
# srfemrem_(anltyavath) = lke the rising sun
#
# srffereet (aadityavarNaM) = luminous Uke the sun
# srtferar®_(andityaan.h) = the twelve sone of Adit
#
# snterarat (andityaannaMt) = of the Aaityas
#
# sree (andidevaM) = the original Lord
#
# sf&=@: (andidevall) = the original Supreme God
#
# (Masesloe.sing.) the fest
# SHTeTe (andhateva) = fix
# arent (andhaaya) = resigning
#
# 28
#
# Extracted Text from Page 29:
# anfirtr (andhikyn)
# anfircre (andhipatya) = overlordship
# anfrtt (andhipatyaM) = supremacy
# srrortere (aadhynatmikaM)
#
# STAT (aanana) = Paco
# STF (aananaM) = face
# TF (aananda) = happiness
# STAT (aanandana) = happiness
# area: (aanandamayatl)
# arate (aantaradeshliya) = within the country mainly for transaction?
# arora (aantarjanlaM) = (n) internot
#
# SHE (aap-h) = to obtain
#
# TT (aapalt) = water,
# ‘TF: (aapaNaH) = (m)
#
# I of great happiness
#
# Tost (aapannaM) = achieved
# sre: (aapannaalt) = gaining
#
# STE (wap) = water
#
# sarge (aapuryamaaNaM) = always being filled
#
# TPF (aapuurya) = covering
# ke leave of
#
# ‘The Sed, Oth, Oth and 12th Houses
#
# sar[at (aapnuynaM)
# sarttat (onpnuvanti
# sarah (napnoti) = achieves
#
# ramet (anpravaasi!) = (m) immigrant
#
# SETA (aaplutas) = immersed
# ‘Ter (anbda) = year
#
# »gnostication, also varshhaphala
# tavanaat.h) = up to the Brsbmaloka planet
# (2) ornaments, jewellery
#
# ampere (aabhansaM) = the original source
# STATT (aamanaska)
#
# Sarre (aamaya)
# STTTTT (aamraphalam.h) = (a) mango (the king of fruits)
# SITET (aamla) = sour
#
# he mind free from desire
#
#
# Extracted Text from Page 30:
# ‘rt (aamlaM) = (n) acid
#
# ‘TET (aayatam.h) = (n) rectangle
#
# arama (aayanaa.nsha) = Precession of Equinoxes, Used to convert Tropical positions to
#
# Sidereal
#
# SHreTT: (aaynatall) = (mm) import
#
# SFTETTT (aayaatana) = abode, resting place
#
# TE: (anya) = [long] life
#
# TEE (aayudhaM) = weapons
#
# TEeT=t (aayudhaanaaM)
# rake) = Significator of Longevity which is Saturn
#
# (2m) commision
#
# crying out of desperation for help, ritual
#
# saree (aarabdhat.h
#
# saree (narabdharn.
#
# HTT (aarabhate)
#
# ogun
#
# ion in the beginning
#
# (en) policeman
# (9 policewoman
#
# ITE (aaruDha) = The sign which is as distant from the lord as the lord is from the house
# concerned
#
# SIFT: (aarurukShoH) = who has just begun yora
#
# sre (ear
# sreett (nar
# reat? (anruuDhaani)
# STATE (anrogya)
# SEIMOEATE (anrogyashanstea) = hygeine
# TMT: (aaropatl)
#
# ort (ancta)
#
# fer (aardita)
# STF (aardea) = wot
#
# Extracted Text from Page 31:
# ofa (aardratan)
# argh (ane)
#
# TF (aarys)
# srrimen(naryaeamaaja) = Aryan group
# airat (aaryaa) =
# saret: (aarhaatl)
# Tree (lamba) = support
# STEER (alambate) = to recline
#
# ones
#
# Sixth nakshatra
#
# ) a respected! woman
#
# snfargfi (aall.ngati) = to embrace
# STATE (anlokyalckhanaM) = graph
# to think, to contemplate
#
# quarters
# form or incarnation
#
# overwhelmed
# fee: (aavishhTaHt) = overwhelmed
# satfefirt (aavikShita) = descendent of avikshit
#
# .e, marutea)
#
# sagt (aavRitaM)
# SET: (aavRitaHt)
# SET (aavRitaa)
# STEM: (anvRitanH)
# (oawniteing)
#
# to wish, to hope, to desire
# HTT (aashaya) = (mase) resting place
# srrafeenr: (aashayasthitaalf) = situated within the heart
#
# a
#
# Extracted Text from Page 32:
# ‘aTaTTTH (aashanpaasha) = entanglements in a network of hope
#
# arrmfevt(aashaapiNDaM)
#
# nfs (anshita) = (a) Baten, given to ent;
#
# anfat (aashitaM) = eating
#
# nfs (anshina) = old (also heard as asi
# 0 give aashievaad,
#
# AshA-+pindaM, desire +lump(piNDaM also mea
#
# STIPE (aashulkaM) = (n) import duty
# Tet (aashcharyaM)
# caret (aashcharyamayaM) = wonderful
#
# with wonder, surprise
#
# sare (aashcharyaaNi)
# SITET (anshrama) = a yoga centre oF school
# dependence, leaning
#
# all the wonders
#
# srat (aashrayan)
# TTT (aashrayet-h)
# wife (anshi) = to take shelter
# Mt) = aseuming
# refuge
# accepting
# shelter of
#
# (0) assurance
# STRPPETETH (aashvansayaamansa) = encouraged
# snfet (aashvinii) = First nakshatra
#
# [THTRIE (aasanastham.h) = (lotus lke.)posture.stood
#
# TFT (aasane)
#
# aTMTET (ansandaya)
# (oasandya)
# (asit.h) = was/existed
# (aasina) = by the weapon
#
# rere
# ante
# ante
# anfet (aati
# antes:
# amit
#
# nthe seat
# (causative of aa-+sad) resort to
#
# (easinalf) = eaters
# (easiitch) = was
#
# 2
#
# ce-ball given
#
# Extracted Text from Page 33:
#  (aasiinalt)
#
# SAT (ansurad)
# Sarr: (aasural)
# sarqrfreart(aasuranishchayaan.h) = demons
# SATA (aasurii) = demonine qualities
#
# atheistic
#
# (6) confidence, interest
# following
# ‘boing situated
#
# Fm _(ichehh
# ‘Fuf (ichehhati)
#
# resent participle of ish, to wish
# performed
# by worship
#
# Far (iDaa) = the channel on the left of the spine
#
# FE (jDyaM) = worshipable
#
# TFT: (ital) = besides this
#
# TFT (itara) = Other
#
# TET: (itaralf) = common
#
# Extracted Text from Page 34:
# ‘mutual, each-other
#
# (Gndecl) here and there
#
# [FATETR(:)_(itihaasa(H)) = history; epic
# Fee (itthaM) = lke that
#
# ‘wert (idaaniiM)
# FT Gani,
# FF (inaw)
# FF (indraHf) = the god Indra
# {FETT (indeachaapa)
#
# iiyagocharanll) = the objects of the senses
# [SPURT (indriyngraamaM) = the full set of senses
#
# ‘epee (indriyajaya) = mastery of the senses by controlling the desires
# ‘Topaea_(ndriyasya) = of the senses
#
# ‘parent (indriyasyaarthe) = in the sense objects
# ‘eyarat_(indsiyaaNaaM) = of the senses
#
# opaifr_(indriyaaNi) = the senses
#
# oparrtm: (indriyaaraamalt) Jed in sense gratification
# brunet (indriyaarthaan.h) = sense objects
#
# forarihet: (indriyaarthebhyalf) = from the sense objects
# aorarity(indriyanrthoshhu) = in sonse gratification
#
# rie: (indriyebhyall)
# PFE (indrivaitt)
# FF (indro) =
# 67 (indhana)
# ‘et (imaNt) = (from
# ‘ear: (imaakt) =
# ‘ET (imnan.h)
#
# more than the senses
#
# by the sensor
# Lord Indra
# fuel
#
# Just lke or as if
# Fat (lshat.h) = a little
#
# TFA: (ishhubhiFl) = with arrows
# FE (ishhTs) = of all desirable things
#
# au
#
# Extracted Text from Page 35:
# FE (ishhTwM)
# err: (ishhTaalt)
# Fert (ishhTaan.h)
# fet (ishhTikna)
#
# od
# et (lidRishhant)
# fect (irshiyyan)
#
# E87 (lishvarn)
# E8t (lishvarant)
#
# ShaNaM)
# Ear (iikShate) = (1 ap) t0 see
# Fer (uktaM) = sai
#
# Fer: (uktatt)
# ETT: (uktank) = are said
#
# infu activi
#
# ‘FATT (ugraasana) stretch posture
#
# 3: (ugraifl) = by terrible
#
# TSR (uchchaars) = prom
# TOME (uchchaarya) = having uttered oF pronounced
# Te (uchchailty
#
# FRATH (uchehalffahravasaM) = Ucesiharava
# eq (uchehha) = Exalted Planet
#
# ition,
#
#
# Extracted Text from Page 36:
# ‘yoqe (uchchhabda) = loud sound (masc)
# “SPST (uchchhishhTaM) = remnants of food eaten by others
#
# RET (uchchhoshhaNeM) = deying up
#
# afegA (uchehheiteM) = high
#
# Tee (uchynte) = ie said
#
# FTF (ulivala) = radiant
#
# aprraft (ubDaayayat) = to fly
#
# APT (uDDiyaana) = a fetcer oF binding involving the raising of the diaphragm
# ) = it in anid
#
# FRET (utkaTaasana) = the the hunkering posture
# RTE (utkaNThayaa) = (instesing.) feelings
# AFIT (uthRityamaana)
# FEE (utkRishhTa) = excellent
#
# FET (uthochakl) = (m) bribe
#
# TeRPT (utkraanti) = evolution
#
# ‘TeRT (utkenamati) = gives up
#
# ‘TERT (uthraamanteM) = quitting the body
# ‘THAAT (utta.ngatas) = greatness
#
# FAR (uttama) = exceptional
#
# me who is ent up.
#
# Ft (uttaraM) = covering
# aeraifert (uttaradaayitvaM) = (2) responsibility
#
# FATET (uttararuupaM) = having it in the northern direction.
# aerrarertr (u i) = Twolfth nakshatra
#
# TATENETE (uttaranbhandrapada) = Twenty-sixth nakshatra
#
# FATT (uttaraayaNaM) = when the sun passes on the northern side
# FATT (utearaashhaDhaa) = Twenty-first nakshatra
#
# ‘FATT (uttaana) = an intense stretch
#
# “aFme (uttiehh Tha) = got up.
#
# ‘afrer (uttish
#
# TAF (uttu.nga)
# ‘Fe (utthaM)
# ‘fear (utthita) = stretched
# aframt (utthitas) = present
#
# eh (utpattt) = production
#
# FR (utpad.h) = to obtain
#
# FTF (utpannaM) = produce
#
# afer (uepaaTin.h) = (mase) pullerup
#
# {aranphia
#
# Imp.lt P.pLPP)get ups
#
#
# Extracted Text from Page 37:
# TEA (utpandashulkaM)
# ehfemT (utpiiThikan)
#
# HAT: (utprapantaHl)
# err (utpravaasii)
# ere (ueplavate)
# FAT (utsanna) = spoiled
#
# (Mfae.Nom.sing.) festival
# rarernt (utenadanaarthaM) = for the sake of eausing annihilation
# FATE (utsandyante) = are devastated
# FAT (wtsnahia) = onthusinam
# {slideyult) = would he put into ruin
# ive up.
# send forth
#
# () water
# fe (wdadhi) = son
# FET (udapaane) = in a wll of water
#
# ET (dara) = generous
# FETT: (udanraaHt) = magnanimous
# seh (a
#
# sat:
# TEETE (udaabRitya) = i
# erty (udlitchii) = (f) north
# ETAT (uduudashan) = Vinshottari Dasha
# ESEAT (udgachehhati) = to overflow
# [FATT (udgnara) = expression
#
# a
#
# Extracted Text from Page 38:
# to dcaw up (water fom a well)
# FET (uddharet.h) = one must deliver
# Far (ddhaaraNs) =
# ‘T_T (uddhRitaM) = that which had been lifted
# ETI (ddhvahanut) = she whos hearing oF carrying the load
# FFF (udbhavaM) = produced
# ‘onaetion
# lined
# FETT (ndyatanlf) = trying
# EF (udyama) = industriousness
# ORT (udyamena) = (mtcinteS) offort; exercise
#
# (m) gardener, mali
#
# iyogin.h)
# Fat (udvarta)
#
# 3a (udvasha)
# HAT (advice
# HET (udvijeth) = become agitated
#
# (m) project, undertaking
# ITE: (upagraball) = (mn) satellite, spacceraft
# ITE (upachayn) = Houses of earning (2,0,10,11)
# TTT: (upachaarsH) = (m) remedy, treatment
# aTifreT (upachaarikaa) = (f) nurse
#
# FATT (upajaayate) = takes place
#
#
# Extracted Text from Page 39:
# ‘FraTET (upajnayante) = are born
# ‘FrTBET (upnjuhvati) = offer
# VET (upadaanaM) = (n) gratuity
# AEH (upadesha) = advice
# Wm: (upadeshalt)
# ita (upadeshay
# air (upadekShyant!
# FVFET (wpadrashhTaa) = overseer
# TET (upadhaanam.n) = (2) pillow
# RATT (upadhaaraya) = know
# TUT (upanagarain.h) = (a) suburb
# TTT (upananma) = alias
# ARE (upanishhit.h) = says the Supanishat.
# ZAPF (upanishhad.h) = the philosophical parts of the Vedas
# ATT (upaneteam.h) = (n) spectactes, glasses
# FTAUTTe: (upanyaasakaF) = (m) lecturer
#
# having obtain
# ign which is as apart from the 12th lord as the latter
#
# advice
#
# from the 120,
#
# THOR (upapadyate)
#
# TTF (upapannad)
# TEA (upabandhal)
# HHT (upabhoga) = consumption
# TF (upamaM)
#
# RT (upamaa)
# emer (upayaan
#
# compared to
#
# comparative
#
# et (upayogitas) = Utility
# ITH (uparataM) = consed
#
# ATATE (uparanjitaitt)
# 97H (uparamate)
#
# splendid, resplondant
# cease (because one feels transcendental happiness)
# ‘one should
#
# ‘TTHTT (upalablyate) = can be perceived
# THAT (upalipyate) = mixes
# FATT (upavastu) = (a) by-product
# afefe: (upavidhiFt) = (ma) by-law
#
# sat down again
#
# AE (upavishhTha) =
#
# Extracted Text from Page 40:
# THTET (upasevate)
# TERT (upasthaa
# THA (upasthe) =
#
# (2m) Iubeicane
#
# aries (upandhitt)
# IF (opaaya) =
# ATT: (upanyataHl) = by appropriate means
# 3947 (upaarjana)
#
# ‘FerEaT: (upaashritaslt) = being fully
# ‘FerEe (upanshritya) = taking shelter of
# FATE (upstate) = worship
# FUATTTE (upsahaaragRiha) = restaurant
# FUETTET (upaahaaragRiham.h)
# FAT: (upetaHl) = haaving reached or at
# FHT (upetya) = achieving
# disregsed
#
# FAH (uruka) = (n) pant
# ahit (urjitaM) = glorious
#
# “0
#
# Extracted Text from Page 41:
# FHT (uvancha)
# Baar (ushanas) =
# afeeaT (ushhitvaa)
# 5 (ushhTra) = a camel
# 5: (wehiTeaHt) = (m) camel
#
# FETA (ushhTrapakShit) = (m) ostrich
# FETT (ushhTrassana)
# eT (usihNa)
#
# after dwelling
#
# Far (auyate)
# FE (wun) =
# FF: (wurwult)
# HF (witha) = (P) enceey
# aT: (asNannabhaHl) = (m) spider
# Bet (uurNaa) = (f) wool
#
# x ‘alse
#
# redhvamukha) = face upwards
# wetrr: (wurdhvaretalt)
#
# “FOnEATTATAT _(wurdhwvahastattanaasana)
#
# FE (iu
# FT (RNa)
# TT (RiNapatraM) = (n) debenture
# eT (RitaM) = truth
#
# RT (Ritu) = seasos
#
# RTH (RituunaaM) = of all seasons
# BRT (Rite) = withour, except for
#
# BRE (RiddhaM) = prosperous
#
# a
#
# Ihvaprasaaritackapaadaasana) = balancing forward posture
#
# celibate intending to control(upward) the semen
#
#
# Extracted Text from Page 42:
# erent sages
# by the wise sages
#
# OF: (okalt) = one
# TTR (okatvaMt) =
# THT (chatvona)
# FET (ckada.ntaM)
# UFEATT (ckadasntaaya) = to the one-tusked
#
# TETEE (ckamakSharaM) = pranava
#
# TeAmfett (ckamovandvitiiyaM) = one without a second
#
# fone who his a single tase
#
# emt (ckasthaM)
# TefeT_ (ckasmin.h) = in one
# Tyr: (ekaaH) = one
#
# aT (ckaakii)
# RTT (ckaagra) = one-pointed
# with one attention,
# with fal
# TTRTAT (ckaantaM) = overly
# TAT (ckaskSharaM) = the one syllable
# TR (eke)
# TT (ckena) = alone
# DF (chaikaM) = one by one
# TERS (claikamakSharaM)
# T¥TEE (cko.ahaM) = T the one single being
#
# coach and every word
#
# TTA (etann.h) = all these
# ‘Tm (etaaniy = all these
# TET (etaavat.h) = this much
# ft (oti) = atta
#
# Th (ote) = they
# TT (etena) = by ein
#
# 2
#
# Extracted Text from Page 43:
# ‘Rat (eteshhaaM) = of the Pandavas
# OR: (etait) = all these
# ‘Ta (edhate) = (1 ap) to grow
# ‘ath (edhan.nsi) = Brewood
# TT (enaM) = this
# ‘ft: (ebhiFt) = by them
#
# to these demigods
# 1d t0 put emphasis )
# it (evaM) = thus
#
# Jnvarya) = desire for power
# STETIAT (o.nkaraasana) = the OM posture
# THT (ajant) = concentrated paychic power
# SHTAT (ojataa) = by My energy
# sre (oshhati) = (1 pp) to burn
# stifine (audyogika) = industrial
# by comparison
#
# = bracelet
# anyone (oF someone)
# (Mase.Nomsing.) throat
# ‘neck
#
# RE (ka.nThe) = in yhe neck
#
# a
#
# Extracted Text from Page 44:
# (inate) tortoise
# amp black
# STR: (laJNehulall) = blouse
# ‘Fer (ka TAHT) = (m) earpot
# ‘Fen (kaTaakSha) = glance
# we (kai) = hip
# ‘wie: (laTiH) = waist
# ‘sews (kaTitnasana)
# HETERE (kaTivasteam.h) = (n) underwear
# int
# (2) pungent, hot
# a) = tougl
# small bie
# [FIT (laNatvn) = particularity
# ‘wfrerirar (kaNikaapiitas) = little droplet, drunk
# ‘Tar (kaNiiya) = particulate
#
# thorns
#
# fm) throat, neck
# ROE (kaNThabhuushhaa) = (f) necklace
# {RORT: (kaNThahsaralf) = (m) necklace
#
# ‘weytit (kaNDuuyati) = to scratch
#
# RET: (laNDolalf) = (m) a wooden basket
# [FATT (lataratih) = whieh
#
# Fe (athe)
# HET (kathanta)
#
# ‘UT (kathayate) = (10 up) to narrate, to tell
# re: (lathayantaHt) = talking
#
# ‘waferafoT (kathayishhyanti) = will speak
# ‘wafeentft (kathayishhyaami) = shall speak
# ‘Far (hatha) = story
#
# [RITTT (kathaamRita) = Gospel
#
# TRIAT (kathaamRitaM) = Gospel
#
#
# Extracted Text from Page 45:
# = (n) banana
#
# weet (kadai)
# weiter (hada
# ‘Fer (kadaa) = when
# ‘WEET (hadanchan.h)
# {WeTeT (kadaachana) = at any time
# ‘warfet (ladaachitsh) = at any time (past, present or future)
# ‘waft (kndaapi) = at any time
#
# TT (kanaka)
# ‘withrer (kaniinikas)
# Fe (lanTha)
# (Ganthatt)
#
# ilaM) = banana oil
#
# (m) root
#
# laasana)
# EF (landuka)
#
# ‘FAT _(Kanyaa) = Zodiacal sign Virgo
# FICHT:  (kapwTayogaHt) = (on) inti
#
# ‘wofew (kapaTika) = cunning, acheming
# FIT (kapataM) = (n) plot, conspiracy
# [ITT (kapaala) = forehead
#
# {FUT (apaalalf) = (m) human skull
#
# ‘worerft (kapaalabhati)
# [FIT=TT (kapaalnala) = fire in the forehead (227 again perhaps wrong)
# ‘FFF (kapi) = monkey
#
# ‘wit: (kapift) = (mm) monkey
#
# ‘FiTerm: (kapidlivajalf) = he whose flng was marked with Hanuman
# ‘FAT (lapota) = pigeon, dove
#
# FTTAT (lapotansana) = the dove posture
#
# process to clear the sinuses
#
# [FETTER (kamalapatenakSha)
# ‘ra (kamalas
#
# [FTATTTAE (kamalansanasthaM) = sitting on the lotus flower
# [FETT (kampate) = (1 ap) to shake
#
# ‘FeTaft (kampayati) = to shake
#
# (FT (kara) = Hand
#
# [FT (kara) = the cause of
#
# 0 lotus-eyed one
# raswat
#
#
# Extracted Text from Page 46:
# ‘Frain (karstalabbikShaa) = alms in the palms
# [FrTAR (keratalam.h) = (a) palm
#
# ‘Free: (karadtipall) = (m) torch, flashlight
#
# ‘FTA (karabhorw) = fair-limbed
#
# ‘FTF (karalaM) = terrible
#
# {FTTH (karavanla) = sword
#
# [Fret (Karavanvahai) = may we do
#
# [FTRTT: (karasthanHf) = oblaining(literally standing) in hie very hands
# [TATE (Laran.nshukam.h) = (n) fll-slooved shirt
#
# ‘TT (Laranla) = drondful
#
# ‘wire (katishhye)
# ‘rm: (karuNaH)
# ‘wre (karuNan)
# [Tort (karuNaakara.n) = the one induces compassion,
# ‘Frame (karuNaarNavaM) = the ocean of ‘karuna’ (compassion)
#
# the sentiment of sorrow
#
# witft (karoti)
#
# ‘witht (laromi
#
# ‘HTP (karosi) = you do
#
# ‘FAT (Jara) = hands (lower arms)
#
# ‘FF (larka) = The Zodincal sign Cancer
#
# HE GarkaT) = (f) eueumbor
# {FETT (karkarogatt) = (m) cancer
#
# ‘eh (kara) = car, also KarNa from Mahabharata
# wt (larNaM)
# swe (kara
# ‘wifeTTeT (karNapiDansans)
# ‘weferr (karNikaar
# switir: (karNebhifl
# ‘winfr (lartayati) = to cut
#
# ‘WHT (kartari) = (f) seissors
#
# ‘wt (kartavya) = should be done
#
# ‘whet (kartavyaM) = prescribed duty
#
# ‘wtenfr (kartavyaani) = should be done as duty
#
# ‘ent (kartas) = doer, also attributed to main person in a household
#
# rs
#
# Extracted Text from Page 47:
# ‘wit (kartanraM)
# ‘rt (kartuM) = to perform
#
# ‘wirffir (kartumarhasi) = kartuMt + ashasi:to do + deserve (You are entitled or you should)
# ‘wtrt (kartRtitvaM) = proprietorship
#
# ‘FET (karmajaM) = duo to fruitive activitios
# {FET (karmajaa) = trom fruitive work
# FETTE (karmajaan.h) = born of work
# ‘FET: (karmaNaHl) = than fruitive action
# ‘wer (larmaNaa) = by work
#
# ‘watt (larmaNaaM)
#
# ‘wet (karmaphalant) tivities
# ‘eherart: (karmaphalatyaagall) =
#
# ‘ere (karmaphalansa.ngaM)
# ‘THTT (karmaphale) = in feutive action
#
# {THTY (karmabandhaM) = bondage of reaction
#
# ‘WHeATT: (karmabandhanall) = bondage by work
#
# ‘Ter: (karmabhiff) = from the bondage ofthe law of fruitive actions
# ‘FEET (harmayoga) = unselfish actions
#
# ‘rit (karmayogaM) = devo
#
# {EET (karmayogall) = work in devotion
# ‘FATT (larmayogeNa) = by the linking process of devotion
# ‘SEETATT (harmasa-nnyansaat.
#
# ‘TiTfyTT (karmasa.nginaaMt)
# ‘TTF (larmasa.ngshiy)
# ‘wiinyT (karmasa.ngena)
# ‘FHT (Karmasu) = in all activi
# ‘wit (karmasNaM)
# ‘wviat (LarmaaNaaM)
# ‘waif (harmaaNi)
#
# nunctation of the results of fruitive acto
#
# in comparison to the renunciation of fruitive work
# ho are attached to fruitive work
# in the association of those engaged in fritive activities
#
# ion with fruitive activity
#
# dees
# ‘sfther: (karmibhyaHf) = than the fruitive workers
#
# ‘THPrT_(karmendriya) = an action organ, e.g. the hands or feet
# ‘witraifi (karmendriyaaNi) = the five working sense organs
# ‘THPFR: (harmendriyailt) = by the active sense organs
#
# {FE (karshha) = attracted, contacted
#
# {TE (harsh) = farmer
#
# fa
#
# Extracted Text from Page 48:
# (AlivayanukaraNa) like a iver flow
# ifleator of marriage partner which is Venus
# 1M) = of subduers
#
# fight discord /argumene
#
# FATE (kalatrakaaraka) =
# TUT (kala
#
# FE (lalaha)
# eT (Jalas)
# FAT (boalannaad
#
# T may be wrong here)
#
# the current, pleasure-oving age
# ‘wit (lalilaM)
# ‘FST (LalushhaHt) = smeared, blot
#
# dense forest
#
# the tree tha will give you anything you ean
# ...
# [FUT (yuktas) = with
# [FeT: (yuktaalt) = engaged
# having the mind Arial set on
#
# relfconnected
# ty + proportion
# boing yoked
# {TET (yuktena) = being engaged in meditation
# get: (yuktaiff) = engaged
# [ge (yuktvnn) = Being absorbed
# FT (yun) = World Ages
#
# 1h) = simultaneously
#
# FET (yuiyate)
# [THEE (yuiyanva) = engage (fieht)
# ETT: (yuNjatalt) = constandy engaged
# FAT (yuINjan.h) = practicing
#
#
# Extracted Text from Page 153:
# FOhe (yuINGlita) = must concentrate in KRishhNa consciousness
# ‘ETAT (yuINiynat.h) = should execute
#
# IT (vuta) = quipped with
#
# Te (yutaka) = (n) shict
#
# [FE (yuddha) = Planetary War
#
# E_(yuddhaMt) = war
#
# [qghTaTTET: (yuddhavishaaradaaHl) = experienced in military science
# [TEM (uddhaa.h) = chan fighting
#
# ‘TENT (yuddhaaya) = for the sake of Aghting
#
# FE (odane) = in ene
#
# ATHPT: (yudhaamanylf) = Yudhamany
# air (yudhi)
# afer: (yudhial
#
# BTT Guten)
# RTT (vuyuthaanaff) = Yuyudhane
# ET (yuvanhy = young
#
# [UT (yuvan) ~ the two youthe
#
# FETT (yusbhmaasu)~ (Mase-Loe.Pl.) among yourselves
# {BE (yuutha) = (neu) collection, troop
#
# (ye) = those who
#
# ‘rcear (gethechchayan) = (adverb) at will
#
# a (yena) = by whom
#
# aeTFeT (ounakenachit.h)
# er (yoshhnadt) = whore
# Gye) = who
#
# eh (yo.
# Aiet (poor
#
# aT (yoga) = offort
# whe (yoga) =
#
# SwakShetralike strength. Also a combination that produces a Yoga
# ‘cheerenes (yogedaNDansana) = the you
#
# ‘eareat (vogadhaaraNaaM) = the yogie situation
# ‘ETPTAT (voganidras) = the sleep of yogs, where the body is resting but the mind is awake
# mfr (yoganivoita) = econtroled by yous
#
# ‘AETET (yoRaphalaM) = (a) sum, addition
#
# ‘AETEHT (yogabalena) = by the power of mystie yous
#
# aff posture
#
#
# Extracted Text from Page 154:
# ‘rere: (yogabhrashh Ta)
# {TETAT (yogamaayas) = by Internal potency
# ‘iit (yogamaishvaraM) = inconceivable mystic power
# ‘HrTaMT: (yoguyaGVaaH}) = aacrifice in eightfold myaticiamn
# ETAT: (vogayuhtalt) = engaged in devotional service
# {EeTTTMAT (yogayuktaatmaa) = one who is dovetailed in KRishhNa consciousness
# {RETTT: (vogaratall) = indulging in youn
# ‘WrfeTAT: (yoravittamaall) = the most perfect in knowledge of yous
# ares (vogasa.nsiddhiM) = the highest perfeetion in mysticism
# airefint (vogasa.nGYitaM) = called trance in youa
# {ETAT (vogaovayaa) = by performance of yous
# ‘TA: (yogasthalT)
# TET (yogasya
# {TT (GogakShemaNt) = family welfare
# from the mystic link
# for the sake of devotional s
# ‘area: (vogaaruuDhalt) = elevated in youn
# ‘tia (yogaasana) = the anchor posture
# ne who practices yoga (Male)
# Life (yoginaM) = yogi
# ‘itfre: (yoinalt) = mystics
# {PTET (voginaaM) = of the devateos
# “thr (yoginily = one who practices yogn (Female)
# ‘irr (voRit) = one who practices yore (Male)
# in work without feuitve rose
# In devotional service
#
# TET (yoxeshvara) = O Lord of all mystic power
# UTET: (yogeshvarall) = the master of mysticism
#
# by devotional service
# ‘work in devotional service
#
# like
#
# EET (yoddhavyant)
# angATTT (voddhukaamnan.h) = desiring to Bight
# ‘EnrTS: (yodhamukhyaiHl) = chiefs among the war
# ‘rtiert (yodhaviirsan.h) = great warriors
#
# ‘inet: (yodhaaHf) = the soldiers
#
# eT: (yonayall) = sources of
#
# {ET (yoni) = species of life
#
#
# Extracted Text from Page 155:
# al
#
# hu) = into the wonnbs
#
# ‘Err (yoni) = vagina, womb, oF the source
#
# FH! (ra.nj-h)
# Ter (rakta)
# ‘Tt (raktaM) = the red one (raktaM may mean blood also)
# THT: (raktaH) = attached
#
# TET (raktagandha) = red scent
#
# TeTTET: (raktapuashhpailf) = with red lowers
#
# TeTTETT (raktaraJNjita)
# ‘TETTTTAR (raktavansasam.
# TeThs (raktahling) = bloodless
# TEPSPTA (enghukulatilakant)
# ‘TENT: (raghuttamaH)
# THIET (raghuna.ndana) = the delighter of the Raghus
# THTETT (raghuna.ndanam.h) = thedelighter of Raghus
# TEP (raghunandana) = Rama
#
# ‘TETUFT (raghunsathasys) = lord of the Raghu's(eAma descer
# ‘TEMA (raghunaatheaya) = to the lord of Raghu
#
# the chosen Raghs.
# ‘TETH: (raghuuttamall) = the best of the raghus (raght-descendants)
# ‘TEMA (raghuuttamau) = the best two of the Raght race
#
# THT (ra.ngavalli) = (f) rangott
#
# TR (racha
# TAT (rachanaa)
#
# construction, arrangement
# construction, arrangement
#
# ‘Trae (rachayati)
#
# 10 mode of passion
# THR: (radakaH) = (m) washerman, dhobi
# ‘Taft (rajani) = night
#
# ott (rai a
#
# ote (enjaniichara)
# THT (rajara) = mobility
# THT: (rajatalf) = from the mode of passion
# ‘ToT (rajasi) = of the mode of passion
#
# ‘moon, demon
#
#
# Extracted Text from Page 156:
# THAT (rajoguNa) = the mode of passion
# fom) rope, straight line
#
# THHT (raJNjana) = entertainment, delight
# f) a giver of delight
#
# or (ea
#
# rower (raNakarkasha)
#
# reemiry (raNara.ngadhii
#
# ‘TATE (raNaat.h) = from the battlefield
# ‘on the battlefeld
#
# THT (raina) = precious stones
# ‘TE (ratha) = chariot
#
# THT (ramaunte) = revel: enjoy (Ve.PrITT P PLAP)
# ‘THT (ramate) = delights
# ‘rafat_(ramanti) = enjoy transcendental bl
# ‘THTETT (ramaavaasa) = the abode of rama (Iaksheni)
# ‘TH (rame) = Oh! ramA (Shiva tells ths sloka to his consort PArvati
# ‘THe (cameshaM) = the lord of ramA(6ItA)
#
# ‘THIET (rambhiaaphala) = plantain
#
# ‘AF (rartjana) = Ent
#
# he (envi
# ‘TPR: (ravitt) = the sun
# ‘hear (ravivanra) = Su
#
# ‘name of Sun,
#
# ving up
# TATEF: (rasaatmakall) = supplying the juice
# ‘TATIT (rasaayanaM) = (n) chemical
# ‘TRTETHTET (rasnayanashaastes) = chemistry
# ‘TRETMTETT, (rasnaynnashaasteam.h)
# ‘rar (rasnale
# THT: (rasyaall) = juicy
# ‘Taft (rahasi) = in a aechuded place
#
# chemistry
#
#
# Extracted Text from Page 157:
# ‘THRE (rahasyaM) = mystery’
# ‘THE (rakSh.h) = to protect
# ‘TH: (rakShaH) = the rAkshasnas
# (em) guard, protector
# protection
# ‘Tart (rakShaNaayn) = for protection
# ‘raft (rakShati) = (1 pp) to protect
# ‘THT (rakShata) = adj- devil
#
# protecting armour
# ‘raft (eakShaa.nsi) = the demons
# chit (rakShitaM) = the person who has ben protected(by)
# fier: (rakShitatl) = (past part.mate.nom.S) the protected one
# TET (rakShya) = protection
# riff (raakiNii) = the goddess in evadhishthana
# ‘THT (rnaga) = Anger
# ‘TrTaPT (rangavati) =
# ‘Tre. (rangaatmakaM) = born of des
# ‘Toft (raagli) = very much attached
# TIRE (ranghavaM) = thew descendant of Raghi
# RAghava (RAma)
#
# he king of confidential knowledge
# fn) sedition
# doors of apalace
#
# he jewel of the kings oF the king of jewels
# ‘TrET (raajayoga) = Combinations for Status and Power
# ToTeT: (ranjarshhayaHf) = the saintly kings
# crrfrat (raajavidyas) = royal policy, king-eraft, statosmanship, state-policy, the training in the
# traits and skills of nobility
#
# in the mode of passion
# in the mode of passion
# ‘TTATAT (ranjasabhaa) = assombly of king,
# ‘TIAET (ranjasasya) = to one in the mode of passion
# ‘TOAT: (ranjasantt) mode of passion
# ‘Trae (ranjasika) = Regal planets - Sun, Mars and Venus
# ‘rath (raajasl) = in the mode of passion
# ‘TTT (raajaha.nsa) = swan
#
# those situated in
#
# ‘rronfcrr (raajandhiraaja) = Overking of kings
# ‘rrr (ranjiiv) = Ions
#
#
# Extracted Text from Page 158:
# ‘rrfte(ranitiva) = lotus
# ‘TroheaT (canivanetraM = the lotus-eyed
#
# THRE (ranjesndeaM) = the lord of kings
#
# ‘TRE (raniya) = Kingdom
#
# ‘Trt (eaaiyaM) = kingdom
#
# “TIFERNATCT (ranjyasukhalobhena) = driven by greed for royal happiness
# TITTET (eanjyasya) = for the kingdom
#
# TTT (ranjyena) = i the kingdom
#
# Te (enatea)
#
# ‘rife (raat) = night
# ‘rE (eaateiNt) = ni
# cre: (rant) = ight
# cep (rantibnitant)
#
# night-done
# = the pair of night and moon
#
# ' beloved
#
# ‘rrm: (rnamaH) = Rama
# ‘TITNTT (raamakavachaM) = rAmearmour
# TrEeT (raamakR
#
# TIRSET (raamakRishhNasys)
# ‘Try (raamacha.ndea) = rAmachandra
# ‘Tirtp: (raamachandralf) = rAma
# ‘THTPT (raamacha.ndram.h) = rAmachandra
# ‘Timer (raamacha.ndraaya) = to rAmachandra
# ‘rrr (eaamacha.ndreti) = saying 'rAmachandea!
# THE (roamacha.ndro) = Lord RAmachandra
# THT (raamanaama)
# TIATST (raamanaamnan) = by the name of rAma
# TIETHTT (rnamabalopetaaM) = that whi
# ‘rime (raamabhadra) = raama who gives the wellbeing
# viraaya) = to the good.giving, protecting RAma
# rAmabhadea- iti, saying *rAmabh
#
# na, a saint from Bengal
#
# che name of rAma (uttering of the word ‘rAma’ only once is
#
# Jas boon attained through rAma’a strength, power
#
# ‘rAma armour or rama- protection
# ‘rrvrat (raamarakShaaM) = raamarakshA (hymn)
#
# ‘cormareheat (raamarakShaastotrajape) = in the chanting of rAmaraksha hymn
# ‘romeo (eaamalakShmaNau) = ream & lakshmaNa
#
# ‘TrRRT (raamasyn)
# ‘TIRE (raamah)
# crrmmmrfer (raamaannaasti) = no one is except from Ama
# ‘TreTHrT (raamaabhoga) = sexual pleasures?
#
# Aman’
#
# Tord Rama
#
#
# Extracted Text from Page 159:
#  (caamayn) = to rAme
# raver: (reamnayaNal) = epie Ramayana, part of thas (history)
#
# TE (rama) ~ in Ramin
#
# Tein anmaNesbhtatan) the one struck by eAma
#
# TET (caameti)~ rAmnst saying thas rAma
#
# TH (ramo) = FAme
#
# Trer (cams) — demon king fom Taka who abducted he wife of Rama
# Trenfrr (ramaNanrim:h) = AvaNasya ari he enemy of eAvaNa
#
# Te (canst) = Sign ot the Zone
#
# A inhabitant of a kingdom or country, a subject, governor
# nifEe (canshhTriva) = belonging to a kingdom or country, national
#
# TMF (raashhiteaM) = kingdom, empire, territory, country, nation, people, subjects
# TITSTET (ransalaasya) = ransa dance
#
# Prgfr (ringatiy = to ex
# Free: (ripavall)
#
# fer
#
# Freq:
#
# ‘Fift: (citiM) = procedure/ practice custom,
# (ew) = light
#
# FAR: (euchilt) = taste; flavour
#
# FE (rudch) = to ory
#
# FEAT (rudchdhvaa) = checking
#
# Fe (rudea) = a form of Shiva
#
# TE: (rudralf) = the Destroying God
#
# ‘TATA (rudraaNanM) = ofall the Rudras
#
# ‘FAT (rudraan.h) = the eleven forms of Rudra
# to stop, control
#
# FF (ruupa)
# ‘FF (ewupady
#
# ‘rath (euupaaN
# ‘sft (ruupiteaM) = (n) camera
# FUT (euupeNa) = form
#
# Extracted Text from Page 160:
# rar (rokhan
# ‘rat (rekhan) = line
# ‘rarer (rekhaachitea)
#
# etching
#
# ye draw
# (0) diagram, chart
#
# 5 skateh
#
# ‘patient ill oF sick person
# (1 ap) to tke
#
# went of violence, wrath, rage
#
# deterioration
#
# climb
#
# TET (laMbodaraM) = having a long stomach
#
# [AWTETTT (laMbodaraaya) = to the long-stomached
#
# FATE (laguDa) = a club,» atiek
#
# PT (lagna) = The Ascendant oF Ist house
#
# ETE: (lagnakall) = (em) bail
#
# rsfrait (Ingnadhipati) = Ascendant lord
#
# small / infortor / 1
# light
#
# aa
#
# ET (ladduka) = laddoo, « swoet-ball
# IRE (labdhaM) = gained
#
# 7 (labh.h) = to obtain
#
# 10
#
# Extracted Text from Page 161:
# a (labhate)
# eer (labhante
# rer (labhasva) =
# it (Vabhe) = T obtain
# i (labhet.h) =
# eT (labhyn) = Rasy
# Fe: (labhyalf) = can be achieved
#
# FF (laya) = Decline
#
# ‘Ft (layaM) = tranquility oF the lull ater destruction or the Deluge
# ‘TaTT (layayoga) = yoga using the latent power of kundalini
#
# ‘TE (IalaaTa) = the forehead
#
# FHTEW (IalanTaka) = (n) forohead
#
# ‘afar (lalita) = (a) playing, sporting, dally
# ‘fat (laita) = lovely, beautiful, elegant, graceful
# ‘fat (lnltaa)
# a (lava)
# ay (lava.nga) = clove
#
# (1 ap) to got, to obtain
# do ad
#
# amorous, lovely, beautiful; grace, charm
#
# form of goddess Durga various metres
#
# rey (lavaNam.h) =
# EET (lashunamn.h)
# cr: (sath
# ‘fT (lastaM)
# ‘a (lakSha) = Lakh, 100,000 in number, also sight
# TH (lakShaMt) = target
#
# ‘ut (lakShaNaM) = symptoms indications aspect; characteristics
# mETTTET. (lakShmaNapuurvajaM) = the (earlier-born)elder of LakShmaNa
# ETT (ekShnaNannchae) = having alana he lower
# InkShmaNo)
# Tere atShmeNopetend
#
# Ihaving Lakshmana nearby
# 1, wife of Vishns
#
# lnkshyam + aten + vyApakaHfsgoal or target +
#
# ‘arfWy (laakiNti) = the goddess in manipuraka
# TET (laaghava) indness, lightness
# [TSE (aaghavaM) = with ense or lightness
#
# ‘art: (laniaiFl) = with the roasted rice, wheat fakes
# ‘AIF (laabha) = acquirement, aca
# nt (laabhaM) = gain
# TAT (Iaabhaalaabhau) = both profit and lows
# TH (Ina
#
# to pamper
#
# 161
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      20 img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
#      22 # Use Tesseract to perform OCR on the image
# ---> 23 text = pytesseract.image_to_string(img)
#      25 # Print extracted text for debugging
#      26 print(f"Extracted Text from Page {page_num + 1}:")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytesseract\pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytesseract\pytesseract.py:489, in image_to_string.<locals>.<lambda>()
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
#     486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytesseract\pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)
#     349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytesseract\pytesseract.py:282, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     279     else:
#     280         raise TesseractNotFoundError()
# --> 282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#     284         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pytesseract\pytesseract.py:144, in timeout_manager(proc, seconds)
#     142 try:
#     143     if not seconds:
# --> 144         yield proc.communicate()[1]
#     145         return
#     147     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:

# %%
import pdfplumber
import pandas as pd

# Load the CSV file containing unique Sanskrit words
input_csv_path = 'unique_sanskrit_words_ordered.csv'
words_df = pd.read_csv(input_csv_path)

# Load the PDF file
pdf_path = 'dictallcheck.pdf'

# Create a dictionary to hold the words and their corresponding page numbers
word_page_dict = {word: [] for word in words_df['Unique_Sanskrit_Words']}

# Function to find page numbers for each word
def find_word_page_numbers(pdf_path, words):
    with pdfplumber.open(pdf_path) as pdf:
        for page_number, page in enumerate(pdf.pages, start=1):
            # Extract text from the page
            text = page.extract_text()
            if text:  # Check if the page contains any text
                for word in words:
                    if word in text and page_number not in word_page_dict[word]:
                        word_page_dict[word].append(page_number)

# Run the search for words
find_word_page_numbers(pdf_path, words_df['Unique_Sanskrit_Words'])

# Convert the dictionary to a DataFrame
word_page_df = pd.DataFrame([(word, pages) for word, pages in word_page_dict.items()],
                             columns=['Sanskrit_Word', 'Page_Numbers'])

# Format Page_Numbers for easier reading
word_page_df['Page_Numbers'] = word_page_df['Page_Numbers'].apply(lambda x: ', '.join(map(str, x)))

# Save results to a new CSV file
word_page_df.to_csv('sanskrit_words_with_page_numbers.csv', index=False)

print(word_page_df)
# Out:
#       Sanskrit_Word Page_Numbers
# 0                 ॐ
# 1              ॐकार
# 2                 अ
# 3             अंकुश
# 4     अंकुशधारिणम्‌
# ...             ...          ...
# 9284   शल्वृपोप्णहट
# 9285          ष्णं;
# 9286      ॐल्टपाश्प
# 9287          पिणत)
# 9288        हस्तपाद
#
# [9289 rows x 2 columns]

# %%
import pandas as pd

# Load the two CSV files
sanskrit_words_df = pd.read_csv('unique_sanskrit_words_ordered.csv')  # Contains Sanskrit words
transliteration_meaning_df = pd.read_csv('sanskrit_dataset_modified.csv')  # Contains transliterations and meanings

# Assuming the transliteration_meaning_df has columns: 'Transliteration' and 'Meaning'
# and sanskrit_words_df has a column 'Unique_Sanskrit_Words' that corresponds to the transliteration.

# Merge the two DataFrames based on the common key (assuming Unique_Sanskrit_Words corresponds to Transliteration)
merged_df = pd.merge(transliteration_meaning_df, sanskrit_words_df, left_on='Transliteration', right_on='Unique_Sanskrit_Words', how='outer')

# Optionally, you can drop the 'Unique_Sanskrit_Words' column if it's redundant
merged_df.drop(columns=['Unique_Sanskrit_Words'], inplace=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_transliteration_meaning_sanskrit.csv', index=False)

print(merged_df)
# Out:
#       Transliteration                            Meaning
# 0                 NaN                                NaN
# 1                 NaN                                NaN
# 2                 AUM                   Primordial Sound
# 3              Dayate                             to fly
# 4       DukRiJNkaraNa  grammatic formula “DukRi.nkaraNa”
# ...               ...                                ...
# 18393             NaN                                NaN
# 18394             NaN                                NaN
# 18395             NaN                                NaN
# 18396             NaN                                NaN
# 18397             NaN                                NaN
#
# [18398 rows x 2 columns]

# %%
import pandas as pd

# Load your data
df = pd.read_csv('unique_sanskrit_words_ordered.csv')

# Calculate the total number of characters in the "Unique_Sanskrit_Words" column
total_characters = df['Unique_Sanskrit_Words'].str.len().sum()
print(f"Total characters: {total_characters}")
# Out:
# Total characters: 64082

# %%
import fitz  # PyMuPDF for PDF text extraction
import pandas as pd
import pytesseract
from PIL import Image, ImageDraw, ImageFont
import io
import re

# Configure Tesseract path if necessary
# pytesseract.pytesseract.tesseract_cmd = r'/path/to/tesseract'  # Uncomment and specify path if needed

def convert_pdf_to_images(pdf_path):
    """
    Convert each page of the PDF into an image.
    """
    images = []
    with fitz.open(pdf_path) as doc:
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()
            img = Image.open(io.BytesIO(pix.tobytes("png")))
            images.append(img)
    return images

def extract_sanskrit_text(image):
    """
    Perform OCR on the image to extract exact Sanskrit words.
    """
    sanskrit_text = pytesseract.image_to_string(image, lang="san")
    sanskrit_words = re.findall(r'[\u0900-\u097F]+', sanskrit_text)  # Devanagari Unicode range
    return sanskrit_words


def create_image_from_text(text, font_path="arial.ttf", font_size=32):
    """
    Create an image from text to perform OCR for transliteration.
    """
    font = ImageFont.truetype(font_path, font_size)
    text_bbox = font.getbbox(text)  # Get bounding box of the text
    text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]
    image = Image.new("L", (text_width + 20, text_height + 20), 255)  # 255 for white background
    draw = ImageDraw.Draw(image)
    draw.text((10, 10), text, font=font, fill=0)  # 0 for black text
    return image




def extract_transliteration(word):
    """
    Convert Sanskrit word to image and perform OCR for transliteration.
    """
    word_image = create_image_from_text(word)
    transliteration = pytesseract.image_to_string(word_image, lang="eng")
    return transliteration.strip()

def pdf_to_csv(pdf_path, csv_path, font_path="arial.ttf"):
    """
    Convert encoded PDF to CSV with exact Sanskrit words and their transliterations.
    """
    images = convert_pdf_to_images(pdf_path)
    all_data = []

    for image in images:
        sanskrit_words = extract_sanskrit_text(image)
        
        for word in sanskrit_words:
            transliteration = extract_transliteration(word)
            all_data.append({
                "Sanskrit Word": word,
                "Transliteration": transliteration,
            })

    df = pd.DataFrame(all_data, columns=["Sanskrit Word", "Transliteration"])
    df.to_csv(csv_path, index=False, encoding='utf-8')
    print(f"CSV file saved as: {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "output_test.csv"  # Replace with desired output CSV file path
pdf_to_csv(pdf_path, csv_path)
# Out:
# CSV file saved as: output_test.csv

# %%
import fitz  # PyMuPDF for PDF text extraction
import pandas as pd
import pytesseract
from PIL import Image
import io
import re

# Configure Tesseract path if necessary
# pytesseract.pytesseract.tesseract_cmd = r'/path/to/tesseract'  # Uncomment and specify path if needed

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def extract_sanskrit_words(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit words before "(" in each line.
    """
    sanskrit_text = pytesseract.image_to_string(image, lang="san")  # Sanskrit OCR
    sanskrit_words = []
    
    # Process each line, only capturing Sanskrit words before "("
    for line in sanskrit_text.splitlines():
        match = re.match(r'^([\u0900-\u097F]+)', line)  # Devanagari characters before "("
        if match:
            word = match.group(1).strip()
            sanskrit_words.append({"Sanskrit Word": word, "Page Number": page_number})
    return sanskrit_words

def pdf_page_to_csv(pdf_path, csv_path, page_num=2):
    """
    Extract Sanskrit words from a specific page in PDF and save to CSV.
    """
    # Convert specified PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num - 1)  # Page number starts from 0
    sanskrit_data = extract_sanskrit_words(image, page_num)
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Page Number"])
    df.to_csv(csv_path, index=False, encoding='utf-8')
    print(f"CSV file saved as: {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "test_page3.csv"  # Replace with desired output CSV file path
pdf_page_to_csv(pdf_path, csv_path, page_num=3)
# Out:
# CSV file saved as: test_page3.csv

# %%
import fitz  # PyMuPDF
import pandas as pd
import pytesseract
from PIL import Image
import io
import re

# Configure Tesseract path if necessary
# pytesseract.pytesseract.tesseract_cmd = r'/path/to/tesseract'  # Uncomment and specify path if needed

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def extract_sanskrit_words(image, page_number):
    """
    Perform OCR on the image and extract only Sanskrit words at the beginning of each line.
    """
    sanskrit_text = pytesseract.image_to_string(image, lang="san")  # Sanskrit OCR
    sanskrit_words = []
    
    # Process each line, extracting only Sanskrit words at the start of the line
    for line in sanskrit_text.splitlines():
        # Capture Sanskrit words (Devanagari script) until the first "(" or any non-Sanskrit characters
        match = re.match(r'^([\u0900-\u097F]+)', line)
        if match:
            word = match.group(1).strip()
            sanskrit_words.append({"Sanskrit Word": word, "Page Number": page_number})
    
    return sanskrit_words

def pdf_page_to_csv(pdf_path, csv_path, page_num=2):
    """
    Extract Sanskrit words from a specific page in PDF and save to CSV.
    """
    # Convert specified PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num - 1)  # Page number starts from 0
    sanskrit_data = extract_sanskrit_words(image, page_num)
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Page Number"])
    df.to_csv(csv_path, index=False, encoding='utf-8')
    print(f"CSV file saved as: {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "test1_page3.csv"  # Replace with desired output CSV file path
pdf_page_to_csv(pdf_path, csv_path, page_num=3)
# Out:
# CSV file saved as: test1_page3.csv

# %%
import pytesseract
import fitz  # PyMuPDF
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)  # Increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image):
    """
    Enhance and preprocess the image for better OCR accuracy.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2)

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter())
    
    return image

def extract_sanskrit_words(image, page_number):
    """
    Perform OCR on the image and extract only Sanskrit words at the beginning of each line.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image)

    # OCR with Sanskrit language setting
    sanskrit_text = pytesseract.image_to_string(image, lang="san")  # Sanskrit OCR

    # Extract Sanskrit words before "(" and keep only the first word in each line
    sanskrit_words = []
    for line in sanskrit_text.splitlines():
        match = re.match(r"^(\S+)\s*\(", line)  # Match Sanskrit words before "("
        if match:
            sanskrit_word = match.group(1)
            sanskrit_words.append({"Sanskrit Word": sanskrit_word, "Page Number": page_number})
    
    return sanskrit_words

def pdf_page_to_csv(pdf_path, csv_path, page_num=3):
    """
    Extract Sanskrit words from a specific page in PDF and save to CSV.
    """
    # Convert specified PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num - 1)  # Page number starts from 0
    sanskrit_data = extract_sanskrit_words(image, page_num)

    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Page Number"])
    df.to_csv(csv_path, index=False)
    print(f"Data saved to {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "output1_page3.csv"  # Replace with desired output CSV file path
pdf_page_to_csv(pdf_path, csv_path, page_num=3)
# Out:
# Data saved to output1_page3.csv

# %%
import pytesseract
import fitz  # PyMuPDF
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)  # Increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image):
    """
    Enhance and preprocess the image for better OCR accuracy.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2)

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter())
    
    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image)

    # OCR with Sanskrit language setting
    sanskrit_text = pytesseract.image_to_string(image, lang="san")  # Sanskrit OCR

    # Extract Sanskrit word, transliteration, and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)
        
        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses
            meaning = match.group(3)  # Text after "="
            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration,
                "Meaning": meaning,
                "Page Number": page_number
            })
    
    return sanskrit_data

def pdf_page_to_csv(pdf_path, csv_path, page_num=3):
    """
    Extract Sanskrit words, transliterations, and meanings from a specific page in PDF and save to CSV.
    """
    # Convert specified PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num - 1)  # Page number starts from 0
    sanskrit_data = extract_sanskrit_data(image, page_num)

    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
    df.to_csv(csv_path, index=False)
    print(f"Data saved to {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "output_page3.csv"  # Replace with desired output CSV file path
pdf_page_to_csv(pdf_path, csv_path, page_num=3)
# Out:
# Data saved to output_page3.csv

# %%
import pytesseract
import fitz  # PyMuPDF
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)  # Increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image, lang="san"):
    """
    Enhance and preprocess the image for better OCR accuracy.
    Use specific preprocessing depending on language.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2)

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter())

    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image, lang="san")

    # OCR for Sanskrit and English
    sanskrit_text = pytesseract.image_to_string(image, lang="san+eng")

    # Extract Sanskrit word, transliteration, and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)

        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses
            meaning = match.group(3)  # Text after "="

            # Filter out any non-English characters from transliteration and meaning
            transliteration = re.sub(r"[^a-zA-Z\s]", "", transliteration)
            meaning = re.sub(r"[^a-zA-Z\s]", "", meaning)
            
            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration.strip(),
                "Meaning": meaning.strip(),
                "Page Number": page_number
            })
    
    return sanskrit_data

def pdf_page_to_csv(pdf_path, csv_path, page_num=3):
    """
    Extract Sanskrit words, transliterations, and meanings from a specific page in PDF and save to CSV.
    """
    # Convert specified PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num - 1)  # Page number starts from 0
    sanskrit_data = extract_sanskrit_data(image, page_num)

    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
    df.to_csv(csv_path, index=False)
    print(f"Data saved to {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
csv_path = "output_page3.csv"  # Replace with desired output CSV file path
pdf_page_to_csv(pdf_path, csv_path, page_num=3)
# Out:
# Data saved to output_page3.csv

# %%
import os
import pytesseract
import fitz  # PyMuPDF
from pdf2image import convert_from_path
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)  # Increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image, lang="san"):
    """
    Enhance and preprocess the image for better OCR accuracy.
    Use specific preprocessing depending on language.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2)

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter())

    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image, lang="san")

    # OCR for Sanskrit and English
    sanskrit_text = pytesseract.image_to_string(image, lang="san+eng")

    # Extract Sanskrit word, transliteration, and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)

        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses
            meaning = match.group(3)  # Text after "="

            # Filter out any non-English characters from transliteration and meaning
            transliteration = re.sub(r"[^a-zA-Z\s]", "", transliteration)
            meaning = re.sub(r"[^a-zA-Z\s]", "", meaning)
            
            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration.strip(),
                "Meaning": meaning.strip(),
                "Page Number": page_number
            })
    
    return sanskrit_data

def save_all_pages_to_csv(pdf_path, output_folder):
    """
    Extract Sanskrit words, transliterations, and meanings from all pages in the PDF and save each to a separate CSV.
    """
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    # Open the PDF
    with fitz.open(pdf_path) as doc:
        total_pages = doc.page_count
        
        # Process each page
        for page_num in range(total_pages):
            print(f"Processing page {page_num + 1} of {total_pages}...")
            
            # Convert current PDF page to image
            image = convert_pdf_page_to_image(pdf_path, page_num)
            
            # Extract Sanskrit data
            sanskrit_data = extract_sanskrit_data(image, page_num + 1)
            
            # Create DataFrame and save to CSV
            df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
            csv_path = os.path.join(output_folder, f"page_{page_num + 1}.csv")
            df.to_csv(csv_path, index=False)
            print(f"Page {page_num + 1} saved to {csv_path}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
output_folder = "output_csv_files"  # Replace with the desired output folder name
save_all_pages_to_csv(pdf_path, output_folder)
# Out:
# Processing page 1 of 221...
# Page 1 saved to output_csv_files\page_1.csv
# Processing page 2 of 221...
# Page 2 saved to output_csv_files\page_2.csv
# Processing page 3 of 221...
# Page 3 saved to output_csv_files\page_3.csv
# Processing page 4 of 221...
# Page 4 saved to output_csv_files\page_4.csv
# Processing page 5 of 221...
# Page 5 saved to output_csv_files\page_5.csv
# Processing page 6 of 221...
# Page 6 saved to output_csv_files\page_6.csv
# Processing page 7 of 221...
# Page 7 saved to output_csv_files\page_7.csv
# Processing page 8 of 221...
# Page 8 saved to output_csv_files\page_8.csv
# Processing page 9 of 221...
# Page 9 saved to output_csv_files\page_9.csv
# Processing page 10 of 221...
# Page 10 saved to output_csv_files\page_10.csv
# Processing page 11 of 221...
# Page 11 saved to output_csv_files\page_11.csv
# Processing page 12 of 221...
# Page 12 saved to output_csv_files\page_12.csv
# Processing page 13 of 221...
# Page 13 saved to output_csv_files\page_13.csv
# Processing page 14 of 221...
# Page 14 saved to output_csv_files\page_14.csv
# Processing page 15 of 221...
# Page 15 saved to output_csv_files\page_15.csv
# Processing page 16 of 221...
# Page 16 saved to output_csv_files\page_16.csv
# Processing page 17 of 221...
# Page 17 saved to output_csv_files\page_17.csv
# Processing page 18 of 221...
# Page 18 saved to output_csv_files\page_18.csv
# Processing page 19 of 221...
# Page 19 saved to output_csv_files\page_19.csv
# Processing page 20 of 221...
# Page 20 saved to output_csv_files\page_20.csv
# Processing page 21 of 221...
# Page 21 saved to output_csv_files\page_21.csv
# Processing page 22 of 221...
# Page 22 saved to output_csv_files\page_22.csv
# Processing page 23 of 221...
# Page 23 saved to output_csv_files\page_23.csv
# Processing page 24 of 221...
# Page 24 saved to output_csv_files\page_24.csv
# Processing page 25 of 221...
# Page 25 saved to output_csv_files\page_25.csv
# Processing page 26 of 221...
# Page 26 saved to output_csv_files\page_26.csv
# Processing page 27 of 221...
# Page 27 saved to output_csv_files\page_27.csv
# Processing page 28 of 221...
# Page 28 saved to output_csv_files\page_28.csv
# Processing page 29 of 221...
# Page 29 saved to output_csv_files\page_29.csv
# Processing page 30 of 221...
# Page 30 saved to output_csv_files\page_30.csv
# Processing page 31 of 221...
# Page 31 saved to output_csv_files\page_31.csv
# Processing page 32 of 221...
# Page 32 saved to output_csv_files\page_32.csv
# Processing page 33 of 221...
# Page 33 saved to output_csv_files\page_33.csv
# Processing page 34 of 221...
# Page 34 saved to output_csv_files\page_34.csv
# Processing page 35 of 221...
# Page 35 saved to output_csv_files\page_35.csv
# Processing page 36 of 221...
# Page 36 saved to output_csv_files\page_36.csv
# Processing page 37 of 221...
# Page 37 saved to output_csv_files\page_37.csv
# Processing page 38 of 221...
# Page 38 saved to output_csv_files\page_38.csv
# Processing page 39 of 221...
# Page 39 saved to output_csv_files\page_39.csv
# Processing page 40 of 221...
# Page 40 saved to output_csv_files\page_40.csv
# Processing page 41 of 221...
# Page 41 saved to output_csv_files\page_41.csv
# Processing page 42 of 221...
# Page 42 saved to output_csv_files\page_42.csv
# Processing page 43 of 221...
# Page 43 saved to output_csv_files\page_43.csv
# Processing page 44 of 221...
# Page 44 saved to output_csv_files\page_44.csv
# Processing page 45 of 221...
# Page 45 saved to output_csv_files\page_45.csv
# Processing page 46 of 221...
# Page 46 saved to output_csv_files\page_46.csv
# Processing page 47 of 221...
# Page 47 saved to output_csv_files\page_47.csv
# Processing page 48 of 221...
# Page 48 saved to output_csv_files\page_48.csv
# Processing page 49 of 221...
# Page 49 saved to output_csv_files\page_49.csv
# Processing page 50 of 221...
# Page 50 saved to output_csv_files\page_50.csv
# Processing page 51 of 221...
# Page 51 saved to output_csv_files\page_51.csv
# Processing page 52 of 221...
# Page 52 saved to output_csv_files\page_52.csv
# Processing page 53 of 221...
# Page 53 saved to output_csv_files\page_53.csv
# Processing page 54 of 221...
# Page 54 saved to output_csv_files\page_54.csv
# Processing page 55 of 221...
# Page 55 saved to output_csv_files\page_55.csv
# Processing page 56 of 221...
# Page 56 saved to output_csv_files\page_56.csv
# Processing page 57 of 221...
# Page 57 saved to output_csv_files\page_57.csv
# Processing page 58 of 221...
# Page 58 saved to output_csv_files\page_58.csv
# Processing page 59 of 221...
# Page 59 saved to output_csv_files\page_59.csv
# Processing page 60 of 221...
# Page 60 saved to output_csv_files\page_60.csv
# Processing page 61 of 221...
# Page 61 saved to output_csv_files\page_61.csv
# Processing page 62 of 221...
# Page 62 saved to output_csv_files\page_62.csv
# Processing page 63 of 221...
# Page 63 saved to output_csv_files\page_63.csv
# Processing page 64 of 221...
# Page 64 saved to output_csv_files\page_64.csv
# Processing page 65 of 221...
# Page 65 saved to output_csv_files\page_65.csv
# Processing page 66 of 221...
# Page 66 saved to output_csv_files\page_66.csv
# Processing page 67 of 221...
# Page 67 saved to output_csv_files\page_67.csv
# Processing page 68 of 221...
# Page 68 saved to output_csv_files\page_68.csv
# Processing page 69 of 221...
# Page 69 saved to output_csv_files\page_69.csv
# Processing page 70 of 221...
# Page 70 saved to output_csv_files\page_70.csv
# Processing page 71 of 221...
# Page 71 saved to output_csv_files\page_71.csv
# Processing page 72 of 221...
# Page 72 saved to output_csv_files\page_72.csv
# Processing page 73 of 221...
# Page 73 saved to output_csv_files\page_73.csv
# Processing page 74 of 221...
# Page 74 saved to output_csv_files\page_74.csv
# Processing page 75 of 221...
# Page 75 saved to output_csv_files\page_75.csv
# Processing page 76 of 221...
# Page 76 saved to output_csv_files\page_76.csv
# Processing page 77 of 221...
# Page 77 saved to output_csv_files\page_77.csv
# Processing page 78 of 221...
# Page 78 saved to output_csv_files\page_78.csv
# Processing page 79 of 221...
# Page 79 saved to output_csv_files\page_79.csv
# Processing page 80 of 221...
# Page 80 saved to output_csv_files\page_80.csv
# Processing page 81 of 221...
# Page 81 saved to output_csv_files\page_81.csv
# Processing page 82 of 221...
# Page 82 saved to output_csv_files\page_82.csv
# Processing page 83 of 221...
# Page 83 saved to output_csv_files\page_83.csv
# Processing page 84 of 221...
# Page 84 saved to output_csv_files\page_84.csv
# Processing page 85 of 221...
# Page 85 saved to output_csv_files\page_85.csv
# Processing page 86 of 221...
# Page 86 saved to output_csv_files\page_86.csv
# Processing page 87 of 221...
# Page 87 saved to output_csv_files\page_87.csv
# Processing page 88 of 221...
# Page 88 saved to output_csv_files\page_88.csv
# Processing page 89 of 221...
# Page 89 saved to output_csv_files\page_89.csv
# Processing page 90 of 221...
# Page 90 saved to output_csv_files\page_90.csv
# Processing page 91 of 221...
# Page 91 saved to output_csv_files\page_91.csv
# Processing page 92 of 221...
# Page 92 saved to output_csv_files\page_92.csv
# Processing page 93 of 221...
# Page 93 saved to output_csv_files\page_93.csv
# Processing page 94 of 221...
# Page 94 saved to output_csv_files\page_94.csv
# Processing page 95 of 221...
# Page 95 saved to output_csv_files\page_95.csv
# Processing page 96 of 221...
# Page 96 saved to output_csv_files\page_96.csv
# Processing page 97 of 221...
# Page 97 saved to output_csv_files\page_97.csv
# Processing page 98 of 221...
# Page 98 saved to output_csv_files\page_98.csv
# Processing page 99 of 221...
# Page 99 saved to output_csv_files\page_99.csv
# Processing page 100 of 221...
# Page 100 saved to output_csv_files\page_100.csv
# Processing page 101 of 221...
# Page 101 saved to output_csv_files\page_101.csv
# Processing page 102 of 221...
# Page 102 saved to output_csv_files\page_102.csv
# Processing page 103 of 221...
# Page 103 saved to output_csv_files\page_103.csv
# Processing page 104 of 221...
# Page 104 saved to output_csv_files\page_104.csv
# Processing page 105 of 221...
# Page 105 saved to output_csv_files\page_105.csv
# Processing page 106 of 221...
# Page 106 saved to output_csv_files\page_106.csv
# Processing page 107 of 221...
# Page 107 saved to output_csv_files\page_107.csv
# Processing page 108 of 221...
# Page 108 saved to output_csv_files\page_108.csv
# Processing page 109 of 221...
# Page 109 saved to output_csv_files\page_109.csv
# Processing page 110 of 221...
# Page 110 saved to output_csv_files\page_110.csv
# Processing page 111 of 221...
# Page 111 saved to output_csv_files\page_111.csv
# Processing page 112 of 221...
# Page 112 saved to output_csv_files\page_112.csv
# Processing page 113 of 221...
# Page 113 saved to output_csv_files\page_113.csv
# Processing page 114 of 221...
# Page 114 saved to output_csv_files\page_114.csv
# Processing page 115 of 221...
# Page 115 saved to output_csv_files\page_115.csv
# Processing page 116 of 221...
# Page 116 saved to output_csv_files\page_116.csv
# Processing page 117 of 221...
# Page 117 saved to output_csv_files\page_117.csv
# Processing page 118 of 221...
# Page 118 saved to output_csv_files\page_118.csv
# Processing page 119 of 221...
# Page 119 saved to output_csv_files\page_119.csv
# Processing page 120 of 221...
# Page 120 saved to output_csv_files\page_120.csv
# Processing page 121 of 221...
# Page 121 saved to output_csv_files\page_121.csv
# Processing page 122 of 221...
# Page 122 saved to output_csv_files\page_122.csv
# Processing page 123 of 221...
# Page 123 saved to output_csv_files\page_123.csv
# Processing page 124 of 221...
# Page 124 saved to output_csv_files\page_124.csv
# Processing page 125 of 221...
# Page 125 saved to output_csv_files\page_125.csv
# Processing page 126 of 221...
# Page 126 saved to output_csv_files\page_126.csv
# Processing page 127 of 221...
# Page 127 saved to output_csv_files\page_127.csv
# Processing page 128 of 221...
# Page 128 saved to output_csv_files\page_128.csv
# Processing page 129 of 221...
# Page 129 saved to output_csv_files\page_129.csv
# Processing page 130 of 221...
# Page 130 saved to output_csv_files\page_130.csv
# Processing page 131 of 221...
# Page 131 saved to output_csv_files\page_131.csv
# Processing page 132 of 221...
# Page 132 saved to output_csv_files\page_132.csv
# Processing page 133 of 221...
# Page 133 saved to output_csv_files\page_133.csv
# Processing page 134 of 221...
# Page 134 saved to output_csv_files\page_134.csv
# Processing page 135 of 221...
# Page 135 saved to output_csv_files\page_135.csv
# Processing page 136 of 221...
# Page 136 saved to output_csv_files\page_136.csv
# Processing page 137 of 221...
# Page 137 saved to output_csv_files\page_137.csv
# Processing page 138 of 221...
# Page 138 saved to output_csv_files\page_138.csv
# Processing page 139 of 221...
# Page 139 saved to output_csv_files\page_139.csv
# Processing page 140 of 221...
# Page 140 saved to output_csv_files\page_140.csv
# Processing page 141 of 221...
# Page 141 saved to output_csv_files\page_141.csv
# Processing page 142 of 221...
# Page 142 saved to output_csv_files\page_142.csv
# Processing page 143 of 221...
# Page 143 saved to output_csv_files\page_143.csv
# Processing page 144 of 221...
# Page 144 saved to output_csv_files\page_144.csv
# Processing page 145 of 221...
# Page 145 saved to output_csv_files\page_145.csv
# Processing page 146 of 221...
# Page 146 saved to output_csv_files\page_146.csv
# Processing page 147 of 221...
# Page 147 saved to output_csv_files\page_147.csv
# Processing page 148 of 221...
# Page 148 saved to output_csv_files\page_148.csv
# Processing page 149 of 221...
# Page 149 saved to output_csv_files\page_149.csv
# Processing page 150 of 221...
# Page 150 saved to output_csv_files\page_150.csv
# Processing page 151 of 221...
# Page 151 saved to output_csv_files\page_151.csv
# Processing page 152 of 221...
# Page 152 saved to output_csv_files\page_152.csv
# Processing page 153 of 221...
# Page 153 saved to output_csv_files\page_153.csv
# Processing page 154 of 221...
# Page 154 saved to output_csv_files\page_154.csv
# Processing page 155 of 221...
# Page 155 saved to output_csv_files\page_155.csv
# Processing page 156 of 221...
# Page 156 saved to output_csv_files\page_156.csv
# Processing page 157 of 221...
# Page 157 saved to output_csv_files\page_157.csv
# Processing page 158 of 221...
# Page 158 saved to output_csv_files\page_158.csv
# Processing page 159 of 221...
# Page 159 saved to output_csv_files\page_159.csv
# Processing page 160 of 221...
# Page 160 saved to output_csv_files\page_160.csv
# Processing page 161 of 221...
# Page 161 saved to output_csv_files\page_161.csv
# Processing page 162 of 221...
# Page 162 saved to output_csv_files\page_162.csv
# Processing page 163 of 221...
# Page 163 saved to output_csv_files\page_163.csv
# Processing page 164 of 221...
# Page 164 saved to output_csv_files\page_164.csv
# Processing page 165 of 221...
# Page 165 saved to output_csv_files\page_165.csv
# Processing page 166 of 221...
# Page 166 saved to output_csv_files\page_166.csv
# Processing page 167 of 221...
# Page 167 saved to output_csv_files\page_167.csv
# Processing page 168 of 221...
# Page 168 saved to output_csv_files\page_168.csv
# Processing page 169 of 221...
# Page 169 saved to output_csv_files\page_169.csv
# Processing page 170 of 221...
# Page 170 saved to output_csv_files\page_170.csv
# Processing page 171 of 221...
# Page 171 saved to output_csv_files\page_171.csv
# Processing page 172 of 221...
# Page 172 saved to output_csv_files\page_172.csv
# Processing page 173 of 221...
# Page 173 saved to output_csv_files\page_173.csv
# Processing page 174 of 221...
# Page 174 saved to output_csv_files\page_174.csv
# Processing page 175 of 221...
# Page 175 saved to output_csv_files\page_175.csv
# Processing page 176 of 221...
# Page 176 saved to output_csv_files\page_176.csv
# Processing page 177 of 221...
# Page 177 saved to output_csv_files\page_177.csv
# Processing page 178 of 221...
# Page 178 saved to output_csv_files\page_178.csv
# Processing page 179 of 221...
# Page 179 saved to output_csv_files\page_179.csv
# Processing page 180 of 221...
# Page 180 saved to output_csv_files\page_180.csv
# Processing page 181 of 221...
# Page 181 saved to output_csv_files\page_181.csv
# Processing page 182 of 221...
# Page 182 saved to output_csv_files\page_182.csv
# Processing page 183 of 221...
# Page 183 saved to output_csv_files\page_183.csv
# Processing page 184 of 221...
# Page 184 saved to output_csv_files\page_184.csv
# Processing page 185 of 221...
# Page 185 saved to output_csv_files\page_185.csv
# Processing page 186 of 221...
# Page 186 saved to output_csv_files\page_186.csv
# Processing page 187 of 221...
# Page 187 saved to output_csv_files\page_187.csv
# Processing page 188 of 221...
# Page 188 saved to output_csv_files\page_188.csv
# Processing page 189 of 221...
# Page 189 saved to output_csv_files\page_189.csv
# Processing page 190 of 221...
# Page 190 saved to output_csv_files\page_190.csv
# Processing page 191 of 221...
# Page 191 saved to output_csv_files\page_191.csv
# Processing page 192 of 221...
# Page 192 saved to output_csv_files\page_192.csv
# Processing page 193 of 221...
# Page 193 saved to output_csv_files\page_193.csv
# Processing page 194 of 221...
# Page 194 saved to output_csv_files\page_194.csv
# Processing page 195 of 221...
# Page 195 saved to output_csv_files\page_195.csv
# Processing page 196 of 221...
# Page 196 saved to output_csv_files\page_196.csv
# Processing page 197 of 221...
# Page 197 saved to output_csv_files\page_197.csv
# Processing page 198 of 221...
# Page 198 saved to output_csv_files\page_198.csv
# Processing page 199 of 221...
# Page 199 saved to output_csv_files\page_199.csv
# Processing page 200 of 221...
# Page 200 saved to output_csv_files\page_200.csv
# Processing page 201 of 221...
# Page 201 saved to output_csv_files\page_201.csv
# Processing page 202 of 221...
# Page 202 saved to output_csv_files\page_202.csv
# Processing page 203 of 221...
# Page 203 saved to output_csv_files\page_203.csv
# Processing page 204 of 221...
# Page 204 saved to output_csv_files\page_204.csv
# Processing page 205 of 221...
# Page 205 saved to output_csv_files\page_205.csv
# Processing page 206 of 221...
# Page 206 saved to output_csv_files\page_206.csv
# Processing page 207 of 221...
# Page 207 saved to output_csv_files\page_207.csv
# Processing page 208 of 221...
# Page 208 saved to output_csv_files\page_208.csv
# Processing page 209 of 221...
# Page 209 saved to output_csv_files\page_209.csv
# Processing page 210 of 221...
# Page 210 saved to output_csv_files\page_210.csv
# Processing page 211 of 221...
# Page 211 saved to output_csv_files\page_211.csv
# Processing page 212 of 221...
# Page 212 saved to output_csv_files\page_212.csv
# Processing page 213 of 221...
# Page 213 saved to output_csv_files\page_213.csv
# Processing page 214 of 221...
# Page 214 saved to output_csv_files\page_214.csv
# Processing page 215 of 221...
# Page 215 saved to output_csv_files\page_215.csv
# Processing page 216 of 221...
# Page 216 saved to output_csv_files\page_216.csv
# Processing page 217 of 221...
# Page 217 saved to output_csv_files\page_217.csv
# Processing page 218 of 221...
# Page 218 saved to output_csv_files\page_218.csv
# Processing page 219 of 221...
# Page 219 saved to output_csv_files\page_219.csv
# Processing page 220 of 221...
# Page 220 saved to output_csv_files\page_220.csv
# Processing page 221 of 221...
# Page 221 saved to output_csv_files\page_221.csv

# %%
import os
import pandas as pd

# Set the path to the folder containing the CSV files
input_folder = 'output_csv_files'
output_folder = 'sorted_csv_files'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Loop through all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        # Create the full path to the input file
        input_file_path = os.path.join(input_folder, filename)
        
        # Read the CSV file
        df = pd.read_csv(input_file_path)
        
        # Sort the DataFrame (adjust the column name as needed)
        sorted_df = df.sort_values(by=df.columns[0])  # Sorting by the first column
        
        # Create the full path for the output file
        output_file_path = os.path.join(output_folder, filename)
        
        # Save the sorted DataFrame to a new CSV file
        sorted_df.to_csv(output_file_path, index=False)

print("Sorting completed. Sorted files are saved in:", output_folder)
# Out:
# Sorting completed. Sorted files are saved in: sorted_csv_files

# %%
import os
import pytesseract
import fitz  # PyMuPDF
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=300)  # Increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image, lang="san"):
    """
    Enhance and preprocess the image for better OCR accuracy.
    Use specific preprocessing depending on language.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2)

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter())

    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image, lang="san")

    # OCR for Sanskrit and English
    sanskrit_text = pytesseract.image_to_string(image, lang="san+eng")

    # Extract Sanskrit word, transliteration, and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)

        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses
            meaning = match.group(3)  # Text after "="

            # Filter out any non-English characters from transliteration and meaning
            transliteration = re.sub(r"[^a-zA-Z\s]", "", transliteration)
            meaning = re.sub(r"[^a-zA-Z\s]", "", meaning)
            
            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration.strip(),
                "Meaning": meaning.strip(),
                "Page Number": page_number
            })
    
    return sanskrit_data

def save_all_pages_to_single_csv(pdf_path, output_csv):
    """
    Extract Sanskrit words, transliterations, and meanings from all pages in the PDF and save them all to a single CSV.
    """
    # List to accumulate all data from each page
    all_data = []
    
    # Open the PDF
    with fitz.open(pdf_path) as doc:
        total_pages = doc.page_count
        
        # Process each page
        for page_num in range(total_pages):
            print(f"Processing page {page_num + 1} of {total_pages}...")
            
            # Convert current PDF page to image
            image = convert_pdf_page_to_image(pdf_path, page_num)
            
            # Extract Sanskrit data and append to all_data
            sanskrit_data = extract_sanskrit_data(image, page_num + 1)
            all_data.extend(sanskrit_data)
    
    # Create DataFrame with all data and save to a single CSV
    df = pd.DataFrame(all_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
    df.to_csv(output_csv, index=False)
    print(f"All pages saved to {output_csv}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
output_csv = "dataset_final.csv"  # The final CSV file to save all data
save_all_pages_to_single_csv(pdf_path, output_csv)
# Out:
# Processing page 1 of 221...
# Processing page 2 of 221...
# Processing page 3 of 221...
# Processing page 4 of 221...
# Processing page 5 of 221...
# Processing page 6 of 221...
# Processing page 7 of 221...
# Processing page 8 of 221...
# Processing page 9 of 221...
# Processing page 10 of 221...
# Processing page 11 of 221...
# Processing page 12 of 221...
# Processing page 13 of 221...
# Processing page 14 of 221...
# Processing page 15 of 221...
# Processing page 16 of 221...
# Processing page 17 of 221...
# Processing page 18 of 221...
# Processing page 19 of 221...
# Processing page 20 of 221...
# Processing page 21 of 221...
# Processing page 22 of 221...
# Processing page 23 of 221...
# Processing page 24 of 221...
# Processing page 25 of 221...
# Processing page 26 of 221...
# Processing page 27 of 221...
# Processing page 28 of 221...
# Processing page 29 of 221...
# Processing page 30 of 221...
# Processing page 31 of 221...
# Processing page 32 of 221...
# Processing page 33 of 221...
# Processing page 34 of 221...
# Processing page 35 of 221...
# Processing page 36 of 221...
# Processing page 37 of 221...
# Processing page 38 of 221...
# Processing page 39 of 221...
# Processing page 40 of 221...
# Processing page 41 of 221...
# Processing page 42 of 221...
# Processing page 43 of 221...
# Processing page 44 of 221...
# Processing page 45 of 221...
# Processing page 46 of 221...
# Processing page 47 of 221...
# Processing page 48 of 221...
# Processing page 49 of 221...
# Processing page 50 of 221...
# Processing page 51 of 221...
# Processing page 52 of 221...
# Processing page 53 of 221...
# Processing page 54 of 221...
# Processing page 55 of 221...
# Processing page 56 of 221...
# Processing page 57 of 221...
# Processing page 58 of 221...
# Processing page 59 of 221...
# Processing page 60 of 221...
# Processing page 61 of 221...
# Processing page 62 of 221...
# Processing page 63 of 221...
# Processing page 64 of 221...
# Processing page 65 of 221...
# Processing page 66 of 221...
# Processing page 67 of 221...
# Processing page 68 of 221...
# Processing page 69 of 221...
# Processing page 70 of 221...
# Processing page 71 of 221...
# Processing page 72 of 221...
# Processing page 73 of 221...
# Processing page 74 of 221...
# Processing page 75 of 221...
# Processing page 76 of 221...
# Processing page 77 of 221...
# Processing page 78 of 221...
# Processing page 79 of 221...
# Processing page 80 of 221...
# Processing page 81 of 221...
# Processing page 82 of 221...
# Processing page 83 of 221...
# Processing page 84 of 221...
# Processing page 85 of 221...
# Processing page 86 of 221...
# Processing page 87 of 221...
# Processing page 88 of 221...
# Processing page 89 of 221...
# Processing page 90 of 221...
# Processing page 91 of 221...
# Processing page 92 of 221...
# Processing page 93 of 221...
# Processing page 94 of 221...
# Processing page 95 of 221...
# Processing page 96 of 221...
# Processing page 97 of 221...
# Processing page 98 of 221...
# Processing page 99 of 221...
# Processing page 100 of 221...
# Processing page 101 of 221...
# Processing page 102 of 221...
# Processing page 103 of 221...
# Processing page 104 of 221...
# Processing page 105 of 221...
# Processing page 106 of 221...
# Processing page 107 of 221...
# Processing page 108 of 221...
# Processing page 109 of 221...
# Processing page 110 of 221...
# Processing page 111 of 221...
# Processing page 112 of 221...
# Processing page 113 of 221...
# Processing page 114 of 221...
# Processing page 115 of 221...
# Processing page 116 of 221...
# Processing page 117 of 221...
# Processing page 118 of 221...
# Processing page 119 of 221...
# Processing page 120 of 221...
# Processing page 121 of 221...
# Processing page 122 of 221...
# Processing page 123 of 221...
# Processing page 124 of 221...
# Processing page 125 of 221...
# Processing page 126 of 221...
# Processing page 127 of 221...
# Processing page 128 of 221...
# Processing page 129 of 221...
# Processing page 130 of 221...
# Processing page 131 of 221...
# Processing page 132 of 221...
# Processing page 133 of 221...
# Processing page 134 of 221...
# Processing page 135 of 221...
# Processing page 136 of 221...
# Processing page 137 of 221...
# Processing page 138 of 221...
# Processing page 139 of 221...
# Processing page 140 of 221...
# Processing page 141 of 221...
# Processing page 142 of 221...
# Processing page 143 of 221...
# Processing page 144 of 221...
# Processing page 145 of 221...
# Processing page 146 of 221...
# Processing page 147 of 221...
# Processing page 148 of 221...
# Processing page 149 of 221...
# Processing page 150 of 221...
# Processing page 151 of 221...
# Processing page 152 of 221...
# Processing page 153 of 221...
# Processing page 154 of 221...
# Processing page 155 of 221...
# Processing page 156 of 221...
# Processing page 157 of 221...
# Processing page 158 of 221...
# Processing page 159 of 221...
# Processing page 160 of 221...
# Processing page 161 of 221...
# Processing page 162 of 221...
# Processing page 163 of 221...
# Processing page 164 of 221...
# Processing page 165 of 221...
# Processing page 166 of 221...
# Processing page 167 of 221...
# Processing page 168 of 221...
# Processing page 169 of 221...
# Processing page 170 of 221...
# Processing page 171 of 221...
# Processing page 172 of 221...
# Processing page 173 of 221...
# Processing page 174 of 221...
# Processing page 175 of 221...
# Processing page 176 of 221...
# Processing page 177 of 221...
# Processing page 178 of 221...
# Processing page 179 of 221...
# Processing page 180 of 221...
# Processing page 181 of 221...
# Processing page 182 of 221...
# Processing page 183 of 221...
# Processing page 184 of 221...
# Processing page 185 of 221...
# Processing page 186 of 221...
# Processing page 187 of 221...
# Processing page 188 of 221...
# Processing page 189 of 221...
# Processing page 190 of 221...
# Processing page 191 of 221...
# Processing page 192 of 221...
# Processing page 193 of 221...
# Processing page 194 of 221...
# Processing page 195 of 221...
# Processing page 196 of 221...
# Processing page 197 of 221...
# Processing page 198 of 221...
# Processing page 199 of 221...
# Processing page 200 of 221...
# Processing page 201 of 221...
# Processing page 202 of 221...
# Processing page 203 of 221...
# Processing page 204 of 221...
# Processing page 205 of 221...
# Processing page 206 of 221...
# Processing page 207 of 221...
# Processing page 208 of 221...
# Processing page 209 of 221...
# Processing page 210 of 221...
# Processing page 211 of 221...
# Processing page 212 of 221...
# Processing page 213 of 221...
# Processing page 214 of 221...
# Processing page 215 of 221...
# Processing page 216 of 221...
# Processing page 217 of 221...
# Processing page 218 of 221...
# Processing page 219 of 221...
# Processing page 220 of 221...
# Processing page 221 of 221...
# All pages saved to dataset_final.csv

# %%
import os
import pytesseract
import fitz  # PyMuPDF
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=400)  # Further increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image, lang="san"):
    """
    Enhance and preprocess the image for better OCR accuracy.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2.5)  # Increase contrast enhancement for clarity

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter(size=3))

    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image, lang="san")

    # OCR with specific configuration to handle word segmentation
    custom_config = r'--psm 6 -c tessedit_char_blacklist=|!@#'  # Further segmentation tuning
    sanskrit_text = pytesseract.image_to_string(image, lang="san+eng", config=custom_config)

    # Enhanced regex to capture punctuation in transliteration and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning with improved punctuation support
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)

        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses, allowing punctuation
            meaning = match.group(3)  # Text after "=", allowing punctuation

            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration.strip(),
                "Meaning": meaning.strip(),
                "Page Number": page_number
            })
    
    return sanskrit_data

def save_single_page_to_csv(pdf_path, page_num, output_csv):
    """
    Extract Sanskrit words, transliterations, and meanings from a single page in the PDF and save to CSV for testing.
    """
    # Convert PDF page to image
    image = convert_pdf_page_to_image(pdf_path, page_num)
    
    # Extract Sanskrit data from the page
    sanskrit_data = extract_sanskrit_data(image, page_num + 1)
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(sanskrit_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
    df.to_csv(output_csv, index=False)
    print(f"Page {page_num + 1} saved to {output_csv}")

# Test with a single page
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
output_csv = "test_page_output.csv"  # The CSV file for testing a single page
test_page_num = 3  # Adjust this to the page number you want to test (0 = first page)
save_single_page_to_csv(pdf_path, test_page_num, output_csv)
# Out:
# Page 4 saved to test_page_output.csv

# %%
import os
import pytesseract
import fitz  # PyMuPDF
from PIL import Image, ImageEnhance, ImageFilter
import pandas as pd
import re
import io

# Set Tesseract executable path if needed (adjust path as per your installation)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def convert_pdf_page_to_image(pdf_path, page_num):
    """
    Convert a specific page of the PDF into an image.
    """
    with fitz.open(pdf_path) as doc:
        page = doc.load_page(page_num)
        pix = page.get_pixmap(dpi=400)  # Further increase DPI for better resolution
        img = Image.open(io.BytesIO(pix.tobytes("png")))
    return img

def preprocess_image(image, lang="san"):
    """
    Enhance and preprocess the image for better OCR accuracy.
    """
    # Convert to grayscale
    image = image.convert("L")

    # Enhance contrast
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(2.5)  # Increase contrast enhancement for clarity

    # Resize image to improve OCR detection of smaller characters
    image = image.resize((image.width * 2, image.height * 2), Image.LANCZOS)

    # Apply a slight blur to reduce noise
    image = image.filter(ImageFilter.MedianFilter(size=3))

    return image

def extract_sanskrit_data(image, page_number):
    """
    Perform OCR on the image and extract Sanskrit word, transliteration, and meaning.
    """
    # Preprocess the image for better OCR accuracy
    image = preprocess_image(image, lang="san")

    # OCR with specific configuration to handle word segmentation
    custom_config = r'--psm 6 -c tessedit_char_blacklist=|!@#'  # Further segmentation tuning
    sanskrit_text = pytesseract.image_to_string(image, lang="san+eng", config=custom_config)

    # Enhanced regex to capture punctuation in transliteration and meaning
    sanskrit_data = []
    for line in sanskrit_text.splitlines():
        # Match Sanskrit word, transliteration, and meaning with improved punctuation support
        match = re.match(r"^(\S+)\s*\(([^)]+)\)\s*=\s*(.+)", line)

        if match:
            sanskrit_word = match.group(1)  # Sanskrit word before "("
            transliteration = match.group(2)  # Text inside parentheses, allowing punctuation
            meaning = match.group(3)  # Text after "=", allowing punctuation

            sanskrit_data.append({
                "Sanskrit Word": sanskrit_word,
                "Transliteration": transliteration.strip(),
                "Meaning": meaning.strip(),
                "Page Number": page_number
            })
    
    return sanskrit_data

def save_all_pages_to_single_csv(pdf_path, output_csv):
    """
    Extract Sanskrit words, transliterations, and meanings from all pages in the PDF and save to a single CSV.
    """
    all_data = []  # Collect data from all pages

    # Open the PDF
    with fitz.open(pdf_path) as doc:
        total_pages = doc.page_count
        
        # Process each page
        for page_num in range(total_pages):
            print(f"Processing page {page_num + 1} of {total_pages}...")
            
            # Convert current PDF page to image
            image = convert_pdf_page_to_image(pdf_path, page_num)
            
            # Extract Sanskrit data
            sanskrit_data = extract_sanskrit_data(image, page_num + 1)
            
            # Append data to the main list
            all_data.extend(sanskrit_data)

    # Create DataFrame from all collected data and save to a single CSV
    df = pd.DataFrame(all_data, columns=["Sanskrit Word", "Transliteration", "Meaning", "Page Number"])
    df.to_csv(output_csv, index=False)
    print(f"All pages saved to {output_csv}")

# Usage example
pdf_path = "dictallcheck.pdf"  # Replace with the path to your encoded PDF
output_csv = "dataset_final1.csv"  # The final CSV file containing all pages' data
save_all_pages_to_single_csv(pdf_path, output_csv)
# Out:
# Processing page 1 of 221...
# Processing page 2 of 221...
# Processing page 3 of 221...
# Processing page 4 of 221...
# Processing page 5 of 221...
# Processing page 6 of 221...
# Processing page 7 of 221...
# Processing page 8 of 221...
# Processing page 9 of 221...
# Processing page 10 of 221...
# Processing page 11 of 221...
# Processing page 12 of 221...
# Processing page 13 of 221...
# Processing page 14 of 221...
# Processing page 15 of 221...
# Processing page 16 of 221...
# Processing page 17 of 221...
# Processing page 18 of 221...
# Processing page 19 of 221...
# Processing page 20 of 221...
# Processing page 21 of 221...
# Processing page 22 of 221...
# Processing page 23 of 221...
# Processing page 24 of 221...
# Processing page 25 of 221...
# Processing page 26 of 221...
# Processing page 27 of 221...
# Processing page 28 of 221...
# Processing page 29 of 221...
# Processing page 30 of 221...
# Processing page 31 of 221...
# Processing page 32 of 221...
# Processing page 33 of 221...
# Processing page 34 of 221...
# Processing page 35 of 221...
# Processing page 36 of 221...
# Processing page 37 of 221...
# Processing page 38 of 221...
# Processing page 39 of 221...
# Processing page 40 of 221...
# Processing page 41 of 221...
# Processing page 42 of 221...
# Processing page 43 of 221...
# Processing page 44 of 221...
# Processing page 45 of 221...
# Processing page 46 of 221...
# Processing page 47 of 221...
# Processing page 48 of 221...
# Processing page 49 of 221...
# Processing page 50 of 221...
# Processing page 51 of 221...
# Processing page 52 of 221...
# Processing page 53 of 221...
# Processing page 54 of 221...
# Processing page 55 of 221...
# Processing page 56 of 221...
# Processing page 57 of 221...
# Processing page 58 of 221...
# Processing page 59 of 221...
# Processing page 60 of 221...
# Processing page 61 of 221...
# Processing page 62 of 221...
# Processing page 63 of 221...
# Processing page 64 of 221...
# Processing page 65 of 221...
# Processing page 66 of 221...
# Processing page 67 of 221...
# Processing page 68 of 221...
# Processing page 69 of 221...
# Processing page 70 of 221...
# Processing page 71 of 221...
# Processing page 72 of 221...
# Processing page 73 of 221...
# Processing page 74 of 221...
# Processing page 75 of 221...
# Processing page 76 of 221...
# Processing page 77 of 221...
# Processing page 78 of 221...
# Processing page 79 of 221...
# Processing page 80 of 221...
# Processing page 81 of 221...
# Processing page 82 of 221...
# Processing page 83 of 221...
# Processing page 84 of 221...
# Processing page 85 of 221...
# Processing page 86 of 221...
# Processing page 87 of 221...
# Processing page 88 of 221...
# Processing page 89 of 221...
# Processing page 90 of 221...
# Processing page 91 of 221...
# Processing page 92 of 221...
# Processing page 93 of 221...
# Processing page 94 of 221...
# Processing page 95 of 221...
# Processing page 96 of 221...
# Processing page 97 of 221...
# Processing page 98 of 221...
# Processing page 99 of 221...
# Processing page 100 of 221...
# Processing page 101 of 221...
# Processing page 102 of 221...
# Processing page 103 of 221...
# Processing page 104 of 221...
# Processing page 105 of 221...
# Processing page 106 of 221...
# Processing page 107 of 221...
# Processing page 108 of 221...
# Processing page 109 of 221...
# Processing page 110 of 221...
# Processing page 111 of 221...
# Processing page 112 of 221...
# Processing page 113 of 221...
# Processing page 114 of 221...
# Processing page 115 of 221...
# Processing page 116 of 221...
# Processing page 117 of 221...
# Processing page 118 of 221...
# Processing page 119 of 221...
# Processing page 120 of 221...
# Processing page 121 of 221...
# Processing page 122 of 221...
# Processing page 123 of 221...
# Processing page 124 of 221...
# Processing page 125 of 221...
# Processing page 126 of 221...
# Processing page 127 of 221...
# Processing page 128 of 221...
# Processing page 129 of 221...
# Processing page 130 of 221...
# Processing page 131 of 221...
# Processing page 132 of 221...
# Processing page 133 of 221...
# Processing page 134 of 221...
# Processing page 135 of 221...
# Processing page 136 of 221...
# Processing page 137 of 221...
# Processing page 138 of 221...
# Processing page 139 of 221...
# Processing page 140 of 221...
# Processing page 141 of 221...
# Processing page 142 of 221...
# Processing page 143 of 221...
# Processing page 144 of 221...
# Processing page 145 of 221...
# Processing page 146 of 221...
# Processing page 147 of 221...
# Processing page 148 of 221...
# Processing page 149 of 221...
# Processing page 150 of 221...
# Processing page 151 of 221...
# Processing page 152 of 221...
# Processing page 153 of 221...
# Processing page 154 of 221...
# Processing page 155 of 221...
# Processing page 156 of 221...
# Processing page 157 of 221...
# Processing page 158 of 221...
# Processing page 159 of 221...
# Processing page 160 of 221...
# Processing page 161 of 221...
# Processing page 162 of 221...
# Processing page 163 of 221...
# Processing page 164 of 221...
# Processing page 165 of 221...
# Processing page 166 of 221...
# Processing page 167 of 221...
# Processing page 168 of 221...
# Processing page 169 of 221...
# Processing page 170 of 221...
# Processing page 171 of 221...
# Processing page 172 of 221...
# Processing page 173 of 221...
# Processing page 174 of 221...
# Processing page 175 of 221...
# Processing page 176 of 221...
# Processing page 177 of 221...
# Processing page 178 of 221...
# Processing page 179 of 221...
# Processing page 180 of 221...
# Processing page 181 of 221...
# Processing page 182 of 221...
# Processing page 183 of 221...
# Processing page 184 of 221...
# Processing page 185 of 221...
# Processing page 186 of 221...
# Processing page 187 of 221...
# Processing page 188 of 221...
# Processing page 189 of 221...
# Processing page 190 of 221...
# Processing page 191 of 221...
# Processing page 192 of 221...
# Processing page 193 of 221...
# Processing page 194 of 221...
# Processing page 195 of 221...
# Processing page 196 of 221...
# Processing page 197 of 221...
# Processing page 198 of 221...
# Processing page 199 of 221...
# Processing page 200 of 221...
# Processing page 201 of 221...
# Processing page 202 of 221...
# Processing page 203 of 221...
# Processing page 204 of 221...
# Processing page 205 of 221...
# Processing page 206 of 221...
# Processing page 207 of 221...
# Processing page 208 of 221...
# Processing page 209 of 221...
# Processing page 210 of 221...
# Processing page 211 of 221...
# Processing page 212 of 221...
# Processing page 213 of 221...
# Processing page 214 of 221...
# Processing page 215 of 221...
# Processing page 216 of 221...
# Processing page 217 of 221...
# Processing page 218 of 221...
# Processing page 219 of 221...
# Processing page 220 of 221...
# Processing page 221 of 221...
# All pages saved to dataset_final1.csv

# %%
print(data.columns)
# Out:
# Index(['Sanskrit Word', 'Transliteration', 'Meaning', 'Page Number'], dtype='object')

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Load the main dataset CSV
data = pd.read_csv('dataset_final1.csv')

# Trim whitespace from column names (in case of extra spaces)
data.columns = data.columns.str.strip()

# Initialize an empty list to store anomalies
anomalies = []

# Define the path to the folder containing page-wise Sanskrit data
pages_folder = 'pages'

# Loop through each row in the main dataset
for index, row in data.iterrows():
    page_number = row['Page Number']
    main_sanskrit_word = row['Sanskrit Word']

    # Construct the file path for the current page number
    page_file_path = os.path.join(pages_folder, f'page_{page_number}.csv')
    
    # Check if the page file exists
    if os.path.exists(page_file_path):
        # Load the page-specific data
        page_data = pd.read_csv(page_file_path)
        
        # Extract the Sanskrit words column from the page file (assuming it's named 'Sanskrit Word')
        page_sanskrit_words = page_data['Sanskrit Word'].tolist()
        
        # Check if the main Sanskrit word is in the page's word list
        if main_sanskrit_word not in page_sanskrit_words:
            # Try fuzzy matching to find the closest match
            closest_match, match_score = process.extractOne(main_sanskrit_word, page_sanskrit_words, scorer=fuzz.ratio)

            # If the match score is high (e.g., > 85), assume it's a close enough match and correct it
            if match_score > 85:
                print(f"Correcting '{main_sanskrit_word}' to '{closest_match}' on page {page_number}")
                data.at[index, 'Sanskrit Word'] = closest_match
            else:
                # If no close match is found, log the anomaly
                anomalies.append({
                    'Page Number': page_number,
                    'Sanskrit Word': main_sanskrit_word,
                    'issue': 'No close match found on page'
                })
    else:
        # Log an anomaly if the page file doesn't exist
        anomalies.append({
            'Page Number': page_number,
            'Sanskrit Word': main_sanskrit_word,
            'issue': 'Page file not found'
        })

# Convert the anomalies to a DataFrame and append it to the original data
anomalies_df = pd.DataFrame(anomalies)
final_data = pd.concat([data, anomalies_df], ignore_index=True)

# Save the final DataFrame with corrections and anomalies to a new CSV
final_data.to_csv('dataset_corrected.csv', index=False)
print("Process completed. Check 'dataset_corrected.csv' for results.")
# Out:
# Process completed. Check 'dataset_corrected.csv' for results.

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

# Load the main dataset CSV
data = pd.read_csv('dataset_final1.csv')

# Trim whitespace from column names (in case of extra spaces)
data.columns = data.columns.str.strip()

# Initialize a list to store unmatched words to append at the end of the CSV
unmatched_words = []

# Define the path to the folder containing page-wise Sanskrit data
pages_folder = 'pages'

# Sanskrit character range pattern to identify Sanskrit text
sanskrit_pattern = re.compile(r'[\u0900-\u097F]+')

# Loop through each row in the main dataset
for index, row in data.iterrows():
    main_sanskrit_word = row['Sanskrit Word']
    
    # Check if 'Sanskrit Word' does not contain Sanskrit characters (indicating it's in English or another language)
    if pd.notna(main_sanskrit_word) and not sanskrit_pattern.search(main_sanskrit_word):
        page_number = row['Page Number']
        
        # Construct the file path for the current page number
        page_file_path = os.path.join(pages_folder, f'page_{page_number}.csv')
        
        # Check if the page file exists
        if os.path.exists(page_file_path):
            # Load the page-specific data
            page_data = pd.read_csv(page_file_path)
            
            # Extract the Sanskrit words column from the page file (assuming it's named 'Sanskrit Word')
            page_sanskrit_words = page_data['Sanskrit Word'].tolist()
            
            # Try fuzzy matching to find the closest match in the page's Sanskrit words list
            closest_match, match_score = process.extractOne(main_sanskrit_word, page_sanskrit_words, scorer=fuzz.ratio)

            # If the match score is high (e.g., > 85), assume it's a close enough match and correct it
            if match_score > 85:
                print(f"Correcting '{main_sanskrit_word}' to '{closest_match}' on page {page_number}")
                data.at[index, 'Sanskrit Word'] = closest_match
            else:
                # If no close match is found, keep the row as it is in unmatched_words
                unmatched_words.append(row)
        else:
            # If the page file does not exist, keep the row as it is in unmatched_words
            unmatched_words.append(row)

# Convert unmatched words to a DataFrame with the exact rows
unmatched_df = pd.DataFrame(unmatched_words)

# Concatenate the main data with unmatched words DataFrame, adding unmatched rows at the end
final_data = pd.concat([data, unmatched_df], ignore_index=True)

# Save the final DataFrame with corrections and unmatched words at the end to a new CSV
final_data.to_csv('dataset_corrected.csv', index=False)
print("Process completed. Check 'dataset_corrected.csv' for results.")
# Out:
# Process completed. Check 'dataset_corrected.csv' for results.

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

# Load the main dataset CSV
data = pd.read_csv('dataset_final1.csv')

# Trim whitespace from column names (in case of extra spaces)
data.columns = data.columns.str.strip()

# Initialize a list to store unmatched words to append at the end of the CSV
unmatched_words = []

# Define the path to the folder containing page-wise Sanskrit data
pages_folder = 'pages'

# Sanskrit character range pattern to identify Sanskrit text
sanskrit_pattern = re.compile(r'[\u0900-\u097F]+')

# Loop through each row in the main dataset
for index, row in data.iterrows():
    main_sanskrit_word = row['Sanskrit Word']
    
    # Check if 'Sanskrit Word' does not contain Sanskrit characters (indicating it's in English or another language)
    if pd.notna(main_sanskrit_word) and not sanskrit_pattern.search(main_sanskrit_word):
        page_number = row['Page Number']
        
        # Construct the file path for the current page number
        page_file_path = os.path.join(pages_folder, f'page_{page_number}.csv')
        
        # Check if the page file exists
        if os.path.exists(page_file_path):
            # Load the page-specific data
            page_data = pd.read_csv(page_file_path)
            
            # Extract the Sanskrit words column from the page file (assuming it's named 'Sanskrit Word')
            page_sanskrit_words = page_data['Sanskrit Word'].tolist()
            
            # Try fuzzy matching to find the closest match in the page's Sanskrit words list
            closest_match, match_score = process.extractOne(main_sanskrit_word, page_sanskrit_words, scorer=fuzz.ratio)

            # If the match score is high (e.g., > 85), assume it's a close enough match and correct it
            if match_score > 85:
                print(f"Correcting '{main_sanskrit_word}' to '{closest_match}' on page {page_number}")
                data.at[index, 'Sanskrit Word'] = closest_match
            else:
                # If no close match is found, move the row to unmatched_words and remove from original position
                unmatched_words.append(row)
                data = data.drop(index)
        else:
            # If the page file does not exist, move the row to unmatched_words and remove from original position
            unmatched_words.append(row)
            data = data.drop(index)

# Convert unmatched words to a DataFrame with the exact rows
unmatched_df = pd.DataFrame(unmatched_words)

# Concatenate the main data with unmatched words DataFrame, adding unmatched rows at the end
final_data = pd.concat([data, unmatched_df], ignore_index=True)

# Save the final DataFrame with corrections and unmatched words at the end to a new CSV
final_data.to_csv('dataset_corrected1.csv', index=False)
print("Process completed. Check 'dataset_corrected.csv' for results.")
# Out:
# Process completed. Check 'dataset_corrected.csv' for results.

# %%
import pandas as pd
import fitz  # PyMuPDF for PDF handling
import pytesseract
from PIL import Image  # Import Image from Pillow

# Configure pytesseract for OCR
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Update the path as needed

# Function to perform OCR on a specific page of a PDF
def extract_text_from_pdf(pdf_path, page_number):
    try:
        doc = fitz.open(pdf_path)
        if 1 <= page_number <= len(doc):
            page = doc[page_number - 1]  # Pages are 0-indexed
            pix = page.get_pixmap()
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)  # Use Pillow to convert Pixmap to Image
            text = pytesseract.image_to_string(img, lang='san')  # Sanskrit OCR
            return text
        else:
            return None
    except Exception as e:
        print(f"Error during OCR on page {page_number}: {e}")
        return None

# Load Excel file
excel_path = "notprocessedvalues.xlsx"
pdf_path = "dictallcheck.pdf"
output_excel_path = "corrected_sanskrit_words.xlsx"

df = pd.read_excel(excel_path)

# Iterate over each row in the DataFrame
for idx, row in df.iterrows():
    word = row['Sanskrit Word']
    page_number = int(row['Page Number'])

    # Extract text from the PDF page
    ocr_text = extract_text_from_pdf(pdf_path, page_number)

    if ocr_text:
        # Simplistic approach to find corrected text (takes the first line of OCR text)
        corrected_word = None
        for line in ocr_text.splitlines():
            line = line.strip()
            if line:  # Ensure line has content
                corrected_word = line
                break

        if corrected_word and corrected_word != word:
            print(f"Row {idx}: Correcting '{word}' to '{corrected_word}'")
            df.at[idx, 'Sanskrit Word'] = corrected_word

# Save the corrected DataFrame to a new Excel file
df.to_excel(output_excel_path, index=False)
# Out:
# Row 0: Correcting 'Apa' to '(णव जा उत गलप'
# Row 1: Correcting 'awattt:' to '(णव जा उत गलप'
# Row 2: Correcting 'ag' to 'अकुल्ाविदाः (भ'
# Row 3: Correcting 'weit' to 'अकुल्ाविदाः (भ'
# Row 4: Correcting 'aes:' to 'अकुल्ाविदाः (भ'
# Row 5: Correcting 'wag' to '०९१५४'
# Row 6: Correcting 'aq' to '(वागत) = प ००८०५ णा ला'
# Row 7: Correcting 'agile:' to '(वागत) = प ००८०५ णा ला'
# Row 8: Correcting 'afacad' to '(वागत) = प ००८०५ णा ला'
# Row 9: Correcting 'afastt' to 'यच (११५०९४२)'
# Row 10: Correcting 'ayq' to 'यच (११५०९४२)'
# Row 11: Correcting 'afte' to 'अनित्यः (  ।'
# Row 12: Correcting 'aarat' to 'अनित्यः (  ।'
# Row 13: Correcting 'aqestq' to 'अनित्यः (  ।'
# Row 14: Correcting 'TUS:' to 'न्वित (५९१७१) = (20) ए०५व ०९ १५००८'
# Row 15: Correcting 'wedadat' to 'न्वित (५९१७१) = (20) ए०५व ०९ १५००८'
# Row 16: Correcting 'afst' to 'अन्धी (भातः) = (०५) ०८५५०,'
# Row 17: Correcting 'wrist:' to 'अमलान्‌ (*१०१।१११.१) = १५५'
# Row 18: Correcting 'wAdied' to 'अमलान्‌ (*१०१।१११.१) = १५५'
# Row 19: Correcting 'aftq' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 20: Correcting 'Saar:' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 21: Correcting 'ay' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 22: Correcting 'ay:' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 23: Correcting 'aut' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 24: Correcting 'aq' to 'अरण्य; (षत) = (धब) १०८५०५५०'
# Row 25: Correcting 'apie' to 'अवाङमन (१८). = (१०)'
# Row 26: Correcting 'ae' to 'अवाङमन (१८). = (१०)'
# Row 27: Correcting 'aefa' to 'अवाङमन (१८). = (१०)'
# Row 28: Correcting 'AAT' to 'अवाङमन (१८). = (१०)'
# Row 29: Correcting 'ay' to 'अष्याहाः (*१५०१०५१०6 १८१'
# Row 30: Correcting 'ataft' to 'अत्यः (क) = ५७७०१०५ ९१५८'
# Row 31: Correcting 'TIENT' to 'अत्यः (क) = ५७७०१०५ ९१५८'
# Row 32: Correcting 'aaa' to 'व'
# Row 33: Correcting 'wegit' to 'जह (५)'
# Row 34: Correcting 'aegttit' to 'जह (५)'
# Row 35: Correcting 'ate' to 'जह (५)'
# Row 36: Correcting 'ated' to 'जह (५)'
# Row 37: Correcting 'ater' to 'जह (५)'
# Row 38: Correcting 'aa' to 'जह (५)'
# Row 39: Correcting 'AFI' to 'आलया (१०३००) = ५० ८०००९'
# Row 40: Correcting 'aids' to '८ ।'
# Row 41: Correcting 'act:' to 'आम्लं (१०५)'
# Row 42: Correcting 'add:' to '4'
# Row 43: Correcting 'aiaat' to '[१'
# Row 44: Correcting 'aed' to ': (रव्य)'
# Row 45: Correcting 'gam' to 'सवरत (८८७) = ११०८१५1 ८०८१०५१'
# Row 46: Correcting 'ge' to 'स्ट (पय)'
# Row 47: Correcting 'gq:' to 'स्ट (पय)'
# Row 48: Correcting 'qq' to 'स्ट (पय)'
# Row 49: Correcting 'sgTaate' to 'उचाव (लष) = 100 ७ (ण)'
# Row 50: Correcting 'Shas' to 'उचाव (लष) = 100 ७ (ण)'
# Row 51: Correcting '3dq' to 'उचाव (लष) = 100 ७ (ण)'
# Row 52: Correcting 'sealed' to 'तादश (५५५५१००१ ५)'
# Row 53: Correcting 'gated:' to 'तादश (५५५५१००१ ५)'
# Row 54: Correcting 'Jaq:' to 'व (७५५८ 0०१ भ)'
# Row 55: Correcting 'air:' to 'व (७५५८ 0०१ भ)'
# Row 56: Correcting 'ge' to 'पत्‌ (का) = (००) 6०'
# Row 57: Correcting 'SeqqH:' to 'पत्‌ (का) = (००) 6०'
# Row 58: Correcting 'gz:' to 'उल्वेन (५,५००)'
# Row 59: Correcting 'HT' to 'उल्वेन (५,५००)'
# Row 60: Correcting 'Hwa' to 'उल्वेन (५,५००)'
# Row 61: Correcting 'wet' to 'उल्वेन (५,५००)'
# Row 62: Correcting 'RATT' to 'उल्वेन (५,५००)'
# Row 63: Correcting 'Hatt:' to 'उल्वेन (५,५००)'
# Row 64: Correcting 'Hat' to 'उल्वेन (५,५००)'
# Row 65: Correcting 'mead' to '(1'
# Row 66: Correcting 'Wh' to '(1'
# Row 67: Correcting 'Wan' to '(1'
# Row 68: Correcting 'Ud:' to 'एतेषा (लवा) = ० ८००'
# Row 69: Correcting 'tat' to 'एतेषा (लवा) = ० ८००'
# Row 70: Correcting 'way' to 'एतेषा (लवा) = ० ८००'
# Row 71: Correcting 'me' to '(८००) ०७८'
# Row 72: Correcting 'avsatd' to '(८००) ०७८'
# Row 73: Correcting 'Hed' to 'करतलमिा (८५०११७११८३१५०) = ५1०५१५५५ १०५५'
# Row 74: Correcting 'ah' to 'करतलमिा (८५०११७११८३१५०) = ५1०५१५५५ १०५५'
# Row 75: Correcting 'waite' to 'समन (८५'
# Row 76: Correcting 'aun' to 'समन (८५'
# Row 77: Correcting 'ace' to '(4) ८०००,'
# Row 78: Correcting 'ala' to 'स्तय: (ग्‌) = (०) ०१०५, १।००० ०६ ००६'
# Row 79: Correcting 'fateay:' to 'स्तय: (ग्‌) = (०) ०१०५, १।००० ०६ ००६'
# Row 80: Correcting 'aldaed:' to 'सीत्‌ (८५८५१)'
# Row 81: Correcting 'Het:' to 'सीत्‌ (८५८५१)'
# Row 82: Correcting 'geld' to 'सीत्‌ (८५८५१)'
# Row 83: Correcting 'meq' to 'सीत्‌ (८५८५१)'
# Row 84: Correcting 'atq' to 'कमारी (बब)'
# Row 85: Correcting 'Heqg:' to 'कमारी (बब)'
# Row 86: Correcting 'fam:' to 'कमारी (बब)'
# Row 87: Correcting 'gatd' to 'कृतौ (८८'
# Row 88: Correcting 'ma' to 'कलकरमकृत्‌ (११८११०१५ ०१०४१ १)'
# Row 89: Correcting 'alata' to 'कण (५०५)'
# Row 90: Correcting 'AGT:' to 'कण (५०५)'
# Row 91: Correcting 'mq:' to 'कण (५०५)'
# Row 92: Correcting 'Ht' to 'कान्िकारक'
# Row 93: Correcting 'SUT' to 'कान्िकारक'
# Row 94: Correcting 'dg:' to 'व'
# Row 95: Correcting 'agit:' to 'व'
# Row 96: Correcting 'fea' to 'व'
# Row 97: Correcting 'feed' to 'व'
# Row 98: Correcting 'fefer' to 'व'
# Row 99: Correcting 'TST' to 'व'
# Row 100: Correcting 'THT' to 'गन्ध (हष) = चा (४९)'
# Row 101: Correcting 'Tes' to 'गन्ध (हष) = चा (४९)'
# Row 102: Correcting 'Tet:' to 'गन्ध (हष) = चा (४९)'
# Row 103: Correcting 'T+' to 'गन्ध (हष) = चा (४९)'
# Row 104: Correcting 'Tm?' to 'गन्ध (हष) = चा (४९)'
# Row 105: Correcting 'Wtf' to 'गन्ध (हष) = चा (४९)'
# Row 106: Correcting 'mT' to 'गन्ध (हष) = चा (४९)'
# Row 107: Correcting 'TMeatt' to 'का (कछ५०) = () भन्न'
# Row 108: Correcting 'it' to 'का (कछ५०) = () भन्न'
# Row 109: Correcting 'Wey:' to 'का (कछ५०) = () भन्न'
# Row 110: Correcting 'Tel' to 'गणाङ़ (हप०.ष०) = ०८१९१५९'
# Row 111: Correcting 'Ja:' to 'गणाङ़ (हप०.ष०) = ०८१९१५९'
# Row 112: Correcting 'Je' to 'गणाङ़ (हप०.ष०) = ०८१९१५९'
# Row 113: Correcting 'Tet' to 'गणाङ़ (हप०.ष०) = ०८१९१५९'
# Row 114: Correcting 'te' to 'गौ (कण) = चना'
# Row 115: Correcting 'We' to 'गौ (कण) = चना'
# Row 116: Correcting 'qd' to 'चनम (५००८१०१०) = 1.1८ ००५५'
# Row 117: Correcting 'gq' to 'चनम (५००८१०१०) = 1.1८ ००५५'
# Row 118: Correcting 'ah' to 'चनम (५००८१०१०) = 1.1८ ००५५'
# Row 119: Correcting 'Faary:' to 'चर (ल)'
# Row 120: Correcting 'Fad' to 'चर (ल)'
# Row 121: Correcting 'Faatse:' to '॥ अ'
# Row 122: Correcting 'fae' to '॥ अ'
# Row 123: Correcting 'gfe:' to '॥ अ'
# Row 124: Correcting 'Baatey:' to 'बेलयालि (०५५११०५'
# Row 125: Correcting 'fecq' to 'बेलयालि (०५५११०५'
# Row 126: Correcting 'feat' to 'बेलयालि (०५५११०५'
# Row 127: Correcting 'featt' to 'बेलयालि (०५५११०५'
# Row 128: Correcting 'fea' to 'बेलयालि (०५५११०५'
# Row 129: Correcting 'Sd' to 'बेलयालि (०५५११०५'
# Row 130: Correcting 'WF' to '[1'
# Row 131: Correcting 'Wet' to '[1'
# Row 132: Correcting 'Wa' to 'जनमकमर (उषम) = पाप ०११९ १००'
# Row 133: Correcting 'Wat' to 'जनमकमर (उषम) = पाप ०११९ १००'
# Row 134: Correcting 'We' to 'जनमकमर (उषम) = पाप ०११९ १००'
# Row 135: Correcting 'Wedd' to 'जनमकमर (उषम) = पाप ०११९ १००'
# Row 136: Correcting 'writ' to 'जनमकमर (उषम) = पाप ०११९ १००'
# Row 137: Correcting 'Wud' to 'जागत (षणासन)'
# Row 138: Correcting 'fread' to 'ए चणा मण'
# Row 139: Correcting 'Geld' to 'ए चणा मण'
# Row 140: Correcting 'wits:' to 'जयोग: (पर) = ॥ ५'
# Row 141: Correcting 'ay' to 'जयोग: (पर) = ॥ ५'
# Row 142: Correcting 'aay' to 'जयोग: (पर) = ॥ ५'
# Row 143: Correcting 'as' to 'जयोग: (पर) = ॥ ५'
# Row 144: Correcting 'ada' to 'तत्राय; (षात्‌) = ज वण ५८५१ नात८्‌ म्फ'
# Row 145: Correcting 'ada' to 'तत्राय; (षात्‌) = ज वण ५८५१ नात८्‌ म्फ'
# Row 146: Correcting 'afast:' to 'तत्राय; (षात्‌) = ज वण ५८५१ नात८्‌ म्फ'
# Row 147: Correcting 'aty' to 'तरतं (५५१५०८०१'
# Row 148: Correcting 'aty:' to 'तरतं (५५१५०८०१'
# Row 149: Correcting 'deat' to 'कतत (त) = (अतत'
# Row 150: Correcting 'ate' to 'कतत (त) = (अतत'
# Row 151: Correcting 'at' to 'कतत (त) = (अतत'
# Row 152: Correcting 'att' to 'तल (ष) = तण ९१८'
# Row 153: Correcting 'q' to 'तल (ष) = तण ९१८'
# Row 154: Correcting 'qu' to 'तृण (लर)'
# Row 155: Correcting 'qu:' to 'तृण (लर)'
# Row 156: Correcting 'ate:' to 'तृण (लर)'
# Row 157: Correcting 'q' to 'तृण (लर)'
# Row 158: Correcting 'ded:' to 'तृण (लर)'
# Row 159: Correcting 'frat' to 'त्याने (ध) = ह मत०१९य १५.०८.०१४ ०१ ५'
# Row 160: Correcting 'ata:' to '1'
# Row 161: Correcting 'cq' to '1'
# Row 162: Correcting 'cde' to '1'
# Row 163: Correcting 'avs' to '1'
# Row 164: Correcting 'aeq:' to 'दन्तपालौ (५००५०००१)'
# Row 165: Correcting 'ay' to 'दन्तपालौ (५००५०००१)'
# Row 166: Correcting 'afstt:' to 'दन्तपालौ (५००५०००१)'
# Row 167: Correcting 'ae' to '(ण) ८०७५'
# Row 168: Correcting 'aid:' to 'वयानां (काण्वो) = ०1८ पाष'
# Row 169: Correcting 'aq' to 'वयानां (काण्वो) = ०1८ पाष'
# Row 170: Correcting 'eutq' to 'वयानां (काण्वो) = ०1८ पाष'
# Row 171: Correcting 'aq' to 'दर्यं (4८८००)'
# Row 172: Correcting 'amt' to 'दर्यं (4८८००)'
# Row 173: Correcting 'aay' to 'दर्यं (4८८००)'
# Row 174: Correcting 'edd' to 'दर्यं (4८८००)'
# Row 175: Correcting 'aq' to 'क्त (०५५५)'
# Row 176: Correcting 'ee' to 'क्त (०५५५)'
# Row 177: Correcting 'aed' to 'क्त (०५५५)'
# Row 178: Correcting 'aelaaq' to 'क्त (०५५५)'
# Row 179: Correcting '«¥' to 'क्त (०५५५)'
# Row 180: Correcting 'qe:' to 'क्त (०५५५)'
# Row 181: Correcting 'af=' to 'क्त (०५५५)'
# Row 182: Correcting 'get' to 'क्त (०५५५)'
# Row 183: Correcting 'weats:' to 'देवदासी (ष) = तवाज (थ्‌) ८७००५ (क'
# Row 184: Correcting 'eat' to 'व्नन्‌ (१८१८.०८१०.१)'
# Row 185: Correcting 'att' to 'व्नन्‌ (१८१८.०८१०.१)'
# Row 186: Correcting 'aq:' to 'रोण (तरण)'
# Row 187: Correcting 'a4' to 'रोण (तरण)'
# Row 188: Correcting 'aa' to 'रोण (तरण)'
# Row 189: Correcting 'ga' to 'रोण (तरण)'
# Row 190: Correcting 'fg' to 'रोण (तरण)'
# Row 191: Correcting '=' to 'रोण (तरण)'
# Row 192: Correcting '‘gle' to 'रोण (तरण)'
# Row 193: Correcting 'gq' to 'रोण (तरण)'
# Row 194: Correcting '‘gut:' to 'रोण (तरण)'
# Row 195: Correcting 'TTT' to 'धनकारक (तायत) = स्तय मापः 1'
# Row 196: Correcting 'TTT' to 'धनकारक (तायत) = स्तय मापः 1'
# Row 197: Correcting 'wy' to 'धनकारक (तायत) = स्तय मापः 1'
# Row 198: Correcting 'wary' to 'धनकारक (तायत) = स्तय मापः 1'
# Row 199: Correcting 'qt' to 'रिः (का१००५०५)'
# Row 200: Correcting 'qty' to 'रिः (का१००५०५)'
# Row 201: Correcting 'wad' to 'रिः (का१००५०५)'
# Row 202: Correcting 'wat' to 'रिः (का१००५०५)'
# Row 203: Correcting 'qd' to 'पुरा (जा) = () उण ग्ना'
# Row 204: Correcting 'qat:' to 'पुरा (जा) = () उण ग्ना'
# Row 205: Correcting 'Yd' to 'पुरा (जा) = () उण ग्ना'
# Row 206: Correcting 'ata' to 'पुरा (जा) = () उण ग्ना'
# Row 207: Correcting 'qd:' to 'पुरा (जा) = () उण ग्ना'
# Row 208: Correcting '“Tad:' to 'पुरा (जा) = () उण ग्ना'
# Row 209: Correcting 'qq:' to 'पुरा (जा) = () उण ग्ना'
# Row 210: Correcting 'gqaracay' to 'पुरा (जा) = () उण ग्ना'
# Row 211: Correcting 'ad' to 'जरः (वाध) = (ष) ष'
# Row 212: Correcting 'ate' to 'सष्ान्‌ (पलगा००,१) = ५ १५००'
# Row 213: Correcting 'fae:' to 'लिः (षत) = न५०॥ (७१०५५ चत)'
# Row 214: Correcting 'fq' to 'निकष्य (ष४०१।५०५९) = १,५८०१०९९ ०१२८५८५'
# Row 215: Correcting 'rere:' to '१०५५ ० नह'
# Row 216: Correcting 'fafa' to '१०५५ ० नह'
# Row 217: Correcting 'fate:' to 'लित; (भ)'
# Row 218: Correcting 'tafser' to '7'
# Row 219: Correcting 'fey:' to '7'
# Row 220: Correcting 'feet' to '7'
# Row 221: Correcting 'ats' to '7'
# Row 222: Correcting 'J' to 'तु (ष) ='
# Row 223: Correcting 'qete' to 'तु (ष) ='
# Row 224: Correcting 'Td:' to '|'
# Row 225: Correcting 'qq:' to 'पोषि (कव)'
# Row 226: Correcting 'qf<y=e' to 'परित्यागः (कषत) = १५१५१८१०।१०१.'
# Row 227: Correcting 'wiper' to 'परोपकार (१०००१०१०'
# Row 228: Correcting 'was' to 'परोपकार (१०००१०१०'
# Row 229: Correcting 'qaqa' to 'परोपकार (१०००१०१०'
# Row 230: Correcting 'Gis:' to 'परोपकार (१०००१०१०'
# Row 231: Correcting 'Want' to 'पधाया (त) = ०१५८५, ५८१'
# Row 232: Correcting 'fet' to 'पावनानि (कब)'
# Row 233: Correcting 'TS' to 'तोषित (रन)'
# Row 234: Correcting 'qa' to 'तोषित (रन)'
# Row 235: Correcting 'qd' to 'पुं (षण्न)'
# Row 236: Correcting 'qt' to 'पुं (षण्न)'
# Row 237: Correcting 'qo:' to 'पुं (षण्न)'
# Row 238: Correcting 'tae' to 'पुं (षण्न)'
# Row 239: Correcting 'Tarver' to 'प (षषण्यभ)'
# Row 240: Correcting 'yeasty' to 'प (षषण्यभ)'
# Row 241: Correcting 'tay:' to 'प (षषण्यभ)'
# Row 242: Correcting 'Waae' to 'गोवि (११७५५०२५) = १००५५५८ १०८०५०५०१००'
# Row 243: Correcting 'rata:' to 'गोवि (११७५५०२५) = १००५५५८ १०८०५०५०१००'
# Row 244: Correcting 'WaT' to 'गोवि (११७५५०२५) = १००५५५८ १०८०५०५०१००'
# Row 245: Correcting 'WI' to 'प्रजातुं (१११।००५१.१९५११)'
# Row 246: Correcting 'WAT' to 'प्रप्यमिः'
# Row 247: Correcting 'Wad:' to 'प्रप्यमिः'
# Row 248: Correcting 'yatdd' to 'प्रयताः (ष्वव)'
# Row 249: Correcting 'Wade' to 'प्रयताः (ष्वव)'
# Row 250: Correcting 'Zara' to '॥ ह 7'
# Row 251: Correcting 'Wig' to '॥ ह 7'
# Row 252: Correcting 'Tiga' to '॥ ह 7'
# Row 253: Correcting 'Wat' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 254: Correcting 'Wart:' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 255: Correcting 'Wea' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 256: Correcting 'We' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 257: Correcting 'Wed' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 258: Correcting 'Wele' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 259: Correcting 'Waele:' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 260: Correcting 'We' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 261: Correcting 'Ware:' to 'पसाव (ष) = ४१ 0५८१२५०१'
# Row 262: Correcting 'We' to 'पर्ष (१५०५०५१५)'
# Row 263: Correcting 'Wat' to 'पर्ष (१५०५०५१५)'
# Row 264: Correcting 'WS' to 'पर्ष (१५०५०५१५)'
# Row 265: Correcting 'wreaked' to 'पर्ष (१५०५०५१५)'
# Row 266: Correcting 'qaqa' to 'पमार (ताना) = कतमा (१४०)'
# Row 267: Correcting 'quttd' to 'पमार (ताना) = कतमा (१४०)'
# Row 268: Correcting 'atts' to 'वनधतदासन (१,७१८१५११००१०००'
# Row 269: Correcting 'ate:' to 'वनधतदासन (१,७१८१५११००१०००'
# Row 270: Correcting 'qe' to 'वनधतदासन (१,७१८१५११००१०००'
# Row 271: Correcting 'qeer' to 'वनधतदासन (१,७१८१५११००१०००'
# Row 272: Correcting 'fa-q' to 'ह्या (१८००१२५)'
# Row 273: Correcting 'qq' to 'वाजः (षा) = ५५.०५८'
# Row 274: Correcting 'Ga:' to 'वाजः (षा) = ५५.०५८'
# Row 275: Correcting 'qactg:' to 'वाजः (षा) = ५५.०५८'
# Row 276: Correcting 'qq:' to 'वाजः (षा) = ५५.०५८'
# Row 277: Correcting 'Seal' to 'दत्तिः (४०५)'
# Row 278: Correcting 'del.' to '1 व'
# Row 279: Correcting 'aaj' to '1 व'
# Row 280: Correcting 'Tavs' to '1 व'
# Row 281: Correcting 'q' to '1 व'
# Row 282: Correcting 'wed' to '1 व'
# Row 283: Correcting 'wed' to '1 व'
# Row 284: Correcting 'watt' to 'भज्‌ (ष) = ५००९९ कण'
# Row 285: Correcting 'Wat' to 'भज्‌ (ष) = ५००९९ कण'
# Row 286: Correcting 'waft' to 'भवतः (काक) = परा'
# Row 287: Correcting 'wat' to 'भवतः (काक) = परा'
# Row 288: Correcting 'way' to '४)'
# Row 289: Correcting 'WE' to 'छिद (५५१.) = ५०७.५०५'
# Row 290: Correcting 'YT' to 'भः (ण) = १,८००१५'
# Row 291: Correcting 'wa:' to 'भेर 7'
# Row 292: Correcting 'watt' to 'भेर 7'
# Row 293: Correcting 'yay' to 'सताः (त)'
# Row 294: Correcting 'We' to 'सद्यः (१०१७)'
# Row 295: Correcting 'aay' to 'सद्यः (१०१७)'
# Row 296: Correcting 'AAWde' to 'सद्यः (१०१७)'
# Row 297: Correcting 'Watt:' to '०५०५९. ए९८८१० ८१०८'
# Row 298: Correcting 'Hach' to '०५०५९. ए९८८१० ८१०८'
# Row 299: Correcting 'Weft' to 'सत्तः (षा) = (०५) ७१८९५१५.'
# Row 300: Correcting 'Weat' to 'प'
# Row 301: Correcting 'AT' to 'प'
# Row 302: Correcting 'fat' to 'मारतः (०५)'
# Row 303: Correcting 'qecaT-' to 'सुक्तम्‌ (१५५५१५४१.१)'
# Row 304: Correcting 'TT' to 'लल (५५८१०)'
# Row 305: Correcting 'yfyf' to 'लल (५५८१०)'
# Row 306: Correcting 'WS' to 'लल (५५८१०)'
# Row 307: Correcting 'Wd' to 'लल (५५८१०)'
# Row 308: Correcting 'Wag' to 'सुतस्य (षाम) = ०१५५५'
# Row 309: Correcting 'HAT' to 'सुतस्य (षाम) = ०१५५५'
# Row 310: Correcting 'Te' to 'सुतस्य (षाम) = ०१५५५'
# Row 311: Correcting 'We:' to 'सुतस्य (षाम) = ०१५५५'
# Row 312: Correcting 'aq' to 'सोदादास्यानि (११०१,१००११०५'
# Row 313: Correcting 'aq:' to 'सोदादास्यानि (११०१,१००११०५'
# Row 314: Correcting 'Get' to 'न णड'
# Row 315: Correcting 'Gees' to 'न णड'
# Row 316: Correcting 'Gav:' to 'यवन (अकण) = पणा'
# Row 317: Correcting 'qT' to 'यातयाम (अष्पकषोथ)'
# Row 318: Correcting 'qq' to 'यु्लील (गात) = पत ०८८०५००० तार ८००८००००'
# Row 319: Correcting 'Gg' to 'यु्लील (गात) = पत ०८८०५००० तार ८००८००००'
# Row 320: Correcting 'Gg' to 'यु्लील (गात) = पत ०८८०५००० तार ८००८००००'
# Row 321: Correcting 'anreatate' to 'योगः (णभ)'
# Row 322: Correcting 'anrat:' to 'योगः (णभ)'
# Row 323: Correcting 'td' to 'रोण (पषण) = ५८०. भ'
# Row 324: Correcting 'ty' to 'रोण (पषण) = ५८०. भ'
# Row 325: Correcting 'te' to 'रामाय (ष) = ८०१'
# Row 326: Correcting 'ett' to 'रामाय (ष) = ८०१'
# Row 327: Correcting 'eq' to 'रामाय (ष) = ८०१'
# Row 328: Correcting 'eaeq?' to 'रामाय (ष) = ८०१'
# Row 329: Correcting 'ey' to 'रामाय (ष) = ८०१'
# Row 330: Correcting 'ea' to 'रामाय (ष) = ८०१'
# Row 331: Correcting 'tq' to 'लन (०८५०५) = नड'
# Row 332: Correcting 'ata' to 'लन (०८५०५) = नड'
# Row 333: Correcting 'ad' to 'लन (०८५०५) = नड'
# Row 334: Correcting 'wean' to 'लन (०८५०५) = नड'
# Row 335: Correcting 'wT' to 'लन (०८५०५) = नड'
# Row 336: Correcting 'wa:' to 'लभते ५०५९९'
# Row 337: Correcting 'aa' to 'लाला (५५७१) = (१) षा'
# Row 338: Correcting 'ast:' to 'लाला (५५७१) = (१) षा'
# Row 339: Correcting 'art' to 'लोकि (१०५५) = २१५१ ०८५'
# Row 340: Correcting 'az' to 'लोकि (१०५५) = २१५१ ०८५'
# Row 341: Correcting 'ae' to 'लोकि (१०५५) = २१५१ ०८५'
# Row 342: Correcting 'qa' to 'लोकि (१०५५) = २१५१ ०८५'
# Row 343: Correcting 'ay' to 'लोकि (१०५५) = २१५१ ०८५'
# Row 344: Correcting 'qa' to 'त पवनम'
# Row 345: Correcting 'aq' to 'त पवनम'
# Row 346: Correcting 'qq' to 'त पवनम'
# Row 347: Correcting 'qq' to 'त पवनम'
# Row 348: Correcting 'qt:' to 'त पवनम'
# Row 349: Correcting 'add' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 350: Correcting 'aqdq' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 351: Correcting 'qded' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 352: Correcting 'qdatt' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 353: Correcting 'adatt:' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 354: Correcting 'ad' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 355: Correcting 'add' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 356: Correcting 'aud' to 'करद (धत) = ५,५५ १८, 6८०१००१'
# Row 357: Correcting 'qa-d' to 'वर्त्‌ (९५)'
# Row 358: Correcting 'ate' to 'वर्त्‌ (९५)'
# Row 359: Correcting 'faseq' to 'वाहनकारक (१५'
# Row 360: Correcting 'fame' to 'वाहनकारक (१५'
# Row 361: Correcting 'faq' to 'विनतो (कोण) = त मवण) ०'
# Row 362: Correcting 'fad' to 'विनतो (कोण) = त मवण) ०'
# Row 363: Correcting 'fad' to 'विनतो (कोण) = त मवण) ०'
# Row 364: Correcting 'fame' to '॥'
# Row 365: Correcting 'fagxrq' to '॥'
# Row 366: Correcting 'fat' to '॥. व'
# Row 367: Correcting 'faftfac:' to '॥. व'
# Row 368: Correcting 'faye:' to 'प्च'
# Row 369: Correcting 'fate' to 'विमुच्य (श्छ)'
# Row 370: Correcting 'faz' to 'दसवत (५५५५५१९५)'
# Row 371: Correcting 'fay' to 'वितनु; (जात) = छम'
# Row 372: Correcting 'fae' to '॥ ब ` ए)'
# Row 373: Correcting 'qalat:' to 'ता्‌'
# Row 374: Correcting 'qd' to 'ता्‌'
# Row 375: Correcting 'qq:' to 'ता्‌'
# Row 376: Correcting 'qf=' to 'ता्‌'
# Row 377: Correcting 'gfe:' to 'ता्‌'
# Row 378: Correcting 'gfat' to 'ता्‌'
# Row 379: Correcting 'qd' to 'केच (९५५५) = ९१८ ४०५.'
# Row 380: Correcting 'aaah:' to 'केच (९५५५) = ९१८ ४०५.'
# Row 381: Correcting 'qt' to 'कषु च०८८०४.५'
# Row 382: Correcting 'qaifarat' to 'कषु च०८८०४.५'
# Row 383: Correcting 'cad' to 'कषु च०८८०४.५'
# Row 384: Correcting 'aa' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 385: Correcting 'aad' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 386: Correcting 'aq' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 387: Correcting 'ad' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 388: Correcting 'ald' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 389: Correcting 'faq' to 'व्यवायतः (षण) = ५१५ ८५७०५००'
# Row 390: Correcting 'Wg' to 'जेषि (ष) = (1 00) ८०८००'
# Row 391: Correcting 'Mo:' to 'जेषि (ष) = (1 00) ८०८००'
# Row 392: Correcting 'wsait' to 'जेषि (ष) = (1 00) ८०८००'
# Row 393: Correcting 'Md:' to 'जलः (श्त) = ब'
# Row 394: Correcting 'weary' to 'जलः (श्त) = ब'
# Row 395: Correcting 'Waits:' to '(५८५५८०५1 १०५५'
# Row 396: Correcting 'Wad:' to 'जवान (न) = भ'
# Row 397: Correcting 'wrad' to 'जवान (न) = भ'
# Row 398: Correcting 'fay' to '(1'
# Row 399: Correcting 'Mitt' to '(1'
# Row 400: Correcting 'Yo:' to '(1'
# Row 401: Correcting 'Wit:' to 'शुका (क)'
# Row 402: Correcting 'Wat' to 'ज (भपप)'
# Row 403: Correcting 'fat:' to 'दयान्वितः (शण ५००१९०) 1'
# Row 404: Correcting 'sad' to 'दयान्वितः (शण ५००१९०) 1'
# Row 405: Correcting 'sft' to 'दयान्वितः (शण ५००१९०) 1'
# Row 406: Correcting 'ataft' to 'भूतौ (ल) = प सत'
# Row 407: Correcting 'Wd' to 'भूतौ (ल) = प सत'
# Row 408: Correcting 'dad:' to 'भूतौ (ल) = प सत'
# Row 409: Correcting 'ad' to 'लात स'
# Row 410: Correcting 'acq' to 'लात स'
# Row 411: Correcting 'aay' to 'लात स'
# Row 412: Correcting 'ted' to 'संितदताः (०१,१०।१५०५१०९००'
# Row 413: Correcting 'de' to 'संितदताः (०१,१०।१५०५१०९००'
# Row 414: Correcting 'Ga:' to 'संितदताः (०१,१०।१५०५१०९००'
# Row 415: Correcting 'agat' to 'सः (न्त) = प'
# Row 416: Correcting 'age' to 'सः (न्त) = प'
# Row 417: Correcting 'ag' to 'सः (न्त) = प'
# Row 418: Correcting 'aq:' to 'सः (न्त) = प'
# Row 419: Correcting 'ae' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 420: Correcting 'Wet' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 421: Correcting 'ag' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 422: Correcting 'Ggted' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 423: Correcting 'Ggid:' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 424: Correcting 'We:' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 425: Correcting 'ad:' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 426: Correcting 'acq' to 'सङ्गीतम्‌ (८१.१४१०३०१५.) = (१) ^ ०१५९ ०००८५'
# Row 427: Correcting 'Wea' to 'सत्वसंगुदिः (*१५५१०००.१०।५८) प)'
# Row 428: Correcting 'aaa' to 'सत्वसंगुदिः (*१५५१०००.१०।५८) प)'
# Row 429: Correcting 'dale' to 'सत्वसंगुदिः (*१५५१०००.१०।५८) प)'
# Row 430: Correcting 'ade' to 'सत्वसंगुदिः (*१५५१०००.१०।५८) प)'
# Row 431: Correcting 'ataattt?' to 'सण त्मकानन'
# Row 432: Correcting 'aay' to 'सण त्मकानन'
# Row 433: Correcting 'ait:' to 'सम्बन्धिनः (ल'
# Row 434: Correcting 'aut' to 'सम्बन्धिनः (ल'
# Row 435: Correcting 'aq:' to 'सम्बन्धिनः (ल'
# Row 436: Correcting 'aad' to '(षा)'
# Row 437: Correcting 'aad:' to '(षा)'
# Row 438: Correcting 'add:' to '(षा)'
# Row 439: Correcting 'ada:' to '(षा)'
# Row 440: Correcting 'waaay:' to '(षा)'
# Row 441: Correcting 'adtaq' to '(षा)'
# Row 442: Correcting 'adqamt' to '(षा)'
# Row 443: Correcting 'aaa:' to '(षा)'
# Row 444: Correcting 'adie' to 'स्वाङ्ग (चर) = ५,८.०१'
# Row 445: Correcting 'aq' to 'स्वाङ्ग (चर) = ५,८.०१'
# Row 446: Correcting 'We' to 'स्वाङ्ग (चर) = ५,८.०१'
# Row 447: Correcting 'Waa' to 'स्वाङ्ग (चर) = ५,८.०१'
# Row 448: Correcting 'aaa' to 'स्वाङ्ग (चर) = ५,८.०१'
# Row 449: Correcting 'qeadiel' to '५१००८००१.१००१'
# Row 450: Correcting 'Weaia:' to '५१००८००१.१००१'
# Row 451: Correcting 'gdh:' to '५१००८००१.१००१'
# Row 452: Correcting 'aga' to '५१००८००१.१००१'
# Row 453: Correcting 'alga' to '५१००८००१.१००१'
# Row 454: Correcting 'aga:' to '५१००८००१.१००१'
# Row 455: Correcting 'fae' to 'सास (ज्‌) = ११५५१५५१'
# Row 456: Correcting 'fad' to 'सास (ज्‌) = ११५५१५५१'
# Row 457: Correcting 'fag:' to 'सास (ज्‌) = ११५५१५५१'
# Row 458: Correcting 'feeaty' to 'सास (ज्‌) = ११५५१५५१'
# Row 459: Correcting 'qd' to 'सुगान्थि (तो)'
# Row 460: Correcting 'qt' to 'सुगान्थि (तो)'
# Row 461: Correcting 'atten' to 'सुगान्थि (तो)'
# Row 462: Correcting 'qa' to 'सुगान्थि (तो)'
# Row 463: Correcting 'qattart:' to 'सुगान्थि (तो)'
# Row 464: Correcting 'Gea' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 465: Correcting 'ad' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 466: Correcting 'qa' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 467: Correcting 'qa' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 468: Correcting 'qaye' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 469: Correcting 'qated:' to 'सुषयवस्थता (च५४१०८५१९११) = भ] ०६००१०८८'
# Row 470: Correcting 'get' to 'सेचननालः (भोकणमभ्‌)'
# Row 471: Correcting 'atte:' to 'सेचननालः (भोकणमभ्‌)'
# Row 472: Correcting 'ae' to 'सेचननालः (भोकणमभ्‌)'
# Row 473: Correcting 'mad' to 'स्मः (भताना) = (र) ५०५१०'
# Row 474: Correcting 'Gis' to 'स्नान (लम) = (षामा) 0५१९'
# Row 475: Correcting 'eqatq' to 'स्नान (लम) = (षामा) 0५१९'
# Row 476: Correcting 'feratttaet' to 'स्नान (लम) = (षामा) 0५१९'
# Row 477: Correcting 'eq:' to 'स्यत्‌ ( ।'
# Row 478: Correcting 'tq:' to 'स्यत्‌ ( ।'
# Row 479: Correcting 'tat' to 'स्वया (कपयषत९१) = साप ९८१०5७१)'
# Row 480: Correcting 'rae' to '५. १५।९०८०९५१००'
# Row 481: Correcting 'eq' to '५. १५।९०८०९५१००'
# Row 482: Correcting 'Beant' to '५. १५।९०८०९५१००'
# Row 483: Correcting 'aa:' to '५. १५।९०८०९५१००'
# Row 484: Correcting 'a' to '५. १५।९०८०९५१००'
# Row 485: Correcting 'aq:' to '५. १५।९०८०९५१००'
# Row 486: Correcting 'att' to '५. १५।९०८०९५१००'
# Row 487: Correcting 'att:' to '५. १५।९०८०९५१००'
# Row 488: Correcting 'ator' to '५. १५।९०८०९५१००'
# Row 489: Correcting 'ated' to 'हत (गात) = किण'
# Row 490: Correcting 'Sut:' to 'हत (गात) = किण'
# Row 491: Correcting 'St:' to 'हत (गात) = किण'
# Row 492: Correcting 'st' to 'हत (गात) = किण'
# Row 493: Correcting 'SY' to 'हत (गात) = किण'
# Row 494: Correcting 'alq:' to 'हत (गात) = किण'
# Row 495: Correcting 'aed' to 'हत (गात) = किण'
# Row 496: Correcting 'featet' to 'हत (गात) = किण'
# Row 497: Correcting 'feat' to 'हत (गात) = किण'
# Row 498: Correcting 'Zest' to '(आ) 1'
# Row 499: Correcting 'eal:' to '(आ) 1'
# Row 500: Correcting 'Zima' to '(आ) 1'
# Row 501: Correcting 'etd' to '(आ) 1'
# Row 502: Correcting 'aqdats:' to '(आ) 1'
# Row 503: Correcting 'peal' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 504: Correcting 'Bl:' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 505: Correcting 'a' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 506: Correcting 'far' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 507: Correcting 'fat' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 508: Correcting 'ay' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 509: Correcting 'as' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 510: Correcting 'ay' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 511: Correcting 'aaT' to 'स्वा (0०८५१) = (१८) ०८१५'
# Row 512: Correcting 'at' to 'धधतं (८७।५,०१५०१५१)'
# Row 513: Correcting 'ay' to 'धधतं (८७।५,०१५०१५१)'
# Row 514: Correcting 'aa' to 'धधतं (८७।५,०१५०१५१)'
# Row 515: Correcting 'aaa' to 'धधतं (८७।५,०१५०१५१)'
# Row 516: Correcting 'aaa:' to 'धधतं (८७।५,०१५०१५१)'
# Row 517: Correcting 'aay' to 'धधतं (८७।५,०१५०१५१)'
# Row 518: Correcting '3' to 'धधतं (८७।५,०१५०१५१)'

# %%
import pandas as pd
import fitz  # PyMuPDF for PDF handling
import pytesseract
from PIL import Image

# Paths to files
incorrect_words_path = "notprocessedvalues.xlsx"  # Your Excel file with incorrect words
reference_words_path = "unique_sanskrit_words_ordered.csv"  # Reference file in CSV (no header)
pdf_path = "dictallcheck.pdf"
output_path = "corrected_with_reference.xlsx"

# Load Excel file with incorrect words
df_incorrect = pd.read_excel(incorrect_words_path)

# Load reference CSV without a header
df_reference = pd.read_csv(reference_words_path, header=None)  # No header
reference_words = df_reference[0].dropna().tolist()  # Extract the first column as a list

# Function to perform OCR on a specific page
def extract_text_with_preprocessing(pdf_path, page_number):
    try:
        doc = fitz.open(pdf_path)
        if 1 <= page_number <= len(doc):
            page = doc[page_number - 1]
            pix = page.get_pixmap(dpi=300)  # Enhance resolution
            img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
            img = img.convert("L")  # Convert to grayscale
            img = img.point(lambda x: 0 if x < 128 else 255, '1')  # Binarization
            text = pytesseract.image_to_string(img, lang='san')  # Sanskrit OCR
            return text.splitlines()  # Return as list of lines
        else:
            return None
    except Exception as e:
        print(f"Error during OCR on page {page_number}: {e}")
        return None

# Iterate through the incorrect words DataFrame
for idx, row in df_incorrect.iterrows():
    word = row['Sanskrit Word']
    page_number = int(row['Page Number'])

    # Perform OCR on the specified page
    ocr_text_lines = extract_text_with_preprocessing(pdf_path, page_number)

    if ocr_text_lines:
        # Match OCR lines with the reference words
        corrected_word = None
        for line in ocr_text_lines:
            line = line.strip()
            if line in reference_words:
                corrected_word = line
                break

        # Update the incorrect word if a match is found
        if corrected_word and corrected_word != word:
            print(f"Row {idx}: Correcting '{word}' to '{corrected_word}'")
            df_incorrect.at[idx, 'Sanskrit Word'] = corrected_word

# Save the corrected DataFrame
df_incorrect.to_excel(output_path, index=False)
print(f"Corrected file saved to {output_path}")
# Out:
# Row 14: Correcting 'TUS:' to '13'
# Row 15: Correcting 'wedadat' to '13'
# Corrected file saved to corrected_with_reference.xlsx

# %%
import pandas as pd

# Function to convert Excel to CSV
def excel_to_csv(excel_file, csv_file):
    # Load the Excel file
    try:
        df = pd.read_excel(excel_file)
        # Save it as a CSV file with UTF-8 encoding
        df.to_csv(csv_file, index=False, encoding='utf-8')
        print(f"Excel file '{excel_file}' has been successfully converted to CSV: '{csv_file}'")
    except Exception as e:
        print(f"Error while converting Excel to CSV: {e}")

# Example usage
excel_file = 'DATASET.xlsx'  # Update with the path to your Excel file
csv_file = 'DATASET.csv'  # Update with the desired output CSV file name

# Call the function to convert
excel_to_csv(excel_file, csv_file)
# Out:
# Excel file 'DATASET.xlsx' has been successfully converted to CSV: 'DATASET.csv'
